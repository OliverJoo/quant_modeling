# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.applications.densenet import DenseNet201
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.optimizers import Adam

import tensorflow_datasets as tfds

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')

sns.set_style('whitegrid')

results_path = Path ('results', 'eurosat')
if not results_path.exists():
    results_path.mkdir(parents=True)
# Out:
# Using GPU

# %%
# Load EuroSat Dataset
(raw_train, raw_validation, raw_test), metadata = tfds.load('eurosat',
                                                  split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
                                                  with_info=True, shuffle_files=False, as_supervised=True,
                                                  data_dir='data/tensorflow')

# %%
metadata # Inspect MetaData
# Out:
# tfds.core.DatasetInfo(
#     name='eurosat',
#     full_name='eurosat/rgb/2.0.0',
#     description="""
#     EuroSAT dataset is based on Sentinel-2 satellite images covering 13 spectral
#     bands and consisting of 10 classes with 27000 labeled and
#     geo-referenced samples.
#
#     Two datasets are offered:
#     - rgb: Contains only the optical R, G, B frequency bands encoded as JPEG image.
#     - all: Contains all 13 bands in the original value range (float32).
#
#     URL: https://github.com/phelber/eurosat
#     """,
#     config_description="""
#     Sentinel-2 RGB channels
#     """,
#     homepage='https://github.com/phelber/eurosat',
#     data_path='data/tensorflow\\eurosat\\rgb\\2.0.0',
#     download_size=89.91 MiB,
#     dataset_size=89.50 MiB,
#     features=FeaturesDict({
#         'filename': Text(shape=(), dtype=tf.string),
#         'image': Image(shape=(64, 64, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=27000, num_shards=1>,
#     },
#     citation="""@misc{helber2017eurosat,
#         title={EuroSAT: A Novel Dataset and Deep Learning Benchmark for Land Use and Land Cover Classification},
#         author={Patrick Helber and Benjamin Bischke and Andreas Dengel and Damian Borth},
#         year={2017},
#         eprint={1709.00029},
#         archivePrefix={arXiv},
#         primaryClass={cs.CV}
#     }""",
# )

# %%
print('Train:\t', raw_train)
print('Valid:\t', raw_validation)
# Out:
# Train:	 <PrefetchDataset shapes: ((64, 64, 3), ()), types: (tf.uint8, tf.int64)>
# Valid:	 <PrefetchDataset shapes: ((64, 64, 3), ()), types: (tf.uint8, tf.int64)>

# %%
# Show sample images
fig, axes = plt.subplots(figsize=(17, 12), ncols=5, nrows=2)
axes = axes.flatten()
get_label_name = metadata.features['label'].int2str
labels = set()
c = 0
for img, label in raw_train.as_numpy_iterator():
    if label not in labels:
        axes[c].imshow(img)
        axes[c].set_title(get_label_name(label))
        axes[c].grid(False)
        axes[c].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False,
                            left=False, labelleft=False)
        labels.add(label)
        c += 1
        if c == 10:
            break
fig.suptitle('EuroSat Satellite Images', fontsize=16)
fig.tight_layout()
fig.subplots_adjust(top=.92);
# fig.savefig(results_path / 'eurosat_samples', dpi=300);

# %%
# Preprocessing
IMG_SIZE = 64
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)

def format_example(image, label):
    image = tf.cast(image, tf.float32)
    image = (image/127.5) - 1
    return image, label

train = raw_train.map(format_example)
validation = raw_validation.map(format_example)
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000
train_batches = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
validation_batches = validation.batch(BATCH_SIZE)

for image_batch, label_batch in train_batches.take(1):
    pass

image_batch.shape
# Out:
# TensorShape([32, 64, 64, 3])

# %%
# Load the DenseNet201 Bottleneck Features
densenet = DenseNet201(input_shape=IMG_SHAPE, include_top=False, weights='imagenet', pooling='max',
                       classes=1000)

densenet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 7s 0us/step
# 74850304/74836368 [==============================] - 7s 0us/step
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 70, 70, 3)   0           ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 32, 32, 64)   9408        ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 32, 32, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 32, 32, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 34, 34, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 16, 16, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 16, 16, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 16, 16, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 16, 16, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 16, 16, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 16, 16, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 16, 16, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 16, 16, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 16, 16, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 16, 16, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 16, 16, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 16, 16, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 16, 16, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 16, 16, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 16, 16, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 16, 16, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 8, 8, 128)    0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 8, 8, 128)   512         ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 8, 8, 128)    16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 8, 8, 160)   0           ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 8, 8, 160)   640         ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 8, 8, 160)   0           ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 8, 8, 128)    20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 8, 8, 192)   0           ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 8, 8, 192)   768         ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 8, 8, 192)   0           ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 8, 8, 128)    24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 8, 8, 224)   0           ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 8, 8, 224)   896         ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 8, 8, 224)   0           ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 8, 8, 128)    28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 8, 8, 256)   0           ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 8, 8, 288)   0           ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 8, 8, 320)   0           ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 8, 8, 352)   0           ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 8, 8, 384)   0           ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 8, 8, 416)   0           ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 8, 8, 416)   1664        ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 8, 8, 416)   0           ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 8, 8, 128)    53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 8, 8, 128)   0           ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 8, 8, 448)   0           ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 8, 8, 448)   1792        ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 8, 8, 448)   0           ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 8, 8, 128)    57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 8, 8, 128)   0           ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 8, 8, 480)   0           ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 8, 8, 480)   1920        ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 8, 8, 480)   0           ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 8, 8, 128)    61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 8, 8, 128)   0           ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 8, 8, 512)   0           ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 8, 8, 512)    2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 8, 8, 512)    0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 8, 8, 256)    131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 4, 4, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 4, 4, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 4, 4, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 4, 4, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 4, 4, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 4, 4, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 4, 4, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 4, 4, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 4, 4, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 4, 4, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 4, 4, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 4, 4, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 4, 4, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 4, 4, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 4, 4, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 4, 4, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 4, 4, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 4, 4, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 4, 4, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 4, 4, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 4, 4, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 4, 4, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 4, 4, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 4, 4, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 4, 4, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 4, 4, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 4, 4, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 4, 4, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
# ...
#  conv5_block25_0_bn (BatchNorma  (None, 2, 2, 1664)  6656        ['conv5_block24_concat[0][0]']
#  lization)
#
#  conv5_block25_0_relu (Activati  (None, 2, 2, 1664)  0           ['conv5_block25_0_bn[0][0]']
#  on)
#
#  conv5_block25_1_conv (Conv2D)  (None, 2, 2, 128)    212992      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 2, 2, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 2, 2, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 2, 2, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 2, 2, 1696)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 2, 2, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 2, 2, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 2, 2, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 2, 2, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 2, 2, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 2, 2, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 2, 2, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 2, 2, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 2, 2, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 2, 2, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 2, 2, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 2, 2, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 2, 2, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 2, 2, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 2, 2, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 2, 2, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 2, 2, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 2, 2, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 2, 2, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 2, 2, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 2, 2, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 2, 2, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 2, 2, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 2, 2, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 2, 2, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 2, 2, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 2, 2, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 2, 2, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 2, 2, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 2, 2, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 2, 2, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 2, 2, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 2, 2, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 2, 2, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 2, 2, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 2, 2, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 2, 2, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 2, 2, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 2, 2, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 2, 2, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 2, 2, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 2, 2, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 2, 2, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 2, 2, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 2, 2, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 2, 2, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 2, 2, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 2, 2, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 2, 2, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 2, 2, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 2, 2, 1920)   0           ['bn[0][0]']
#
#  max_pool (GlobalMaxPooling2D)  (None, 1920)         0           ['relu[0][0]']
#
# ==================================================================================================
# Total params: 18,321,984
# Trainable params: 18,092,928
# Non-trainable params: 229,056
# __________________________________________________________________________________________________

# %%
feature_batch = densenet(image_batch)
feature_batch.shape
# Out:
# TensorShape([32, 1920])

# %%
len(densenet.layers)
# Out:
# 708

# %%
# Add new layers to model
model = Sequential([
    densenet,
    BatchNormalization(),
    Dense(2048, activation='relu', kernel_regularizer=l1_l2(0.01)),
    BatchNormalization(),
    Dense(2048, activation='relu', kernel_regularizer=l1_l2(0.01)),
    BatchNormalization(),
    Dense(2048, activation='relu', kernel_regularizer=l1_l2(0.01)),
    BatchNormalization(),
    Dense(2048, activation='relu', kernel_regularizer=l1_l2(0.01)),
    BatchNormalization(),
    Dense(10, activation='softmax')
])

for layer in model.layers:
    layer.trainable = True

model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(lr=1e-4), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dense (Dense)               (None, 2048)              3934208
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dense_1 (Dense)             (None, 2048)              4196352
#
#  batch_normalization_2 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dense_2 (Dense)             (None, 2048)              4196352
#
#  batch_normalization_3 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dense_3 (Dense)             (None, 2048)              4196352
#
#  batch_normalization_4 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dense_4 (Dense)             (None, 10)                20490
#
# =================================================================
# Total params: 34,906,186
# Trainable params: 34,656,906
# Non-trainable params: 249,280
# _________________________________________________________________

# %%
# Compute baseline metrics
initial_epochs = 10
validation_steps = 20

initial_loss, initial_accuracy = model.evaluate(validation_batches, steps = validation_steps)
# Out:
# 20/20 [==============================] - 9s 50ms/step - loss: 3255.9126 - accuracy: 0.1250

# %%
print(f'Initial loss: {initial_loss:.2f} | initial_accuracy accuracy: {initial_accuracy:.2%}')
# Out:
# Initial loss: 3255.91 | initial_accuracy accuracy: 12.50%

# %%
# Train model
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10)
eurosat_path = (results_path / 'cnn.weights.best.hdf5').as_posix()
checkpointer = ModelCheckpoint(filepath=eurosat_path, verbose=1, monitor='val_accuracy', save_best_only=True)
epochs = 100
history = model.fit(train_batches, epochs=epochs, validation_data=validation_batches,
                    callbacks=[checkpointer, early_stopping], workers=6)
# Out:
# Epoch 1/100
# 675/675 [==============================] - ETA: 0s - loss: 789.9310 - accuracy: 0.8120
# Epoch 00001: val_accuracy improved from -inf to 0.67074, saving model to results/eurosat\cnn.weights.best.hdf5
# 675/675 [==============================] - 134s 173ms/step - loss: 789.9310 - accuracy: 0.8120 - val_loss: 6.6478 - val_accuracy: 0.6707
# Epoch 2/100
# 675/675 [==============================] - ETA: 0s - loss: 2.7839 - accuracy: 0.9145
# Epoch 00002: val_accuracy improved from 0.67074 to 0.94741, saving model to results/eurosat\cnn.weights.best.hdf5
# 675/675 [==============================] - 116s 171ms/step - loss: 2.7839 - accuracy: 0.9145 - val_loss: 2.7190 - val_accuracy: 0.9474
# Epoch 3/100
# 675/675 [==============================] - ETA: 0s - loss: 2.3447 - accuracy: 0.9541
# Epoch 00003: val_accuracy did not improve from 0.94741
# 675/675 [==============================] - 111s 164ms/step - loss: 2.3447 - accuracy: 0.9541 - val_loss: 2.2897 - val_accuracy: 0.9370
# Epoch 4/100
# 675/675 [==============================] - ETA: 0s - loss: 2.2558 - accuracy: 0.9646
# Epoch 00004: val_accuracy improved from 0.94741 to 0.96778, saving model to results/eurosat\cnn.weights.best.hdf5
# 675/675 [==============================] - 112s 166ms/step - loss: 2.2558 - accuracy: 0.9646 - val_loss: 2.2559 - val_accuracy: 0.9678
# Epoch 5/100
# 675/675 [==============================] - ETA: 0s - loss: 2.4599 - accuracy: 0.9628
# Epoch 00005: val_accuracy did not improve from 0.96778
# 675/675 [==============================] - 111s 164ms/step - loss: 2.4599 - accuracy: 0.9628 - val_loss: 2.3054 - val_accuracy: 0.9515
# Epoch 6/100
# 675/675 [==============================] - ETA: 0s - loss: 2.1432 - accuracy: 0.9749
# Epoch 00006: val_accuracy did not improve from 0.96778
# 675/675 [==============================] - 108s 161ms/step - loss: 2.1432 - accuracy: 0.9749 - val_loss: 2.1683 - val_accuracy: 0.9670
# Epoch 7/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0660 - accuracy: 0.9842
# Epoch 00007: val_accuracy improved from 0.96778 to 0.96889, saving model to results/eurosat\cnn.weights.best.hdf5
# 675/675 [==============================] - 113s 168ms/step - loss: 2.0660 - accuracy: 0.9842 - val_loss: 2.1433 - val_accuracy: 0.9689
# Epoch 8/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0609 - accuracy: 0.9856
# Epoch 00008: val_accuracy did not improve from 0.96889
# 675/675 [==============================] - 106s 156ms/step - loss: 2.0609 - accuracy: 0.9856 - val_loss: 2.1435 - val_accuracy: 0.9619
# Epoch 9/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0671 - accuracy: 0.9823
# Epoch 00009: val_accuracy did not improve from 0.96889
# 675/675 [==============================] - 109s 161ms/step - loss: 2.0671 - accuracy: 0.9823 - val_loss: 2.2055 - val_accuracy: 0.9441
# Epoch 10/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0402 - accuracy: 0.9838
# Epoch 00010: val_accuracy did not improve from 0.96889
# 675/675 [==============================] - 112s 166ms/step - loss: 2.0402 - accuracy: 0.9838 - val_loss: 4.2306 - val_accuracy: 0.8770
# Epoch 11/100
# 675/675 [==============================] - ETA: 0s - loss: 1.9548 - accuracy: 0.9862
# Epoch 00011: val_accuracy did not improve from 0.96889
# 675/675 [==============================] - 108s 159ms/step - loss: 1.9548 - accuracy: 0.9862 - val_loss: 2.0040 - val_accuracy: 0.9681
# Epoch 12/100
# 675/675 [==============================] - ETA: 0s - loss: 2.1017 - accuracy: 0.9841
# Epoch 00012: val_accuracy improved from 0.96889 to 0.97667, saving model to results/eurosat\cnn.weights.best.hdf5
# 675/675 [==============================] - 114s 169ms/step - loss: 2.1017 - accuracy: 0.9841 - val_loss: 2.0168 - val_accuracy: 0.9767
# Epoch 13/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0686 - accuracy: 0.9823
# Epoch 00013: val_accuracy did not improve from 0.97667
# 675/675 [==============================] - 112s 165ms/step - loss: 2.0686 - accuracy: 0.9823 - val_loss: 2.1870 - val_accuracy: 0.9441
# Epoch 14/100
# 675/675 [==============================] - ETA: 0s - loss: 1.9318 - accuracy: 0.9927
# Epoch 00014: val_accuracy did not improve from 0.97667
# 675/675 [==============================] - 113s 167ms/step - loss: 1.9318 - accuracy: 0.9927 - val_loss: 2.0110 - val_accuracy: 0.9733
# Epoch 15/100
# 675/675 [==============================] - ETA: 0s - loss: 1.9919 - accuracy: 0.9873
# Epoch 00015: val_accuracy did not improve from 0.97667
# 675/675 [==============================] - 111s 164ms/step - loss: 1.9919 - accuracy: 0.9873 - val_loss: 2.5769 - val_accuracy: 0.8926
# Epoch 16/100
# 675/675 [==============================] - ETA: 0s - loss: 1.9751 - accuracy: 0.9855
# Epoch 00016: val_accuracy did not improve from 0.97667
# 675/675 [==============================] - 109s 162ms/step - loss: 1.9751 - accuracy: 0.9855 - val_loss: 1.9605 - val_accuracy: 0.9737
# Epoch 17/100
# 675/675 [==============================] - ETA: 0s - loss: 1.8802 - accuracy: 0.9957
# Epoch 00017: val_accuracy improved from 0.97667 to 0.97926, saving model to results/eurosat\cnn.weights.best.hdf5
# 675/675 [==============================] - 111s 165ms/step - loss: 1.8802 - accuracy: 0.9957 - val_loss: 1.9299 - val_accuracy: 0.9793
# Epoch 18/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0338 - accuracy: 0.9893
# Epoch 00018: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 110s 163ms/step - loss: 2.0338 - accuracy: 0.9893 - val_loss: 2.8908 - val_accuracy: 0.9311
# Epoch 19/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0755 - accuracy: 0.9833
# Epoch 00019: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 111s 164ms/step - loss: 2.0755 - accuracy: 0.9833 - val_loss: 2.1496 - val_accuracy: 0.9596
# Epoch 20/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0370 - accuracy: 0.9893
# Epoch 00020: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 110s 163ms/step - loss: 2.0370 - accuracy: 0.9893 - val_loss: 1.9756 - val_accuracy: 0.9737
# Epoch 21/100
# 675/675 [==============================] - ETA: 0s - loss: 1.9935 - accuracy: 0.9904
# Epoch 00021: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 108s 159ms/step - loss: 1.9935 - accuracy: 0.9904 - val_loss: 2.0660 - val_accuracy: 0.9619
# Epoch 22/100
# 675/675 [==============================] - ETA: 0s - loss: 1.9786 - accuracy: 0.9937
# Epoch 00022: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 112s 166ms/step - loss: 1.9786 - accuracy: 0.9937 - val_loss: 2.3786 - val_accuracy: 0.9241
# Epoch 23/100
# 675/675 [==============================] - ETA: 0s - loss: 2.1229 - accuracy: 0.9831
# Epoch 00023: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 108s 160ms/step - loss: 2.1229 - accuracy: 0.9831 - val_loss: 2.7553 - val_accuracy: 0.9407
# Epoch 24/100
# 675/675 [==============================] - ETA: 0s - loss: 2.1065 - accuracy: 0.9843
# Epoch 00024: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 113s 167ms/step - loss: 2.1065 - accuracy: 0.9843 - val_loss: 2.1221 - val_accuracy: 0.9726
# Epoch 25/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0514 - accuracy: 0.9886
# Epoch 00025: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 115s 170ms/step - loss: 2.0514 - accuracy: 0.9886 - val_loss: 2.3570 - val_accuracy: 0.9515
# Epoch 26/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0333 - accuracy: 0.9929
# Epoch 00026: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 110s 163ms/step - loss: 2.0333 - accuracy: 0.9929 - val_loss: 2.1504 - val_accuracy: 0.9630
# Epoch 27/100
# 675/675 [==============================] - ETA: 0s - loss: 2.0480 - accuracy: 0.9897
# Epoch 00027: val_accuracy did not improve from 0.97926
# 675/675 [==============================] - 107s 159ms/step - loss: 2.0480 - accuracy: 0.9897 - val_loss: 2.0171 - val_accuracy: 0.9737

# %%
# Plot Learning Curves
def plot_learning_curves(df):
    fig, axes = plt.subplots(ncols=2, figsize=(15, 4))
    df[['accuracy', 'val_accuracy']].plot(ax=axes[0], title='Accuracy')
    df[['loss', 'val_loss']].plot(ax=axes[1], title='Cross-Entropy')
    for ax in axes:
        ax.legend(['Training', 'Validation'])
    fig.tight_layout()

metrics = pd.DataFrame(history.history)
metrics.index = metrics.index.to_series().add(1)

fig, axes = plt.subplots(ncols=2, figsize=(15, 4))
metrics[['accuracy', 'val_accuracy']].plot(ax=axes[0],
                                           title=f'Accuracy (Best: {metrics.val_accuracy.max():.2%})')
axes[0].axvline(metrics.val_accuracy.idxmax(), ls='--', lw=1, c='k')
metrics[['loss', 'val_loss']].plot(ax=axes[1], title='Cross-Entropy', logy=True)

for ax in axes:
    ax.legend(['Training', 'Validation'])
    ax.set_xlabel('Epoch')

axes[0].yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
axes[0].set_ylabel('Accuracy')
axes[1].set_ylabel('Loss')
sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'satellite_accuracy', dpi=300);
