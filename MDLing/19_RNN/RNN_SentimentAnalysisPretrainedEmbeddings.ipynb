# %%
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import tensorflow.keras.backend as K

import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
    # tf.config.experimental.set_virtual_device_configuration(gpu_devices[0],
    # [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024*6)])
else:
    print('Using CPU')

sns.set_style('whitegrid')
np.random.seed(42)

results_path = Path('results', 'sentiment_imdb')
if not results_path.exists():
    results_path.mkdir(parents=True)
# Out:
# Using GPU

# %%
# Load Reviews
path = Path('data', 'aclImdb')
files = path.glob('**/*.txt')
len(list(files))
# Out:
# 100006

# %%
files = path.glob('*/**/*.txt')
outcomes = set()
data = []
for f in files:
    if f.stem.startswith(('urls_', 'imdbEr')):
        continue
    _, _, data_set, outcome = f.parent.as_posix().split('/')
    if outcome == 'unsup':
        continue
    data.append([data_set, int(outcome == 'pos'), f.read_text(encoding='latin1')])

data = pd.DataFrame(data, columns=['dataset', 'label', 'review'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  0 non-null      object
#  1   label    0 non-null      object
#  2   review   0 non-null      object
# dtypes: object(3)
# memory usage: 0.0+ bytes

# %%
train_data = data.loc[data.dataset=='train', ['label', 'review']]
test_data = data.loc[data.dataset=='test', ['label', 'review']]
train_data.label.value_counts()
# Out:
# 0    12500
# 1    12500
# Name: label, dtype: int64

# %%
train_data.review.sample(5)
# Out:
# 32455    Curiously, Season 6 of the Columbo series cont...
# 34069    Believe it or not, "The Woodchipper Massacre" ...
# 46322    This movie is a lot of fun. What makes it grea...
# 44454    As the first of the TV specials offered on the...
# 36803    This documentary is at its best when it is sim...
# Name: review, dtype: object

# %%
test_data.label.value_counts()
# Out:
# 0    12500
# 1    12500
# Name: label, dtype: int64

# %%
# Tokenizer
num_words = 10000
t = Tokenizer(num_words=num_words, lower=True, oov_token=2)
t.fit_on_texts(train_data.review)
vocab_size = len(t.word_index) + 1
vocab_size
# Out:
# 88586

# %%
print(t.word_docs)
# Out:
# defaultdict(<class 'int'>, {'with': 17466, 'singers': 62, 'might': 2423, 'just': 10549, 'from': 11715, 'those': 3771, 'putting': 357, 'seem': 1921, 'to': 23475, 'third': 664, 'has': 10065, 'zsigmond': 4, 'even': 8418, 'of': 23726, 'story': 7584, 'level': 870, 'cryptic': 18, 'opening': 891, 'be': 14139, 'it': 21332, 'into': 6424, 'orchestra': 40, 'formal': 24, 'stays': 175, 'who': 11133, 'out': 10612, 'should': 4037, 'narrative': 355, 'an': 12208, 'forrest': 37, 'mob': 131, 'and': 24164, 'absurd': 280, 'stars': 1463, 'man': 3790, 'grader': 24, 'briefly': 133, 'make': 6128, 'feelings': 354, "it's": 9225, 'you': 12888, 'audience': 1766, 'crazy': 572, 'think': 5441, 'too': 5722, 'that': 20041, 'a': 24174, 'future': 757, 'comedy': 2339, 'era': 530, 'violent': 460, 'than': 7121, 'kirkland': 5, 'chantings': 1, 'pig': 78, 'better': 4625, 'dialogue': 1335, 'on': 15710, 'no': 8202, 'the': 24793, 'for': 17882, 'unnatural': 42, 'would': 8043, 'starts': 1073, 'eventually': 663, 'general': 656, 'is': 22427, 'by': 11721, 'shakespeare': 148, 'time': 8720, 'seen': 5328, 'can': 7856, 'terrific': 392, 'insane': 204, 'great': 6305, 'whole': 2641, 'good': 9616, 'making': 2550, 'turned': 868, 'unfortunately': 1242, 'example': 1222, 'technical': 273, 'some': 9645, 'easy': 734, 'cinematography': 938, 'vilmos': 4, 'scene': 3813, 'frederic': 12, 'sally': 94, 'off': 4638, 'fast': 807, 'lee': 475, 'plenty': 567, 'sleeping': 168, 'daughter': 811, 'hits': 264, 'pace': 522, 'properly': 160, 'flashbacks': 216, 'plane': 222, 'sequels': 188, "'79": 3, 'rescue': 204, 'another': 3609, 'lacking': 269, 'reasons': 560, 'jack': 570, 'spectacular': 237, 'oil': 107, 'bunch': 728, 'nothing': 3428, 'land': 311, 'entertaining': 1340, 'my': 8114, 'couple': 1475, 'home': 1534, 'actually': 3440, 'when': 9031, 'tension': 478, 'choices': 164, 'other': 6683, 'supply': 59, 'design': 298, 'thriller': 731, 'isolated': 92, 'rich': 515, 'ideas': 514, "shouldn't": 326, "there's": 2345, 'fashions': 42, 'drown': 26, 'followed': 360, 'george': 644, 'help': 1624, 'two': 4961, 'triangle': 64, 'pieces': 385, 'suspense': 641, 'knock': 124, 'also': 6459, 'lemmon': 64, 'smash': 53, 'julie': 141, 'us': 2759, 'james': 792, 'trapped': 175, 'descent': 74, 'orientated': 8, 'michael': 920, 'known': 987, 'makers': 438, 'hall': 181, 'values': 426, 'rather': 2263, 'floods': 6, 'flick': 1063, 'co': 533, 'but': 17979, 'minutes': 2398, 'bit': 2565, 'lack': 953, 'his': 10678, 'was': 16164, 'so': 11714, 'problems': 769, 'idea': 1760, 'ocean': 73, 'lots': 699, 'cargo': 21, 'run': 1090, 'once': 2081, 'one': 14100, 'if': 10688, 'pataki': 7, 'action': 2301, 'scenes': 3914, 'old': 3464, 'though': 3591, 'place': 2070, "award's": 2, 'planned': 96, 'favourite': 283, 'estate': 107, 'expected': 664, 'second': 1709, "survivor's": 2, 'become': 1370, 'said': 1925, 'urgency': 36, 'submerged': 10, 'in': 22039, 'classic': 1544, 'worse': 1271, 'crew': 472, 'jinxed': 2, 'are': 13900, 'kennedy': 77, 'made': 6365, 'navigator': 2, 'excitement': 207, 'quinlan': 2, 'while': 4096, 'video': 1370, 'almost': 2658, 'or': 10338, 'drunk': 260, 'familiar': 511, 'pilot': 214, 'banker': 15, 'mistake': 394, 'he': 9900, 'new': 3219, 'stark': 75, 'steal': 226, 'sort': 1274, 'credits': 622, 'pretty': 2911, 'frail': 25, 'they': 10367, 'discovery': 109, 'concorde': 7, 'ships': 69, 'helicopters': 24, 'only': 8362, 'jerry': 227, 'pride': 124, 'been': 6653, 'do': 6645, 'huge': 862, 'jacking': 3, 'theatrical': 208, 'winner': 193, 'dull': 706, 'jetliner': 1, 'flying': 285, 'mount': 20, 'have': 14185, 'middle': 886, '108': 6, 'oscar': 665, 'businessman': 76, 'cross': 303, 'decent': 1028, 'leaking': 4, 'along': 1616, '200': 56, 'many': 5067, 'jacked': 7, 'boring': 1506, 'badly': 592, 'facing': 88, 'toy': 142, 'right': 2772, 'versions': 226, "isn't": 2588, 'opportunity': 369, '1972': 81, 'about': 10491, 'loaded': 82, 'see': 8083, 'grant': 172, 'joe': 392, 'sequel': 627, 'them': 5596, 'bodies': 197, 'here': 4202, 'most': 6509, "didn't": 3433, 'dead': 1 ...

# %%
train_data_encoded = t.texts_to_sequences(train_data.review)
test_data_encoded = t.texts_to_sequences(test_data.review)
max_length = 100

# %%
# Pad Sequences
X_train_padded = pad_sequences(train_data_encoded, maxlen=max_length, padding='post', truncating='post')
y_train = train_data['label']
X_train_padded.shape
# Out:
# (25000, 100)

# %%
X_train_padded[:5]
# Out:
# array([[  63,    5,    4,  130,   35,   45, 7577, 1415,   16,    4, 4253,
#          515,   44,   17,    4,  634,  134,   13,    7,    4, 1302,  460,
#            5, 1752,  210,    4,    1, 7694,  309,    7,  677,   81,   33,
#         2138, 1111, 3009,   32,    2,  930,    1,    5,   43, 5121,  470,
#           10, 2666, 1752,    2,  224,   56,   17,   55,  829, 1319,  848,
#          229,   10,   41,   97,  123, 1485,   58,  146,   37,    2,  997,
#          142,   28,  677,  123,    2,    1,  412,   60,   95, 2279,  304,
#          773,    6,    4,  838,    1,   21,    4, 1756,  647,   43,  126,
#           72,   23,  236,  102,   17,   47,   50,  625,   32,  703,   85,
#            1],
#        [4518,    1,  515,   15,    4, 3418,  160, 8596,    1, 1703,    7,
#         4893,   54,   17, 4519, 5675,  139,    1,    6, 1024, 4989, 3051,
#         4520,  589, 1340,   35,    7, 1545,   96,    4,  759,    5,    1,
#            6,   25, 3514,    9,    1,    5,   10,  110, 3052,    6,    2,
#         1068,   15,    4, 4521,   80,   21, 2087,    7, 4520,  575, 2799,
#         7263,    1,   39,  490,    2, 8596,    1,  302,  123,   15, 4254,
#           19, 1694,  943,    2, 1703,    7, 6539,    1,   32,    2,  999,
#         1808,    1,  668,    1,   25,  105,    1,    1,    1,    1, 2603,
#          486,    1,   35, 3286,    2, 6540, 1049,   44,   17, 2754, 2548,
#           34],
#        [  12,   20, 3658,  140,   11,  424,  274,   59, 4382,   21,   31,
#           84, 3310,   21,    2,  171,    5,    2,  969,  521,   12, 4990,
#         5400,    6,  581,    5, 1172,   52,   57, 5341,    2,  266,   17,
#           39,  969,  130,   58,    2,  727,  137,  383,  636,   15,  110,
#         1526,    2,  154,   31,  295,   10,   98,   53,   71,   26,   75,
#            2,  165,   35,    1,   49,   27,  885,   37,    2,  154,   11,
#           41,   90,  122,    8,    8,   19,   98,   10,   26,   75,    2,
#          878,   41,  615,   35,   14,    2, 9655,    9,  117,   17,   27,
#          466,   51,    1,    5,   25,    1, 1952,    3, 3735,    3, 1114,
#            5],
#        [ 804,  314,   11,  122,   12,    7,  422,    6,   28,   33,  496,
#           20,   19, 1315,   34,  142,   26, 2667,   44, 1862,   31,    2,
#         2814,   36,   82,   98, 2472,   66, 4078,   44,    3,   22,  104,
#          259,    2,  134, 1589,    3,    1,  456,   14,  319,   12,   63,
#            7,   97, 1348,    6,  104,    2, 3816,    5,    4,  479, 1403,
#           14, 1764,    2,    1,  660,   69,   97,  194,   87,  194,   68,
#           23,  104,  105,   82,   41, 1261,   48,    3,  661,  260,   52,
#            2,  412,    7,  105,   82, 5285,   11,   64,   67,    4,  252,
#           56,   41,  395,  141,   12,   20,    2,  352,   69,  319,   19,
#           87],
#        [  52,   11,   14,  115,   59,  844,  560,   70,  365,    6,    2,
#          749,    6,   65, 8171,   10,   14,   29,    5,  109,  100,   11,
#          294,   17,   59,  844,   19,   12,   14,    2,   62,   29,   73,
#         2526,   44,    5,  235,   93,   11,   67,  113,  108, 8171,  364,
#           41, 1030,    3,   11,   98,   26, 1449,   44,    2,  358,    5,
#           59,  111,  207,   10,   49,    4, 1944,    1,    3, 2143,  355,
#          416,    5, 1695, 6794,    3, 3037, 5172, 2290, 1599,    7,   29,
#            5,   59,  512,  905,   19, 8171,    7,   32,  228,    2,  247,
#          416,    5,  593,    5,   25,  609,    9,    2,    1,  403,    5,
#            1]])

# %%
X_test_padded = pad_sequences(test_data_encoded, maxlen=max_length, padding='post', truncating='post')
y_test = test_data['label']
X_test_padded.shape
# Out:
# (25000, 100)

# %%
# load the pretrained GloVe embeddings into memory
glove_path = Path('data', 'glove', 'glove.6B.100d.txt')
embeddings_index = dict()

for line in glove_path.open(encoding='latin1'):
    values = line.split()
    word = values[0]
    try:
        coefs = np.asarray(values[1:], dtype='float32')
    except:
        continue
    embeddings_index[word] = coefs
print(f'Loaded {len(embeddings_index):,d} word vectors.')
# Out:
# Loaded 399,883 word vectors.

# %%
t.word_index
# Out:
# {2: 1,
#  'the': 2,
#  'and': 3,
#  'a': 4,
#  'of': 5,
#  'to': 6,
#  'is': 7,
#  'br': 8,
#  'in': 9,
#  'it': 10,
#  'i': 11,
#  'this': 12,
#  'that': 13,
#  'was': 14,
#  'as': 15,
#  'for': 16,
#  'with': 17,
#  'movie': 18,
#  'but': 19,
#  'film': 20,
#  'on': 21,
#  'not': 22,
#  'you': 23,
#  'are': 24,
#  'his': 25,
#  'have': 26,
#  'he': 27,
#  'be': 28,
#  'one': 29,
#  'all': 30,
#  'at': 31,
#  'by': 32,
#  'an': 33,
#  'they': 34,
#  'who': 35,
#  'so': 36,
#  'from': 37,
#  'like': 38,
#  'her': 39,
#  'or': 40,
#  'just': 41,
#  'about': 42,
#  "it's": 43,
#  'out': 44,
#  'has': 45,
#  'if': 46,
#  'some': 47,
#  'there': 48,
#  'what': 49,
#  'good': 50,
#  'more': 51,
#  'when': 52,
#  'very': 53,
#  'up': 54,
#  'no': 55,
#  'time': 56,
#  'she': 57,
#  'even': 58,
#  'my': 59,
#  'would': 60,
#  'which': 61,
#  'only': 62,
#  'story': 63,
#  'really': 64,
#  'see': 65,
#  'their': 66,
#  'had': 67,
#  'can': 68,
#  'were': 69,
#  'me': 70,
#  'well': 71,
#  'than': 72,
#  'we': 73,
#  'much': 74,
#  'been': 75,
#  'bad': 76,
#  'get': 77,
#  'will': 78,
#  'do': 79,
#  'also': 80,
#  'into': 81,
#  'people': 82,
#  'other': 83,
#  'first': 84,
#  'great': 85,
#  'because': 86,
#  'how': 87,
#  'him': 88,
#  'most': 89,
#  "don't": 90,
#  'made': 91,
#  'its': 92,
#  'then': 93,
#  'way': 94,
#  'make': 95,
#  'them': 96,
#  'too': 97,
#  'could': 98,
#  'any': 99,
#  'movies': 100,
#  'after': 101,
#  'think': 102,
#  'characters': 103,
#  'watch': 104,
#  'two': 105,
#  'films': 106,
#  'character': 107,
#  'seen': 108,
#  'many': 109,
#  'being': 110,
#  'life': 111,
#  'plot': 112,
#  'never': 113,
#  'acting': 114,
#  'little': 115,
#  'best': 116,
#  'love': 117,
#  'over': 118,
#  'where': 119,
#  'did': 120,
#  'show': 121,
#  'know': 122,
#  'off': 123,
#  'ever': 124,
#  'does': 125,
#  'better': 126,
#  'your': 127,
#  'end': 128,
#  'still': 129,
#  'man': 130,
#  'here': 131,
#  'these': 132,
#  'say': 133,
#  'scene': 134,
#  'while': 135,
#  'why': 136,
#  'scenes': 137,
#  'go': 138,
#  'such': 139,
#  'something': 140,
#  'through': 141,
#  'should': 142,
#  'back': 143,
#  "i'm": 144,
#  'real': 145,
#  'those': 146,
#  'watching': 147,
#  'now': 148,
#  'though': 149,
#  "doesn't": 150,
#  'years': 151,
#  'old': 152,
#  'thing': 153,
#  'actors': 154,
#  'work': 155,
#  '10': 156,
#  'before': 157,
#  'another': 158,
#  "didn't": 159,
#  'new': 160,
#  'funny': 161,
#  'nothing': 162,
#  'actually': 163,
#  'makes': 164,
#  'director': 165,
#  'look': 166,
#  'find': 167,
#  'going': 168,
#  'few': 169,
#  'same': 170,
#  'part': 171,
#  'again': 172,
#  'every': 173,
#  'lot': 174,
#  'cast': 175,
#  'us': 176,
#  'quite': 177,
#  'down': 178,
#  'want': 179,
#  'world': 180,
#  'things': 181,
#  'pretty': 182,
#  'young': 183,
#  'seems': 184,
#  'around': 185,
#  'got': 186,
#  'horror': 187,
#  'however': 188,
#  "can't": 189,
#  'fact': 190,
#  'take': 191,
#  'big': 192,
#  'enough': 193,
#  'long': 194,
#  'thought': 195,
#  "that's": 196,
#  'both': 197,
#  'between': 198,
#  'series': 199,
#  'give': 200,
#  'may': 201,
#  'original': 202,
#  'action': 203,
#  'own': 204,
#  "i've": 205,
#  'right': 206,
#  'without': 207,
#  'always': 208,
#  'times': 209,
#  'comedy': 210,
#  'point': 211,
#  'gets': 212,
#  'must': 213,
#  'come': 214,
#  'role': 215,
#  "isn't": 216,
#  'saw': 217,
#  'almost': 218,
#  'interesting': 219,
#  'least': 220,
#  'family': 221,
#  'done': 222,
#  "there's": 223,
#  'whole': 224,
#  'bit': 225,
#  'music': 226,
#  'script': 227,
#  'far': 228,
#  'making': 229,
#  'anything': 230,
#  'guy': 231,
#  'minutes': 232,
#  'feel': 233,
#  'last': 234,
#  'since': 235,
#  'might': 236,
#  'performance': 237,
#  "he's": 238,
#  '2': 239,
#  'probably': 240,
#  'kind': 241,
#  'am': 242,
#  'away': 243,
#  'yet': 244,
#  'rather': 245,
#  'tv': 246,
#  'worst': 247,
#  'girl': 248,
#  'day': 249,
#  'sure': 250,
#  'fun': 251,
#  'hard': 252,
#  'woman': 253,
#  'played': 254,
#  'each': 255,
#  'found': 256,
#  'anyone': 257,
#  'having': 258,
#  'although': 259,
#  'especially': 260,
#  'our': 261,
#  'course': 262,
#  'believe': 263,
#  'comes': 264,
#  'looking': 265,
#  'screen': 266,
#  'trying': 267,
#  'set': 268,
#  'goes': 269,
#  'looks': 270,
#  'place': 271,
#  'book': 272,
#  'different': 273,
#  'put': 274,
#  'ending': 275,
#  'money': 276,
#  'maybe': 277,
#  'once': 278,
#  'sense': 279,
#  'reason': 280,
#  'true': 281,
#  'actor': 282,
#  'everything': 283,
#  "wasn't": 284,
#  'shows': 285,
#  'dvd': 286,
#  'three': 287,
#  'worth': 288,
#  'year': 289,
#  'job': 290,
#  'main': 291,
#  'someone': 292,
#  'together': 293,
#  'watched': 294,
#  'play': 295,
#  'plays': 296,
#  'american': 297,
#  '1': 298,
#  'said': 299,
#  'effects': 300,
#  'later': 301,
#  'takes': 302,
#  'instead': 303,
#  'seem': 304,
#  'beautiful': 305,
#  'john': 306,
#  'himself': 307,
#  'version': 308,
#  'audience': 309,
#  'high': 310,
#  'house': 311,
#  'night': 312,
#  'during': 313,
#  'everyone': 314,
#  'left': 315,
#  'special': 316,
#  'seeing': 317,
#  'half': 318,
#  'excellent': 319,
#  'wife': 320,
#  'star': 321,
#  'shot': 322,
#  'war': 323,
#  'idea': 324,
#  'nice': 325,
#  'black': 326,
#  'less': 327,
#  'mind': 328,
#  'simply': 329,
#  'read': 330,
#  'second': 331,
#  'else': 332,
#  "you're": 333,
#  'father': 334,
#  'fan': 335,
#  'help': 336,
#  'poor': 337,
#  'completely': 338,
#  'death': 339,
#  '3': 340,
#  'used': 341,
#  'home': 342,
#  'either': 343,
#  'short': 344,
#  'line': 345,
#  'given': 346,
#  'men': 347,
#  'top': 348,
#  'dead': 349,
#  'budget': 350,
#  'try': 351,
#  'performances': 352,
#  'wrong': 353,
#  'classic': 354,
#  'boring': 355,
#  'enjoy': 356,
#  'need': 357,
#  'rest': 358,
#  'use': 359,
#  'hollywood': 360,
#  'kids': 361,
#  'low': 362,
#  'production': 363,
#  'until': 364,
#  'along': 365,
#  'full': 366,
#  'friends': 367,
#  'camera': 368,
#  'truly': 369,
#  'women': 370,
#  'awful': 371,
#  'video': 372,
#  'next': 373,
#  'tell': 374,
#  'remember': 375,
#  'couple': 376,
#  'stupid': 377,
#  'start': 378,
#  'stars': 379,
#  'perhaps': 380,
#  'mean': 381,
#  'sex': 382,
#  'came': 383,
#  'recommend': 384,
#  'let': 385,
#  'moments': 386,
#  'wonderful': 387,
#  'episode': 388,
#  'understand': 389,
#  'small': 390,
#  'face': 391,
#  'terrible': 392,
#  'playing': 393,
#  'school': 394,
#  'getting': 395,
#  'written': 396,
#  'often': 397,
#  'doing': 398,
#  'keep': 399,
#  'early': 400,
#  'name': 401,
#  'perfect': 402,
#  'style': 403,
#  'human': 404,
#  'definitely': 405,
#  'gives': 406,
#  'others': 407,
#  'itself': 408,
#  'lines': 409,
#  'live': 410,
#  'become': 411,
#  'dialogue': 412,
#  'person': 413,
#  'lost': 414,
#  'finally': 415,
#  'piece': 416,
#  'head': 417,
#  'felt': 418,
#  'case': 419,
#  'yes': 420,
#  'liked': 421,
#  'supposed': 422,
#  'title': 423,
#  "couldn't": 424,
#  'absolutely': 425,
#  'white': 426,
#  'against': 427,
#  'boy': 428,
#  'picture': 429,
#  'sort': 430,
#  'worse': 431,
#  'certainly': 432,
#  'went': 433,
#  'entire': 434,
#  'waste': 435,
#  'cinema': 436,
#  'problem': 437,
#  'hope': 438,
#  'entertaining': 439,
#  "she's": 440,
#  'mr': 441,
#  'overall': 442,
#  'evil': 443,
#  'called': 444,
#  'loved': 445,
#  'based': 446,
#  'oh': 447,
#  'several': 448,
#  'fans': 449,
#  'mother': 450,
#  'drama': 451,
#  'beginning': 452,
#  'killer': 453,
#  'lives': 454,
#  '5': 455,
#  'direction': 456,
#  'care': 457,
#  'becomes': 458,
#  'already': 459,
#  'example': 460,
#  'laugh': 461,
#  'friend': 462,
#  'dark': 463,
#  'under': 464,
#  'despite': 465,
#  'seemed': 466,
#  'throughout': 467,
#  '4': 468,
#  'turn': 469,
#  'unfortunately': 470,
#  'wanted': 471,
#  "i'd": 472,
#  'â\x96': 473,
#  'children': 474,
#  'final': 475,
#  'fine': 476,
#  'history': 477,
#  'amazing': 478,
#  'sound': 479,
#  'guess': 480,
#  'heart': 481,
#  'totally': 482,
#  'humor': 483,
#  'lead': 484,
#  'writing': 485,
#  'michael': 486,
#  'quality': 487,
#  "you'll": 488,
#  'close': 489,
#  'son': 490,
#  'guys': 491,
#  'wants': 492,
#  'works': 493,
#  'behind': 494,
#  'tries': 495,
#  'art': 496,
#  'side': 497,
#  'game': 498,
#  'past': 499,
#  'able': 500,
#  'b': 501,
#  'days': 502,
#  'turns': 503,
#  'child': 504,
#  "they're": 505,
#  'hand': 506,
#  'flick': 507,
#  'enjoyed': 508,
#  'act': 509,
#  'genre': 510,
#  'town': 511,
#  'favorite': 512,
#  'soon': 513,
#  'kill': 514,
#  'starts': 515,
#  'sometimes': 516,
#  'car': 517,
#  'gave': 518,
#  'run': 519,
#  'late': 520,
#  'actress': 521,
#  'etc': 522,
#  'eyes': 523,
#  'directed': 524,
#  'horrible': 525,
#  "won't": 526,
#  'brilliant': 527,
#  'viewer': 528,
#  'parts': 529,
#  'themselves': 530,
#  'self': 531,
#  'hour': 532,
#  'expect': 533,
#  'thinking': 534,
#  'stories': 535,
#  'stuff': 536,
#  'girls': 537,
#  'obviously': 538,
#  'blood': 539,
#  'decent': 540,
#  'city': 541,
#  'voice': 542,
#  'highly': 543,
#  'myself': 544,
#  'feeling': 545,
#  'fight': 546,
#  'except': 547,
#  'slow': 548,
#  'matter': 549,
#  'type': 550,
#  'kid': 551,
#  'anyway': 552,
#  'roles': 553,
#  'heard': 554,
#  'killed': 555,
#  'says': 556,
#  'god': 557,
#  'age': 558,
#  'moment': 559,
#  'took': 560,
#  'leave': 561,
#  'writer': 562,
#  'strong': 563,
#  'cannot': 564,
#  'violence': 565,
#  'police': 566,
#  'hit': 567,
#  'happens': 568,
#  'stop': 569,
#  'particularly': 570,
#  'known': 571,
#  'involved': 572,
#  'happened': 573,
#  'extremely': 574,
#  'daughter': 575,
#  'obvious': 576,
#  'told': 577,
#  'chance': 578,
#  'living': 579,
#  'coming': 580,
#  'lack': 581,
#  'experience': 582,
#  'alone': 583,
#  'including': 584,
#  "wouldn't": 585,
#  'murder': 586,
#  'attempt': 587,
#  's': 588,
#  'james': 589,
#  'please': 590,
#  'happen': 591,
#  'wonder': 592,
#  'crap': 593,
#  'brother': 594,
#  'ago': 595,
#  "film's": 596,
#  'gore': 597,
#  'complete': 598,
#  'none': 599,
#  'interest': 600,
#  'score': 601,
#  'group': 602,
#  'cut': 603,
#  'simple': 604,
#  'save': 605,
#  'looked': 606,
#  'ok': 607,
#  'hell': 608,
#  'career': 609,
#  'number': 610,
#  'song': 611,
#  'possible': 612,
#  'seriously': 613,
#  'annoying': 614,
#  'exactly': 615,
#  'sad': 616,
#  'shown': 617,
#  'running': 618,
#  'serious': 619,
#  'musical': 620,
#  'yourself': 621,
#  'taken': 622,
#  'whose': 623,
#  'released': 624,
#  'cinematography': 625,
#  'david': 626,
#  'scary': 627,
#  'ends': 628,
#  'english': 629,
#  'hero': 630,
#  'usually': 631,
#  'hours': 632,
#  'reality': 633,
#  'opening': 634,
#  "i'll": 635,
#  'across': 636,
#  'light': 637,
#  'jokes': 638,
#  'today': 639,
#  'hilarious': 640,
#  'somewhat': 641,
#  'usual': 642,
#  'body': 643,
#  'ridiculous': 644,
#  'cool': 645,
#  'started': 646,
#  'level': 647,
#  'view': 648,
#  'relationship': 649,
#  'change': 650,
#  'opinion': 651,
#  'happy': 652,
#  'middle': 653,
#  'taking': 654,
#  'wish': 655,
#  'finds': 656,
#  'husband': 657,
#  'order': 658,
#  'saying': 659,
#  'shots': 660,
#  'talking': 661,
#  'ones': 662,
#  'documentary': 663,
#  'huge': 664,
#  'novel': 665,
#  'mostly': 666,
#  'female': 667,
#  'robert': 668,
#  'power': 669,
#  'episodes': 670,
#  'room': 671,
#  'important': 672,
#  'rating': 673,
#  'talent': 674,
#  'five': 675,
#  'major': 676,
#  'turned': 677,
#  'strange': 678,
#  'word': 679,
#  'modern': 680,
#  'call': 681,
#  'apparently': 682,
#  'disappointed': 683,
#  'single': 684,
#  'events': 685,
#  'due': 686,
#  'four': 687,
#  'songs': 688,
#  'basically': 689,
#  'attention': 690,
#  '7': 691,
#  'knows': 692,
#  'clearly': 693,
#  'supporting': 694,
#  'knew': 695,
#  'non': 696,
#  'comic': 697,
#  'television': 698,
#  'british': 699,
#  'fast': 700,
#  'earth': 701,
#  'country': 702,
#  'future': 703,
#  'class': 704,
#  'cheap': 705,
#  'thriller': 706,
#  'silly': 707,
#  '8': 708,
#  'king': 709,
#  'problems': 710,
#  "aren't": 711,
#  'easily': 712,
#  'words': 713,
#  'tells': 714,
#  'jack': 715,
#  'miss': 716,
#  'local': 717,
#  'sequence': 718,
#  'entertainment': 719,
#  'bring': 720,
#  'paul': 721,
#  'beyond': 722,
#  'upon': 723,
#  'whether': 724,
#  'predictable': 725,
#  'moving': 726,
#  'romantic': 727,
#  'straight': 728,
#  'similar': 729,
#  'sets': 730,
#  'review': 731,
#  'oscar': 732,
#  'falls': 733,
#  'mystery': 734,
#  'enjoyable': 735,
#  'appears': 736,
#  'talk': 737,
#  'rock': 738,
#  'needs': 739,
#  'george': 740,
#  'giving': 741,
#  'eye': 742,
#  'richard': 743,
#  'within': 744,
#  'ten': 745,
#  'animation': 746,
#  'message': 747,
#  'near': 748,
#  'theater': 749,
#  'above': 750,
#  'dull': 751,
#  'sequel': 752,
#  'nearly': 753,
#  'theme': 754,
#  'points': 755,
#  'stand': 756,
#  "'": 757,
#  'mention': 758,
#  'bunch': 759,
#  'add': 760,
#  'lady': 761,
#  'herself': 762,
#  'feels': 763,
#  'release': 764,
#  'red': 765,
#  'team': 766,
#  'storyline': 767,
#  'surprised': 768,
#  'ways': 769,
#  'using': 770,
#  'named': 771,
#  "haven't": 772,
#  'easy': 773,
#  'lots': 774,
#  'fantastic': 775,
#  'begins': 776,
#  'actual': 777,
#  'working': 778,
#  'effort': 779,
#  'york': 780,
#  'die': 781,
#  'hate': 782,
#  'french': 783,
#  'tale': 784,
#  'minute': 785,
#  'stay': 786,
#  '9': 787,
#  'clear': 788,
#  'elements': 789,
#  'feature': 790,
#  'among': 791,
#  'follow': 792,
#  'comments': 793,
#  're': 794,
#  'viewers': 795,
#  'avoid': 796,
#  'sister': 797,
#  'typical': 798,
#  'showing': 799,
#  'editing': 800,
#  'tried': 801,
#  "what's": 802,
#  'famous': 803,
#  'sorry': 804,
#  'dialog': 805,
#  'fall': 806,
#  'check': 807,
#  'period': 808,
#  'form': 809,
#  'season': 810,
#  'certain': 811,
#  'filmed': 812,
#  'weak': 813,
#  'soundtrack': 814,
#  'means': 815,
#  'material': 816,
#  'buy': 817,
#  'realistic': 818,
#  'somehow': 819,
#  'figure': 820,
#  'crime': 821,
#  'gone': 822,
#  'doubt': 823,
#  'peter': 824,
#  'tom': 825,
#  'viewing': 826,
#  'kept': 827,
#  't': 828,
#  'general': 829,
#  'leads': 830,
#  'greatest': 831,
#  'space': 832,
#  'lame': 833,
#  'suspense': 834,
#  'dance': 835,
#  'brought': 836,
#  'imagine': 837,
#  'third': 838,
#  'atmosphere': 839,
#  'hear': 840,
#  'particular': 841,
#  'whatever': 842,
#  'sequences': 843,
#  'parents': 844,
#  'lee': 845,
#  'move': 846,
#  'indeed': 847,
#  'eventually': 848,
#  'rent': 849,
#  'learn': 850,
#  'de': 851,
#  'note': 852,
#  'forget': 853,
#  'deal': 854,
#  'reviews': 855,
#  'wait': 856,
#  'average': 857,
#  'japanese': 858,
#  'poorly': 859,
#  'sexual': 860,
#  'okay': 861,
#  'premise': 862,
#  'surprise': 863,
#  'zombie': 864,
#  'believable': 865,
#  'stage': 866,
#  'sit': 867,
#  'possibly': 868,
#  "who's": 869,
#  'decided': 870,
#  'expected': 871,
#  "you've": 872,
#  'subject': 873,
#  'nature': 874,
#  'became': 875,
#  'difficult': 876,
#  'free': 877,
#  'screenplay': 878,
#  'killing': 879,
#  'truth': 880,
#  'romance': 881,
#  'dr': 882,
#  'nor': 883,
#  'reading': 884,
#  'needed': 885,
#  'question': 886,
#  'leaves': 887,
#  'street': 888,
#  '20': 889,
#  'meets': 890,
#  'hot': 891,
#  'unless': 892,
#  'begin': 893,
#  'baby': 894,
#  'credits': 895,
#  'otherwise': 896,
#  'imdb': 897,
#  'superb': 898,
#  'write': 899,
#  'shame': 900,
#  "let's": 901,
#  'situation': 902,
#  'dramatic': 903,
#  'memorable': 904,
#  'directors': 905,
#  'earlier': 906,
#  'badly': 907,
#  'meet': 908,
#  'open': 909,
#  'disney': 910,
#  'dog': 911,
#  'joe': 912,
#  'male': 913,
#  'weird': 914,
#  'forced': 915,
#  'acted': 916,
#  'laughs': 917,
#  'sci': 918,
#  'emotional': 919,
#  'older': 920,
#  'realize': 921,
#  'fi': 922,
#  'dream': 923,
#  'society': 924,
#  'writers': 925,
#  'interested': 926,
#  'footage': 927,
#  'comment': 928,
#  'forward': 929,
#  'crazy': 930,
#  'deep': 931,
#  'whom': 932,
#  'plus': 933,
#  'beauty': 934,
#  'america': 935,
#  'sounds': 936,
#  'fantasy': 937,
#  'directing': 938,
#  'keeps': 939,
#  'development': 940,
#  'ask': 941,
#  'features': 942,
#  'air': 943,
#  'quickly': 944,
#  'mess': 945,
#  'creepy': 946,
#  'towards': 947,
#  'perfectly': 948,
#  'mark': 949,
#  'worked': 950,
#  'box': 951,
#  'cheesy': 952,
#  'unique': 953,
#  'hands': 954,
#  'setting': 955,
#  'plenty': 956,
#  'previous': 957,
#  'brings': 958,
#  'result': 959,
#  'total': 960,
#  'e': 961,
#  'effect': 962,
#  'incredibly': 963,
#  'personal': 964,
#  'monster': 965,
#  'rate': 966,
#  'fire': 967,
#  'business': 968,
#  'leading': 969,
#  'apart': 970,
#  'casting': 971,
#  'admit': 972,
#  'background': 973,
#  'powerful': 974,
#  'appear': 975,
#  'joke': 976,
#  'girlfriend': 977,
#  'telling': 978,
#  'meant': 979,
#  'hardly': 980,
#  'present': 981,
#  'christmas': 982,
#  'battle': 983,
#  'potential': 984,
#  'create': 985,
#  'break': 986,
#  'bill': 987,
#  'pay': 988,
#  'masterpiece': 989,
#  'gay': 990,
#  'return': 991,
#  'political': 992,
#  'dumb': 993,
#  'fails': 994,
#  'fighting': 995,
#  'various': 996,
#  'era': 997,
#  'portrayed': 998,
#  'co': 999,
#  'cop': 1000,
#  ...}

# %%
embedding_matrix = np.zeros((vocab_size, 100))
for word, i in t.word_index.items():
    embedding_vector = embeddings_index.get(word) # creating embedding matrix by GloVe(pretrained word vectors)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
embedding_matrix.shape
# Out:
# (88586, 100)

# %%
# Define Model Architecture
embedding_size = 100
rnn = Sequential([
    Embedding(input_dim=vocab_size, output_dim= embedding_size, input_length=max_length,
              weights=[embedding_matrix], trainable=False),
    GRU(units=32,  dropout=0.2, recurrent_dropout=0.2),
    Dense(1, activation='sigmoid')
])
rnn.summary()
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 100)          8858600
#
#  gru (GRU)                   (None, 32)                12864
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 8,871,497
# Trainable params: 12,897
# Non-trainable params: 8,858,600
# _________________________________________________________________
# 587/782 [=====================>........] - ETA: 1:07 - loss: 0.6430 - accuracy: 0.6123 - AUC: 0.6678

# %%
rnn.compile(loss='binary_crossentropy', optimizer='RMSProp',
            metrics=['accuracy', tf.keras.metrics.AUC(name='AUC')])
rnn_path = (results_path / 'lstm.pretrained.h5').as_posix()

checkpointer = ModelCheckpoint(filepath=rnn_path, verbose=1, monitor='val_AUC', mode='max',
                               save_best_only=True)
early_stopping = EarlyStopping(monitor='val_AUC', patience=5, mode='max', restore_best_weights=True)
training = rnn.fit(X_train_padded, y_train, batch_size=32, epochs=100,
                   validation_data=(X_test_padded, y_test), callbacks=[early_stopping, checkpointer],
                   verbose=1, workers=6)
# Out:
# Epoch 1/100
# 782/782 [==============================] - ETA: 0s - loss: 0.6143 - accuracy: 0.6452 - AUC: 0.7136
# Epoch 00001: val_AUC improved from -inf to 0.83855, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 314s 399ms/step - loss: 0.6143 - accuracy: 0.6452 - AUC: 0.7136 - val_loss: 0.5074 - val_accuracy: 0.7547 - val_AUC: 0.8385
# Epoch 2/100
# 782/782 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.7690 - AUC: 0.8472
# Epoch 00002: val_AUC improved from 0.83855 to 0.87378, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 298s 381ms/step - loss: 0.4850 - accuracy: 0.7690 - AUC: 0.8472 - val_loss: 0.4862 - val_accuracy: 0.7567 - val_AUC: 0.8738
# Epoch 3/100
# 782/782 [==============================] - ETA: 0s - loss: 0.4492 - accuracy: 0.7881 - AUC: 0.8708
# Epoch 00003: val_AUC improved from 0.87378 to 0.88782, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 295s 377ms/step - loss: 0.4492 - accuracy: 0.7881 - AUC: 0.8708 - val_loss: 0.4255 - val_accuracy: 0.8013 - val_AUC: 0.8878
# Epoch 4/100
# 782/782 [==============================] - ETA: 0s - loss: 0.4293 - accuracy: 0.8013 - AUC: 0.8829
# Epoch 00004: val_AUC improved from 0.88782 to 0.89395, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 296s 378ms/step - loss: 0.4293 - accuracy: 0.8013 - AUC: 0.8829 - val_loss: 0.4104 - val_accuracy: 0.8074 - val_AUC: 0.8939
# Epoch 5/100
# 782/782 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.8082 - AUC: 0.8912
# Epoch 00005: val_AUC improved from 0.89395 to 0.89783, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 299s 383ms/step - loss: 0.4148 - accuracy: 0.8082 - AUC: 0.8912 - val_loss: 0.4251 - val_accuracy: 0.8008 - val_AUC: 0.8978
# Epoch 6/100
# 782/782 [==============================] - ETA: 0s - loss: 0.4079 - accuracy: 0.8120 - AUC: 0.8951
# Epoch 00006: val_AUC improved from 0.89783 to 0.89928, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 299s 382ms/step - loss: 0.4079 - accuracy: 0.8120 - AUC: 0.8951 - val_loss: 0.4776 - val_accuracy: 0.7710 - val_AUC: 0.8993
# Epoch 7/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8177 - AUC: 0.9017
# Epoch 00007: val_AUC improved from 0.89928 to 0.90277, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 294s 376ms/step - loss: 0.3957 - accuracy: 0.8177 - AUC: 0.9017 - val_loss: 0.3932 - val_accuracy: 0.8190 - val_AUC: 0.9028
# Epoch 8/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3909 - accuracy: 0.8206 - AUC: 0.9042
# Epoch 00008: val_AUC improved from 0.90277 to 0.90303, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 296s 379ms/step - loss: 0.3909 - accuracy: 0.8206 - AUC: 0.9042 - val_loss: 0.4026 - val_accuracy: 0.8134 - val_AUC: 0.9030
# Epoch 9/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3863 - accuracy: 0.8254 - AUC: 0.9068
# Epoch 00009: val_AUC improved from 0.90303 to 0.90587, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 299s 382ms/step - loss: 0.3863 - accuracy: 0.8254 - AUC: 0.9068 - val_loss: 0.3881 - val_accuracy: 0.8221 - val_AUC: 0.9059
# Epoch 10/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.8270 - AUC: 0.9115
# Epoch 00010: val_AUC improved from 0.90587 to 0.90680, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 298s 382ms/step - loss: 0.3766 - accuracy: 0.8270 - AUC: 0.9115 - val_loss: 0.3868 - val_accuracy: 0.8224 - val_AUC: 0.9068
# Epoch 11/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3708 - accuracy: 0.8343 - AUC: 0.9144
# Epoch 00011: val_AUC improved from 0.90680 to 0.90747, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 295s 378ms/step - loss: 0.3708 - accuracy: 0.8343 - AUC: 0.9144 - val_loss: 0.4022 - val_accuracy: 0.8166 - val_AUC: 0.9075
# Epoch 12/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3669 - accuracy: 0.8356 - AUC: 0.9162
# Epoch 00012: val_AUC did not improve from 0.90747
# 782/782 [==============================] - 293s 375ms/step - loss: 0.3669 - accuracy: 0.8356 - AUC: 0.9162 - val_loss: 0.3909 - val_accuracy: 0.8238 - val_AUC: 0.9069
# Epoch 13/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3640 - accuracy: 0.8366 - AUC: 0.9178
# Epoch 00013: val_AUC improved from 0.90747 to 0.90875, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 294s 375ms/step - loss: 0.3640 - accuracy: 0.8366 - AUC: 0.9178 - val_loss: 0.3856 - val_accuracy: 0.8246 - val_AUC: 0.9088
# Epoch 14/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3570 - accuracy: 0.8393 - AUC: 0.9208
# Epoch 00014: val_AUC did not improve from 0.90875
# 782/782 [==============================] - 299s 382ms/step - loss: 0.3570 - accuracy: 0.8393 - AUC: 0.9208 - val_loss: 0.3841 - val_accuracy: 0.8250 - val_AUC: 0.9082
# Epoch 15/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3524 - accuracy: 0.8417 - AUC: 0.9232
# Epoch 00015: val_AUC did not improve from 0.90875
# 782/782 [==============================] - 292s 373ms/step - loss: 0.3524 - accuracy: 0.8417 - AUC: 0.9232 - val_loss: 0.3908 - val_accuracy: 0.8230 - val_AUC: 0.9080
# Epoch 16/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3514 - accuracy: 0.8431 - AUC: 0.9236
# Epoch 00016: val_AUC did not improve from 0.90875
# 782/782 [==============================] - 296s 379ms/step - loss: 0.3514 - accuracy: 0.8431 - AUC: 0.9236 - val_loss: 0.3854 - val_accuracy: 0.8221 - val_AUC: 0.9075
# Epoch 17/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.8474 - AUC: 0.9259
# Epoch 00017: val_AUC did not improve from 0.90875
# 782/782 [==============================] - 297s 379ms/step - loss: 0.3462 - accuracy: 0.8474 - AUC: 0.9259 - val_loss: 0.3970 - val_accuracy: 0.8168 - val_AUC: 0.9087
# Epoch 18/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3418 - accuracy: 0.8500 - AUC: 0.9280
# Epoch 00018: val_AUC improved from 0.90875 to 0.91016, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 298s 381ms/step - loss: 0.3418 - accuracy: 0.8500 - AUC: 0.9280 - val_loss: 0.4290 - val_accuracy: 0.8052 - val_AUC: 0.9102
# Epoch 19/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8477 - AUC: 0.9272
# Epoch 00019: val_AUC did not improve from 0.91016
# 782/782 [==============================] - 296s 378ms/step - loss: 0.3433 - accuracy: 0.8477 - AUC: 0.9272 - val_loss: 0.4020 - val_accuracy: 0.8180 - val_AUC: 0.9095
# Epoch 20/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.8498 - AUC: 0.9292
# Epoch 00020: val_AUC did not improve from 0.91016
# 782/782 [==============================] - 295s 378ms/step - loss: 0.3386 - accuracy: 0.8498 - AUC: 0.9292 - val_loss: 0.4083 - val_accuracy: 0.8180 - val_AUC: 0.9098
# Epoch 21/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3343 - accuracy: 0.8531 - AUC: 0.9311
# Epoch 00021: val_AUC did not improve from 0.91016
# 782/782 [==============================] - 292s 373ms/step - loss: 0.3343 - accuracy: 0.8531 - AUC: 0.9311 - val_loss: 0.3933 - val_accuracy: 0.8198 - val_AUC: 0.9097
# Epoch 22/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3313 - accuracy: 0.8511 - AUC: 0.9322
# Epoch 00022: val_AUC did not improve from 0.91016
# 782/782 [==============================] - 298s 381ms/step - loss: 0.3313 - accuracy: 0.8511 - AUC: 0.9322 - val_loss: 0.4133 - val_accuracy: 0.8116 - val_AUC: 0.9089
# Epoch 23/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8522 - AUC: 0.9317
# Epoch 00023: val_AUC improved from 0.91016 to 0.91106, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 297s 380ms/step - loss: 0.3328 - accuracy: 0.8522 - AUC: 0.9317 - val_loss: 0.3858 - val_accuracy: 0.8249 - val_AUC: 0.9111
# Epoch 24/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.8572 - AUC: 0.9339
# Epoch 00024: val_AUC did not improve from 0.91106
# 782/782 [==============================] - 298s 381ms/step - loss: 0.3277 - accuracy: 0.8572 - AUC: 0.9339 - val_loss: 0.4204 - val_accuracy: 0.8056 - val_AUC: 0.9091
# Epoch 25/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3253 - accuracy: 0.8569 - AUC: 0.9349
# Epoch 00025: val_AUC improved from 0.91106 to 0.91141, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 301s 385ms/step - loss: 0.3253 - accuracy: 0.8569 - AUC: 0.9349 - val_loss: 0.3913 - val_accuracy: 0.8259 - val_AUC: 0.9114
# Epoch 26/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3270 - accuracy: 0.8551 - AUC: 0.9341
# Epoch 00026: val_AUC did not improve from 0.91141
# 782/782 [==============================] - 290s 371ms/step - loss: 0.3270 - accuracy: 0.8551 - AUC: 0.9341 - val_loss: 0.3851 - val_accuracy: 0.8268 - val_AUC: 0.9108
# Epoch 27/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.8604 - AUC: 0.9358
# Epoch 00027: val_AUC did not improve from 0.91141
# 782/782 [==============================] - 296s 379ms/step - loss: 0.3232 - accuracy: 0.8604 - AUC: 0.9358 - val_loss: 0.3872 - val_accuracy: 0.8277 - val_AUC: 0.9111
# Epoch 28/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3256 - accuracy: 0.8589 - AUC: 0.9348
# Epoch 00028: val_AUC did not improve from 0.91141
# 782/782 [==============================] - 297s 380ms/step - loss: 0.3256 - accuracy: 0.8589 - AUC: 0.9348 - val_loss: 0.3863 - val_accuracy: 0.8252 - val_AUC: 0.9114
# Epoch 29/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.8597 - AUC: 0.9374
# Epoch 00029: val_AUC improved from 0.91141 to 0.91242, saving model to results/sentiment_imdb\lstm.pretrained.h5
# 782/782 [==============================] - 297s 380ms/step - loss: 0.3190 - accuracy: 0.8597 - AUC: 0.9374 - val_loss: 0.3842 - val_accuracy: 0.8279 - val_AUC: 0.9124
# Epoch 30/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3173 - accuracy: 0.8634 - AUC: 0.9383
# Epoch 00030: val_AUC did not improve from 0.91242
# 782/782 [==============================] - 305s 390ms/step - loss: 0.3173 - accuracy: 0.8634 - AUC: 0.9383 - val_loss: 0.4109 - val_accuracy: 0.8146 - val_AUC: 0.9112
# Epoch 31/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3153 - accuracy: 0.8626 - AUC: 0.9389
# Epoch 00031: val_AUC did not improve from 0.91242
# 782/782 [==============================] - 299s 383ms/step - loss: 0.3153 - accuracy: 0.8626 - AUC: 0.9389 - val_loss: 0.3946 - val_accuracy: 0.8259 - val_AUC: 0.9114
# Epoch 32/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3153 - accuracy: 0.8620 - AUC: 0.9388
# Epoch 00032: val_AUC did not improve from 0.91242
# 782/782 [==============================] - 301s 385ms/step - loss: 0.3153 - accuracy: 0.8620 - AUC: 0.9388 - val_loss: 0.3867 - val_accuracy: 0.8251 - val_AUC: 0.9098
# Epoch 33/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3147 - accuracy: 0.8629 - AUC: 0.9392
# Epoch 00033: val_AUC did not improve from 0.91242
# 782/782 [==============================] - 300s 383ms/step - loss: 0.3147 - accuracy: 0.8629 - AUC: 0.9392 - val_loss: 0.3858 - val_accuracy: 0.8246 - val_AUC: 0.9108
# Epoch 34/100
# 782/782 [==============================] - ETA: 0s - loss: 0.3144 - accuracy: 0.8618 - AUC: 0.9393
# Epoch 00034: val_AUC did not improve from 0.91242
# 782/782 [==============================] - 293s 375ms/step - loss: 0.3144 - accuracy: 0.8618 - AUC: 0.9393 - val_loss: 0.3880 - val_accuracy: 0.8266 - val_AUC: 0.9118

# %%
y_score = rnn.predict(X_test_padded)
roc_auc_score(y_score=y_score.squeeze(), y_true=y_test)
# Out:
# 0.9124665056000001

# %%
df = pd.DataFrame(training.history)
best_auc = df.val_AUC.max()
best_acc = df.val_accuracy.max()

fig, axes = plt.subplots(ncols=2, figsize=(16,8))
df.index = df.index.to_series().add(1)
df[['AUC', 'val_AUC']].plot(ax=axes[0], title=f'AUC | Best: {best_auc:.4f}', legend=False, xlim=(1, 33),
                            ylim=(.7, .95))

axes[0].axvline(df.val_AUC.idxmax(), ls='--', lw=1, c='k')
df[['accuracy', 'val_accuracy']].plot(ax=axes[1], title=f'Accuracy | Best: {best_acc:.2%}', legend=False,
                                              xlim=(1, 33), ylim=(.7, .9))
axes[1].axvline(df.val_accuracy.idxmax(), ls='--', lw=1, c='k')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('AUC')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
fig.suptitle('Sentiment Analysis - Pretrained Vectors', fontsize=14)
fig.legend(['Train', 'Validation'], loc='center right')

sns.despine()
fig.tight_layout()
fig.subplots_adjust(top=.9)
fig.savefig(results_path / 'imdb_pretrained', dpi=300);
# using pretrained word vectors with not trainable MDL(0.9124665056000001) seems not to be the better performance than training own word embeddings MDL(0.9413989215999999)
