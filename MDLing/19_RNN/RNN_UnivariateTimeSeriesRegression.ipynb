# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from scipy.stats import spearmanr

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow import keras

import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
    # tf.config.experimental.set_virtual_device_configuration(gpu_devices[0],
    # [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024*6)])
else:
    print('Using CPU')

sns.set_style('whitegrid')
np.random.seed(42)

results_path = Path('results', 'univariate_time_series')
if not results_path.exists():
    results_path.mkdir(parents=True)
# Out:
# Using GPU

# %%
sp500 = web.DataReader('SP500', 'fred', start='2010', end='2023').dropna()
ax = sp500.plot(title='S&P 500', legend=False, figsize=(16, 8), rot=0)
ax.set_xlabel('')
sns.despine()

# %%
sp500.sample(10).sort_index()
# Out:
#               SP500
# DATE
# 2013-08-12  1689.47
# 2013-12-24  1833.32
# 2016-01-04  2012.66
# 2016-10-10  2163.66
# 2017-07-11  2425.53
# 2019-04-16  2907.06
# 2020-06-01  3055.73
# 2021-04-09  4128.80
# 2021-06-30  4297.50
# 2022-10-11  3588.84

# %%
# Preprocessing
scaler = MinMaxScaler()
sp500_scaled = pd.Series(scaler.fit_transform(sp500).squeeze(), index=sp500.index)
sp500_scaled.describe()
# Out:
# count    2394.000000
# mean        0.373830
# std         0.267597
# min         0.000000
# 25%         0.146282
# 50%         0.327455
# 75%         0.544762
# max         1.000000
# dtype: float64

# %%
# Generating recurrent sequences from our time series
def create_univariate_rnn_data(data, window_size):
    n = len(data)
    y = data[window_size:]
    data = data.values.reshape(-1, 1) # make 2D
    X = np.hstack(tuple([data[i: n-j, :] for i, j in enumerate(range(window_size, 0, -1))]))
    return pd.DataFrame(X, index=y.index), y

window_size = 63 #  for 3 months
X, y = create_univariate_rnn_data(sp500_scaled, window_size=window_size)
X.head()
# Out:
#                   0         1         2         3         4         5   \
# DATE
# 2013-09-30  0.000277  0.000000  0.000418  0.005596  0.008289  0.012016
# 2013-10-01  0.000000  0.000418  0.005596  0.008289  0.012016  0.012110
# 2013-10-02  0.000418  0.005596  0.008289  0.012016  0.012110  0.019149
# 2013-10-03  0.005596  0.008289  0.012016  0.012110  0.019149  0.020773
# 2013-10-04  0.008289  0.012016  0.012110  0.019149  0.020773  0.021499
#
#                   6         7         8         9   ...        53        54  \
# DATE                                                ...
# 2013-09-30  0.012110  0.019149  0.020773  0.021499  ...  0.026244  0.028494
# 2013-10-01  0.019149  0.020773  0.021499  0.019538  ...  0.028494  0.035017
# 2013-10-02  0.020773  0.021499  0.019538  0.020999  ...  0.035017  0.034017
# 2013-10-03  0.021499  0.019538  0.020999  0.023658  ...  0.034017  0.030112
# 2013-10-04  0.019538  0.020999  0.023658  0.024512  ...  0.030112  0.027576
#
#                   55        56        57        58        59        60  \
# DATE
# 2013-09-30  0.035017  0.034017  0.030112  0.027576  0.026187  0.024726
# 2013-10-01  0.034017  0.030112  0.027576  0.026187  0.024726  0.026580
# 2013-10-02  0.030112  0.027576  0.026187  0.024726  0.026580  0.024405
# 2013-10-03  0.027576  0.026187  0.024726  0.026580  0.024405  0.021200
# 2013-10-04  0.026187  0.024726  0.026580  0.024405  0.021200  0.025427
#
#                   61        62
# DATE
# 2013-09-30  0.026580  0.024405
# 2013-10-01  0.024405  0.021200
# 2013-10-02  0.021200  0.025427
# 2013-10-03  0.025427  0.025072
# 2013-10-04  0.025072  0.020292
#
# [5 rows x 63 columns]

# %%
y.head()
# Out:
# DATE
# 2013-09-30    0.021200
# 2013-10-01    0.025427
# 2013-10-02    0.025072
# 2013-10-03    0.020292
# 2013-10-04    0.024013
# dtype: float64

# %%
X.shape
# Out:
# (2331, 63)

# %%
# Train-test split
ax = sp500_scaled.plot(lw=2, figsize=(16, 8), rot=0)
ax.set_xlabel('')
sns.despine()

# %%
# reshape to 3 dimensions for RNN(Features, Batch size, time steps)
X_train = X[:'2021'].values.reshape(-1, window_size, 1)
y_train = y[:'2021']

# keep the last year for testing
X_test = X['2022'].values.reshape(-1, window_size, 1)
y_test = y['2022']
n_obs, window_size, n_features = X_train.shape
y_train.shape
# Out:
# (2080,)

# %%
X_train.shape
# Out:
# (2080, 63, 1)

# %%
# Keras LSTM Layer
rnn = Sequential([
     LSTM(units=10, input_shape=(window_size, n_features), name='LSTM'),
     Dense(1, name='Output')
])

# %%
rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM (LSTM)                 (None, 10)                480
#
#  Output (Dense)              (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the Model
optimizer = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
rnn.compile(loss='mean_squared_error', optimizer=optimizer)

rnn_path = (results_path / 'rnn.h5').as_posix()
checkpointer = ModelCheckpoint(filepath=rnn_path, verbose=1, monitor='val_loss', save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
lstm_training = rnn.fit(X_train, y_train, epochs=150, batch_size=20, shuffle=True,
                        validation_data=(X_test, y_test), callbacks=[early_stopping, checkpointer],
                        verbose=1, workers=6)
# Out:
# Epoch 1/150
# 105/105 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 00001: val_loss improved from inf to 0.00179, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 5s 10ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 2/150
#  98/105 [===========================>..] - ETA: 0s - loss: 5.1920e-04
# Epoch 00002: val_loss improved from 0.00179 to 0.00165, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 5.2240e-04 - val_loss: 0.0016
# Epoch 3/150
# 101/105 [===========================>..] - ETA: 0s - loss: 4.2005e-04
# Epoch 00003: val_loss improved from 0.00165 to 0.00135, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 4.2035e-04 - val_loss: 0.0013
# Epoch 4/150
# 102/105 [============================>.] - ETA: 0s - loss: 3.9075e-04
# Epoch 00004: val_loss did not improve from 0.00135
# 105/105 [==============================] - 1s 6ms/step - loss: 3.8742e-04 - val_loss: 0.0019
# Epoch 5/150
#  99/105 [===========================>..] - ETA: 0s - loss: 3.4915e-04
# Epoch 00005: val_loss improved from 0.00135 to 0.00122, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 3.4321e-04 - val_loss: 0.0012
# Epoch 6/150
# 102/105 [============================>.] - ETA: 0s - loss: 3.3190e-04
# Epoch 00006: val_loss improved from 0.00122 to 0.00105, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 3.2785e-04 - val_loss: 0.0010
# Epoch 7/150
# 104/105 [============================>.] - ETA: 0s - loss: 3.2277e-04
# Epoch 00007: val_loss did not improve from 0.00105
# 105/105 [==============================] - 1s 6ms/step - loss: 3.2212e-04 - val_loss: 0.0011
# Epoch 8/150
# 101/105 [===========================>..] - ETA: 0s - loss: 2.9372e-04
# Epoch 00008: val_loss did not improve from 0.00105
# 105/105 [==============================] - 1s 6ms/step - loss: 2.9388e-04 - val_loss: 0.0011
# Epoch 9/150
# 104/105 [============================>.] - ETA: 0s - loss: 2.8311e-04
# Epoch 00009: val_loss improved from 0.00105 to 0.00096, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 2.8251e-04 - val_loss: 9.5807e-04
# Epoch 10/150
# 101/105 [===========================>..] - ETA: 0s - loss: 2.7502e-04
# Epoch 00010: val_loss did not improve from 0.00096
# 105/105 [==============================] - 1s 6ms/step - loss: 2.7302e-04 - val_loss: 0.0011
# Epoch 11/150
# 104/105 [============================>.] - ETA: 0s - loss: 2.5513e-04
# Epoch 00011: val_loss did not improve from 0.00096
# 105/105 [==============================] - 1s 6ms/step - loss: 2.5457e-04 - val_loss: 0.0017
# Epoch 12/150
# 103/105 [============================>.] - ETA: 0s - loss: 2.4928e-04
# Epoch 00012: val_loss improved from 0.00096 to 0.00088, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 2.5247e-04 - val_loss: 8.7542e-04
# Epoch 13/150
# 104/105 [============================>.] - ETA: 0s - loss: 2.3475e-04
# Epoch 00013: val_loss did not improve from 0.00088
# 105/105 [==============================] - 1s 6ms/step - loss: 2.3685e-04 - val_loss: 0.0025
# Epoch 14/150
# 101/105 [===========================>..] - ETA: 0s - loss: 2.4162e-04
# Epoch 00014: val_loss did not improve from 0.00088
# 105/105 [==============================] - 1s 6ms/step - loss: 2.4012e-04 - val_loss: 0.0012
# Epoch 15/150
# 103/105 [============================>.] - ETA: 0s - loss: 2.3251e-04
# Epoch 00015: val_loss did not improve from 0.00088
# 105/105 [==============================] - 1s 6ms/step - loss: 2.3161e-04 - val_loss: 9.9213e-04
# Epoch 16/150
# 101/105 [===========================>..] - ETA: 0s - loss: 2.2108e-04
# Epoch 00016: val_loss did not improve from 0.00088
# 105/105 [==============================] - 1s 6ms/step - loss: 2.2021e-04 - val_loss: 0.0017
# Epoch 17/150
# 105/105 [==============================] - ETA: 0s - loss: 2.0951e-04
# Epoch 00017: val_loss did not improve from 0.00088
# 105/105 [==============================] - 1s 6ms/step - loss: 2.0951e-04 - val_loss: 0.0014
# Epoch 18/150
# 101/105 [===========================>..] - ETA: 0s - loss: 2.1255e-04
# Epoch 00018: val_loss did not improve from 0.00088
# 105/105 [==============================] - 1s 6ms/step - loss: 2.1082e-04 - val_loss: 0.0027
# Epoch 19/150
# 105/105 [==============================] - ETA: 0s - loss: 2.0542e-04
# Epoch 00019: val_loss did not improve from 0.00088
# 105/105 [==============================] - 1s 6ms/step - loss: 2.0542e-04 - val_loss: 8.9627e-04
# Epoch 20/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.9037e-04
# Epoch 00020: val_loss did not improve from 0.00088
# 105/105 [==============================] - 1s 6ms/step - loss: 1.8867e-04 - val_loss: 0.0013
# Epoch 21/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.8909e-04
# Epoch 00021: val_loss improved from 0.00088 to 0.00072, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 7ms/step - loss: 1.8909e-04 - val_loss: 7.1999e-04
# Epoch 22/150
#  98/105 [===========================>..] - ETA: 0s - loss: 1.8260e-04
# Epoch 00022: val_loss did not improve from 0.00072
# 105/105 [==============================] - 1s 6ms/step - loss: 1.9621e-04 - val_loss: 8.0761e-04
# Epoch 23/150
# 100/105 [===========================>..] - ETA: 0s - loss: 1.7881e-04
# Epoch 00023: val_loss did not improve from 0.00072
# 105/105 [==============================] - 1s 6ms/step - loss: 1.8023e-04 - val_loss: 0.0013
# Epoch 24/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.7297e-04
# Epoch 00024: val_loss did not improve from 0.00072
# 105/105 [==============================] - 1s 6ms/step - loss: 1.7749e-04 - val_loss: 9.6676e-04
# Epoch 25/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.7376e-04
# Epoch 00025: val_loss improved from 0.00072 to 0.00071, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.7768e-04 - val_loss: 7.0751e-04
# Epoch 26/150
#  97/105 [==========================>...] - ETA: 0s - loss: 1.6031e-04
# Epoch 00026: val_loss did not improve from 0.00071
# 105/105 [==============================] - 1s 6ms/step - loss: 1.6475e-04 - val_loss: 0.0021
# Epoch 27/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.6805e-04
# Epoch 00027: val_loss did not improve from 0.00071
# 105/105 [==============================] - 1s 6ms/step - loss: 1.6797e-04 - val_loss: 7.1214e-04
# Epoch 28/150
# 104/105 [============================>.] - ETA: 0s - loss: 1.6096e-04
# Epoch 00028: val_loss improved from 0.00071 to 0.00059, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.6065e-04 - val_loss: 5.9219e-04
# Epoch 29/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.6257e-04
# Epoch 00029: val_loss improved from 0.00059 to 0.00056, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.6040e-04 - val_loss: 5.5511e-04
# Epoch 30/150
# 104/105 [============================>.] - ETA: 0s - loss: 1.5414e-04
# Epoch 00030: val_loss did not improve from 0.00056
# 105/105 [==============================] - 1s 6ms/step - loss: 1.5455e-04 - val_loss: 6.0961e-04
# Epoch 31/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.5671e-04
# Epoch 00031: val_loss did not improve from 0.00056
# 105/105 [==============================] - 1s 6ms/step - loss: 1.5628e-04 - val_loss: 8.6196e-04
# Epoch 32/150
#  96/105 [==========================>...] - ETA: 0s - loss: 1.5408e-04
# Epoch 00032: val_loss did not improve from 0.00056
# 105/105 [==============================] - 1s 6ms/step - loss: 1.5147e-04 - val_loss: 6.2824e-04
# Epoch 33/150
# 104/105 [============================>.] - ETA: 0s - loss: 1.4865e-04
# Epoch 00033: val_loss improved from 0.00056 to 0.00052, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.4844e-04 - val_loss: 5.2325e-04
# Epoch 34/150
#  96/105 [==========================>...] - ETA: 0s - loss: 1.4456e-04
# Epoch 00034: val_loss improved from 0.00052 to 0.00050, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.4650e-04 - val_loss: 5.0183e-04
# Epoch 35/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.3752e-04
# Epoch 00035: val_loss improved from 0.00050 to 0.00050, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.3988e-04 - val_loss: 4.9529e-04
# Epoch 36/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.4349e-04
# Epoch 00036: val_loss did not improve from 0.00050
# 105/105 [==============================] - 1s 6ms/step - loss: 1.4288e-04 - val_loss: 5.2460e-04
# Epoch 37/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.4502e-04
# Epoch 00037: val_loss did not improve from 0.00050
# 105/105 [==============================] - 1s 6ms/step - loss: 1.4257e-04 - val_loss: 5.1866e-04
# Epoch 38/150
# 104/105 [============================>.] - ETA: 0s - loss: 1.3331e-04
# Epoch 00038: val_loss did not improve from 0.00050
# 105/105 [==============================] - 1s 6ms/step - loss: 1.3322e-04 - val_loss: 8.9202e-04
# Epoch 39/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.3976e-04
# Epoch 00039: val_loss improved from 0.00050 to 0.00047, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.4129e-04 - val_loss: 4.7092e-04
# Epoch 40/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.3150e-04
# Epoch 00040: val_loss did not improve from 0.00047
# 105/105 [==============================] - 1s 6ms/step - loss: 1.3059e-04 - val_loss: 4.8941e-04
# Epoch 41/150
# 105/105 [==============================] - ETA: 0s - loss: 1.3314e-04
# Epoch 00041: val_loss did not improve from 0.00047
# 105/105 [==============================] - 1s 5ms/step - loss: 1.3314e-04 - val_loss: 6.7439e-04
# Epoch 42/150
#  96/105 [==========================>...] - ETA: 0s - loss: 1.3773e-04
# Epoch 00042: val_loss did not improve from 0.00047
# 105/105 [==============================] - 1s 6ms/step - loss: 1.3305e-04 - val_loss: 4.8235e-04
# Epoch 43/150
# 104/105 [============================>.] - ETA: 0s - loss: 1.2767e-04
# Epoch 00043: val_loss did not improve from 0.00047
# 105/105 [==============================] - 1s 6ms/step - loss: 1.2740e-04 - val_loss: 4.7376e-04
# Epoch 44/150
#  98/105 [===========================>..] - ETA: 0s - loss: 1.2747e-04
# Epoch 00044: val_loss did not improve from 0.00047
# 105/105 [==============================] - 1s 6ms/step - loss: 1.2352e-04 - val_loss: 5.3598e-04
# Epoch 45/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.2745e-04
# Epoch 00045: val_loss improved from 0.00047 to 0.00043, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.2727e-04 - val_loss: 4.3380e-04
# Epoch 46/150
#  99/105 [===========================>..] - ETA: 0s - loss: 1.2292e-04
# Epoch 00046: val_loss did not improve from 0.00043
# 105/105 [==============================] - 1s 6ms/step - loss: 1.2359e-04 - val_loss: 9.7389e-04
# Epoch 47/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.2219e-04
# Epoch 00047: val_loss did not improve from 0.00043
# 105/105 [==============================] - 1s 6ms/step - loss: 1.2158e-04 - val_loss: 4.3756e-04
# Epoch 48/150
#  98/105 [===========================>..] - ETA: 0s - loss: 1.1489e-04
# Epoch 00048: val_loss did not improve from 0.00043
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1873e-04 - val_loss: 7.2563e-04
# Epoch 49/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.1941e-04
# Epoch 00049: val_loss did not improve from 0.00043
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1806e-04 - val_loss: 6.7742e-04
# Epoch 50/150
#  96/105 [==========================>...] - ETA: 0s - loss: 1.1985e-04
# Epoch 00050: val_loss improved from 0.00043 to 0.00042, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1973e-04 - val_loss: 4.2355e-04
# Epoch 51/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.1964e-04
# Epoch 00051: val_loss improved from 0.00042 to 0.00041, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1853e-04 - val_loss: 4.1003e-04
# Epoch 52/150
#  99/105 [===========================>..] - ETA: 0s - loss: 1.0769e-04
# Epoch 00052: val_loss did not improve from 0.00041
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1217e-04 - val_loss: 4.1468e-04
# Epoch 53/150
# 105/105 [==============================] - ETA: 0s - loss: 1.1483e-04
# Epoch 00053: val_loss did not improve from 0.00041
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1483e-04 - val_loss: 4.5232e-04
# Epoch 54/150
#  99/105 [===========================>..] - ETA: 0s - loss: 1.0913e-04
# Epoch 00054: val_loss did not improve from 0.00041
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0921e-04 - val_loss: 5.2108e-04
# Epoch 55/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.1227e-04
# Epoch 00055: val_loss did not improve from 0.00041
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1233e-04 - val_loss: 6.2518e-04
# Epoch 56/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.0882e-04
# Epoch 00056: val_loss did not improve from 0.00041
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1047e-04 - val_loss: 4.1138e-04
# Epoch 57/150
# 100/105 [===========================>..] - ETA: 0s - loss: 1.0950e-04
# Epoch 00057: val_loss improved from 0.00041 to 0.00040, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0821e-04 - val_loss: 3.9518e-04
# Epoch 58/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.0665e-04
# Epoch 00058: val_loss did not improve from 0.00040
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0552e-04 - val_loss: 4.5754e-04
# Epoch 59/150
# 100/105 [===========================>..] - ETA: 0s - loss: 1.1371e-04
# Epoch 00059: val_loss did not improve from 0.00040
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1139e-04 - val_loss: 4.2705e-04
# Epoch 60/150
# 104/105 [============================>.] - ETA: 0s - loss: 1.0858e-04
# Epoch 00060: val_loss did not improve from 0.00040
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0883e-04 - val_loss: 4.7946e-04
# Epoch 61/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.0570e-04
# Epoch 00061: val_loss did not improve from 0.00040
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0658e-04 - val_loss: 8.3609e-04
# Epoch 62/150
#  99/105 [===========================>..] - ETA: 0s - loss: 1.0553e-04
# Epoch 00062: val_loss did not improve from 0.00040
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0475e-04 - val_loss: 9.7794e-04
# Epoch 63/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.0564e-04
# Epoch 00063: val_loss did not improve from 0.00040
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0493e-04 - val_loss: 4.1659e-04
# Epoch 64/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.1029e-04
# Epoch 00064: val_loss did not improve from 0.00040
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0886e-04 - val_loss: 4.0177e-04
# Epoch 65/150
#  97/105 [==========================>...] - ETA: 0s - loss: 1.0130e-04
# Epoch 00065: val_loss improved from 0.00040 to 0.00038, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0345e-04 - val_loss: 3.8337e-04
# Epoch 66/150
#  99/105 [===========================>..] - ETA: 0s - loss: 1.0407e-04
# Epoch 00066: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0668e-04 - val_loss: 7.1931e-04
# Epoch 67/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.0997e-04
# Epoch 00067: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0937e-04 - val_loss: 3.9990e-04
# Epoch 68/150
#  97/105 [==========================>...] - ETA: 0s - loss: 1.0795e-04
# Epoch 00068: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.1004e-04 - val_loss: 3.9814e-04
# Epoch 69/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.0059e-04
# Epoch 00069: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0300e-04 - val_loss: 4.7213e-04
# Epoch 70/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.0134e-04
# Epoch 00070: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0126e-04 - val_loss: 5.3629e-04
# Epoch 71/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.0612e-04
# Epoch 00071: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0563e-04 - val_loss: 5.1317e-04
# Epoch 72/150
#  98/105 [===========================>..] - ETA: 0s - loss: 1.0917e-04
# Epoch 00072: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0857e-04 - val_loss: 4.1922e-04
# Epoch 73/150
# 105/105 [==============================] - ETA: 0s - loss: 1.0378e-04
# Epoch 00073: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 1.0378e-04 - val_loss: 4.8584e-04
# Epoch 74/150
# 100/105 [===========================>..] - ETA: 0s - loss: 1.0495e-04
# Epoch 00074: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0320e-04 - val_loss: 3.9283e-04
# Epoch 75/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.0644e-04
# Epoch 00075: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0552e-04 - val_loss: 4.3894e-04
# Epoch 76/150
# 100/105 [===========================>..] - ETA: 0s - loss: 1.0535e-04
# Epoch 00076: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0315e-04 - val_loss: 4.6945e-04
# Epoch 77/150
# 103/105 [============================>.] - ETA: 0s - loss: 9.9759e-05
# Epoch 00077: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0050e-04 - val_loss: 5.6374e-04
# Epoch 78/150
#  97/105 [==========================>...] - ETA: 0s - loss: 1.0061e-04
# Epoch 00078: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0320e-04 - val_loss: 3.9124e-04
# Epoch 79/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.0251e-04
# Epoch 00079: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0270e-04 - val_loss: 3.8885e-04
# Epoch 80/150
#  99/105 [===========================>..] - ETA: 0s - loss: 1.0227e-04
# Epoch 00080: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0047e-04 - val_loss: 7.5559e-04
# Epoch 81/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.0632e-04
# Epoch 00081: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0617e-04 - val_loss: 4.5456e-04
# Epoch 82/150
#  97/105 [==========================>...] - ETA: 0s - loss: 1.0398e-04
# Epoch 00082: val_loss improved from 0.00038 to 0.00038, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0387e-04 - val_loss: 3.8099e-04
# Epoch 83/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.0191e-04
# Epoch 00083: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0057e-04 - val_loss: 3.8709e-04
# Epoch 84/150
# 105/105 [==============================] - ETA: 0s - loss: 1.0315e-04
# Epoch 00084: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0315e-04 - val_loss: 3.9209e-04
# Epoch 85/150
# 102/105 [============================>.] - ETA: 0s - loss: 9.7579e-05
# Epoch 00085: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9430e-05 - val_loss: 3.9862e-04
# Epoch 86/150
#  98/105 [===========================>..] - ETA: 0s - loss: 1.0139e-04
# Epoch 00086: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0499e-04 - val_loss: 3.9781e-04
# Epoch 87/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.0007e-04
# Epoch 00087: val_loss improved from 0.00038 to 0.00038, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0025e-04 - val_loss: 3.7762e-04
# Epoch 88/150
#  99/105 [===========================>..] - ETA: 0s - loss: 9.6342e-05
# Epoch 00088: val_loss improved from 0.00038 to 0.00038, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9877e-05 - val_loss: 3.7739e-04
# Epoch 89/150
# 103/105 [============================>.] - ETA: 0s - loss: 9.9011e-05
# Epoch 00089: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9796e-05 - val_loss: 4.6716e-04
# Epoch 90/150
#  97/105 [==========================>...] - ETA: 0s - loss: 1.0306e-04
# Epoch 00090: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0085e-04 - val_loss: 7.7330e-04
# Epoch 91/150
# 103/105 [============================>.] - ETA: 0s - loss: 9.9826e-05
# Epoch 00091: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9909e-05 - val_loss: 3.8563e-04
# Epoch 92/150
#  97/105 [==========================>...] - ETA: 0s - loss: 9.9967e-05
# Epoch 00092: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0019e-04 - val_loss: 3.8691e-04
# Epoch 93/150
# 102/105 [============================>.] - ETA: 0s - loss: 9.8789e-05
# Epoch 00093: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0110e-04 - val_loss: 4.2778e-04
# Epoch 94/150
#  97/105 [==========================>...] - ETA: 0s - loss: 1.0354e-04
# Epoch 00094: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0142e-04 - val_loss: 3.9062e-04
# Epoch 95/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.0036e-04
# Epoch 00095: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9279e-05 - val_loss: 8.9954e-04
# Epoch 96/150
#  96/105 [==========================>...] - ETA: 0s - loss: 9.6894e-05
# Epoch 00096: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0184e-04 - val_loss: 4.1930e-04
# Epoch 97/150
# 101/105 [===========================>..] - ETA: 0s - loss: 9.9591e-05
# Epoch 00097: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.8530e-05 - val_loss: 3.8699e-04
# Epoch 98/150
# 100/105 [===========================>..] - ETA: 0s - loss: 1.0069e-04
# Epoch 00098: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9594e-05 - val_loss: 3.7939e-04
# Epoch 99/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.0128e-04
# Epoch 00099: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 1.0140e-04 - val_loss: 4.2894e-04
# Epoch 100/150
# 101/105 [===========================>..] - ETA: 0s - loss: 9.8426e-05
# Epoch 00100: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.7841e-05 - val_loss: 4.4699e-04
# Epoch 101/150
# 103/105 [============================>.] - ETA: 0s - loss: 1.0285e-04
# Epoch 00101: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 1.0227e-04 - val_loss: 4.4501e-04
# Epoch 102/150
# 103/105 [============================>.] - ETA: 0s - loss: 9.9435e-05
# Epoch 00102: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9151e-05 - val_loss: 8.4723e-04
# Epoch 103/150
# 100/105 [===========================>..] - ETA: 0s - loss: 1.0183e-04
# Epoch 00103: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0172e-04 - val_loss: 3.9488e-04
# Epoch 104/150
# 101/105 [===========================>..] - ETA: 0s - loss: 1.0359e-04
# Epoch 00104: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0385e-04 - val_loss: 3.8042e-04
# Epoch 105/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.0100e-04
# Epoch 00105: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0083e-04 - val_loss: 4.0721e-04
# Epoch 106/150
# 103/105 [============================>.] - ETA: 0s - loss: 9.9600e-05
# Epoch 00106: val_loss improved from 0.00038 to 0.00038, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9527e-05 - val_loss: 3.7699e-04
# Epoch 107/150
#  98/105 [===========================>..] - ETA: 0s - loss: 1.0411e-04
# Epoch 00107: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0267e-04 - val_loss: 5.3727e-04
# Epoch 108/150
# 100/105 [===========================>..] - ETA: 0s - loss: 9.8441e-05
# Epoch 00108: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.8410e-05 - val_loss: 9.8103e-04
# Epoch 109/150
# 102/105 [============================>.] - ETA: 0s - loss: 1.0131e-04
# Epoch 00109: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0073e-04 - val_loss: 3.8240e-04
# Epoch 110/150
# 104/105 [============================>.] - ETA: 0s - loss: 1.0087e-04
# Epoch 00110: val_loss improved from 0.00038 to 0.00038, saving model to results/univariate_time_series\rnn.h5
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0065e-04 - val_loss: 3.7589e-04
# Epoch 111/150
#  99/105 [===========================>..] - ETA: 0s - loss: 1.0289e-04
# Epoch 00111: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0122e-04 - val_loss: 4.8533e-04
# Epoch 112/150
# 102/105 [============================>.] - ETA: 0s - loss: 9.9927e-05
# Epoch 00112: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9117e-05 - val_loss: 5.1407e-04
# Epoch 113/150
# 104/105 [============================>.] - ETA: 0s - loss: 9.7887e-05
# Epoch 00113: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.7823e-05 - val_loss: 6.2023e-04
# Epoch 114/150
#  97/105 [==========================>...] - ETA: 0s - loss: 1.0051e-04
# Epoch 00114: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 1.0210e-04 - val_loss: 3.7677e-04
# Epoch 115/150
#  99/105 [===========================>..] - ETA: 0s - loss: 1.0024e-04
# Epoch 00115: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.8472e-05 - val_loss: 3.9187e-04
# Epoch 116/150
# 104/105 [============================>.] - ETA: 0s - loss: 9.8675e-05
# Epoch 00116: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 9.8507e-05 - val_loss: 3.8216e-04
# Epoch 117/150
#  99/105 [===========================>..] - ETA: 0s - loss: 1.0114e-04
# Epoch 00117: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0340e-04 - val_loss: 4.9135e-04
# Epoch 118/150
# 103/105 [============================>.] - ETA: 0s - loss: 9.9637e-05
# Epoch 00118: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 9.8914e-05 - val_loss: 4.8407e-04
# Epoch 119/150
# 100/105 [===========================>..] - ETA: 0s - loss: 1.0338e-04
# Epoch 00119: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 1.0289e-04 - val_loss: 4.6546e-04
# Epoch 120/150
# 103/105 [============================>.] - ETA: 0s - loss: 9.9359e-05
# Epoch 00120: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 9.8773e-05 - val_loss: 3.8039e-04
# Epoch 121/150
#  98/105 [===========================>..] - ETA: 0s - loss: 9.8646e-05
# Epoch 00121: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.7545e-05 - val_loss: 9.3129e-04
# Epoch 122/150
#  97/105 [==========================>...] - ETA: 0s - loss: 9.7737e-05
# Epoch 00122: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 1.0136e-04 - val_loss: 3.9788e-04
# Epoch 123/150
# 101/105 [===========================>..] - ETA: 0s - loss: 9.9954e-05
# Epoch 00123: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.9502e-05 - val_loss: 9.5335e-04
# Epoch 124/150
# 104/105 [============================>.] - ETA: 0s - loss: 1.0181e-04
# Epoch 00124: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 1.0198e-04 - val_loss: 5.3076e-04
# Epoch 125/150
#  98/105 [===========================>..] - ETA: 0s - loss: 9.6001e-05
# Epoch 00125: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.7505e-05 - val_loss: 6.7242e-04
# Epoch 126/150
# 104/105 [============================>.] - ETA: 0s - loss: 9.6536e-05
# Epoch 00126: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 5ms/step - loss: 9.6480e-05 - val_loss: 3.7722e-04
# Epoch 127/150
#  98/105 [===========================>..] - ETA: 0s - loss: 9.8719e-05
# Epoch 00127: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.8520e-05 - val_loss: 6.4043e-04
# Epoch 128/150
# 102/105 [============================>.] - ETA: 0s - loss: 9.6372e-05
# Epoch 00128: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.5498e-05 - val_loss: 4.1401e-04
# Epoch 129/150
#  96/105 [==========================>...] - ETA: 0s - loss: 1.0036e-04
# Epoch 00129: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.8783e-05 - val_loss: 4.1435e-04
# Epoch 130/150
# 101/105 [===========================>..] - ETA: 0s - loss: 9.5588e-05
# Epoch 00130: val_loss did not improve from 0.00038
# 105/105 [==============================] - 1s 6ms/step - loss: 9.6449e-05 - val_loss: 5.7101e-04

# %%
# Evaluate model performance
fig, ax = plt.subplots(figsize=(16, 8))

loss_history = pd.DataFrame(lstm_training.history).pow(.5)
loss_history.index += 1
best_rmse = loss_history.val_loss.min()
best_epoch = loss_history.val_loss.idxmin()

title = f'5-Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
loss_history.columns=['Training RMSE', 'Validation RMSE']

# display 5 epoch rolling avg of the training and validation RMSE
loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=ax)
ax.axvline(best_epoch, ls='--', lw=1, c='k')
sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'rnn_sp500_error', dpi=300);

# %%
train_rmse_scaled = np.sqrt(rnn.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(rnn.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE: {train_rmse_scaled:.4f} | Test RMSE: {test_rmse_scaled:.4f}')
# Out:
# Train RMSE: 0.0092 | Test RMSE: 0.0194

# %%
train_predict_scaled = rnn.predict(X_train)
test_predict_scaled = rnn.predict(X_test)
train_ic = spearmanr(y_train, train_predict_scaled)[0]
test_ic = spearmanr(y_test, test_predict_scaled)[0]
print(f'Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}')
# Out:
# Train IC: 0.9984 | Test IC: 0.9721

# %%
# Rescale predictions
train_predict = pd.Series(scaler.inverse_transform(train_predict_scaled).squeeze(), index=y_train.index)
test_predict = (pd.Series(scaler.inverse_transform(test_predict_scaled).squeeze(),index=y_test.index))
y_train_rescaled = scaler.inverse_transform(y_train.to_frame()).squeeze()
y_test_rescaled = scaler.inverse_transform(y_test.to_frame()).squeeze()
train_rmse = np.sqrt(mean_squared_error(train_predict, y_train_rescaled))
test_rmse = np.sqrt(mean_squared_error(test_predict, y_test_rescaled))
f'Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}'
# Out:
# 'Train RMSE: 29.61 | Test RMSE: 62.50'

# %%
sp500['Train Predictions'] = train_predict
sp500['Test Predictions'] = test_predict
sp500 = sp500.join(train_predict.to_frame('predictions').assign(data='Train')
                        .append(test_predict.to_frame('predictions').assign(data='Test')))

# %%
# Plot Results
fig=plt.figure(figsize=(16,12))
ax1 = plt.subplot(221)

sp500.loc['2018':, 'SP500'].plot(lw=4, ax=ax1, c='k')
sp500.loc['2018':, ['Test Predictions', 'Train Predictions']].plot(lw=1, ax=ax1, ls='--')
ax1.set_title('In- and Out-of-sample Predictions')


with sns.axes_style("white"):
    ax3 = plt.subplot(223)
    sns.scatterplot(x='SP500', y='predictions', data=sp500, hue='data', ax=ax3)
    ax3.text(x=.02, y=.95, s=f'Test IC ={test_ic:.2%}', transform=ax3.transAxes)
    ax3.text(x=.02, y=.87, s=f'Train IC={train_ic:.2%}', transform=ax3.transAxes)
    ax3.set_title('Correlation')
    ax3.legend(loc='lower right')

    ax2 = plt.subplot(222)
    ax4 = plt.subplot(224, sharex = ax2, sharey=ax2)
    sns.distplot(train_predict.squeeze()- y_train_rescaled, ax=ax2)
    ax2.set_title('Train Error')
    ax2.text(x=.03, y=.92, s=f'Train RMSE ={train_rmse:.4f}', transform=ax2.transAxes)
    sns.distplot(test_predict.squeeze()-y_test_rescaled, ax=ax4)
    ax4.set_title('Test Error')
    ax4.text(x=.03, y=.92, s=f'Test RMSE ={test_rmse:.4f}', transform=ax4.transAxes)

sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'rnn_sp500_regression', dpi=300);
