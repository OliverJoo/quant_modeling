# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from pathlib import Path
from copy import deepcopy
import numpy as np
import pandas as pd

import sklearn
from sklearn.datasets import make_circles # To generate the dataset

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import TensorBoard

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D  # 3D plots

import seaborn as sns
# plotting style
sns.set_style('white')

# for reproducibility
np.random.seed(seed=42)

# %%
# get GPU list if it exists
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    # GPU memory allocating GPU and increse if it needs
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using GPU

# %%
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
results_path = Path('results')
if not results_path.exists():
    results_path.mkdir()

# %%
# Input Data

# dataset params
N = 50000
factor = 0.1
noise = 0.1

# generate data
X, y = make_circles(n_samples=N, shuffle=True, factor=factor, noise=noise)

# define outcome matrix
Y = np.zeros((N, 2))
for c in [0, 1]:
    Y[y == c, c] = 1
f'Shape of: X: {X.shape} | Y: {Y.shape} | y: {y.shape}'
# Out:
# 'Shape of: X: (50000, 2) | Y: (50000, 2) | y: (50000,)'

# %%
# Visualize Data
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, style=y, markers=['_', '+']);

# %%
# Build Keras Model
model = Sequential([
    Dense(units=3, input_shape=(2,), name='hidden'),
    Activation('sigmoid', name='logistic'),
    Dense(2, name='output'),
    Activation('softmax', name='softmax'),
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 3)                 9
#
#  logistic (Activation)       (None, 3)                 0
#
#  output (Dense)              (None, 2)                 8
#
#  softmax (Activation)        (None, 2)                 0
#
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

tb_callback = TensorBoard(log_dir=results_path / 'tensorboard', histogram_freq=1, write_graph=True,
                          write_images=True)

training=model.fit(X, Y, epochs=50, validation_split=.2, batch_size=128, verbose=1, callbacks=[tb_callback])
# Out:
# Epoch 1/50
# 313/313 [==============================] - 4s 5ms/step - loss: 0.7127 - accuracy: 0.5760 - val_loss: 0.6971 - val_accuracy: 0.6874
# Epoch 2/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6952 - accuracy: 0.6155 - val_loss: 0.6941 - val_accuracy: 0.4497
# Epoch 3/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.6937 - accuracy: 0.5753 - val_loss: 0.6934 - val_accuracy: 0.6947
# Epoch 4/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6928 - accuracy: 0.6249 - val_loss: 0.6924 - val_accuracy: 0.4893
# Epoch 5/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6919 - accuracy: 0.6679 - val_loss: 0.6911 - val_accuracy: 0.6207
# Epoch 6/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6902 - accuracy: 0.6605 - val_loss: 0.6893 - val_accuracy: 0.6914
# Epoch 7/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6873 - accuracy: 0.7013 - val_loss: 0.6855 - val_accuracy: 0.6974
# Epoch 8/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6826 - accuracy: 0.7025 - val_loss: 0.6800 - val_accuracy: 0.6799
# Epoch 9/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6758 - accuracy: 0.7056 - val_loss: 0.6724 - val_accuracy: 0.6670
# Epoch 10/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6665 - accuracy: 0.7206 - val_loss: 0.6615 - val_accuracy: 0.7987
# Epoch 11/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6548 - accuracy: 0.7976 - val_loss: 0.6488 - val_accuracy: 0.7959
# Epoch 12/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6406 - accuracy: 0.8268 - val_loss: 0.6331 - val_accuracy: 0.8480
# Epoch 13/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6242 - accuracy: 0.8515 - val_loss: 0.6159 - val_accuracy: 0.8523
# Epoch 14/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6064 - accuracy: 0.8577 - val_loss: 0.5978 - val_accuracy: 0.8602
# Epoch 15/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5875 - accuracy: 0.8631 - val_loss: 0.5780 - val_accuracy: 0.8685
# Epoch 16/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5678 - accuracy: 0.8698 - val_loss: 0.5582 - val_accuracy: 0.8697
# Epoch 17/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5478 - accuracy: 0.8729 - val_loss: 0.5377 - val_accuracy: 0.8761
# Epoch 18/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5275 - accuracy: 0.8771 - val_loss: 0.5176 - val_accuracy: 0.8799
# Epoch 19/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5076 - accuracy: 0.8806 - val_loss: 0.4975 - val_accuracy: 0.8844
# Epoch 20/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4880 - accuracy: 0.8846 - val_loss: 0.4785 - val_accuracy: 0.8875
# Epoch 21/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4697 - accuracy: 0.8882 - val_loss: 0.4608 - val_accuracy: 0.8891
# Epoch 22/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4518 - accuracy: 0.8913 - val_loss: 0.4429 - val_accuracy: 0.8916
# Epoch 23/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4346 - accuracy: 0.8939 - val_loss: 0.4261 - val_accuracy: 0.8979
# Epoch 24/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.4182 - accuracy: 0.8972 - val_loss: 0.4100 - val_accuracy: 0.8983
# Epoch 25/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4031 - accuracy: 0.8988 - val_loss: 0.3959 - val_accuracy: 0.8977
# Epoch 26/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3893 - accuracy: 0.8996 - val_loss: 0.3829 - val_accuracy: 0.8972
# Epoch 27/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3771 - accuracy: 0.9006 - val_loss: 0.3707 - val_accuracy: 0.9008
# Epoch 28/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3653 - accuracy: 0.9016 - val_loss: 0.3595 - val_accuracy: 0.9006
# Epoch 29/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3544 - accuracy: 0.9019 - val_loss: 0.3490 - val_accuracy: 0.9013
# Epoch 30/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3444 - accuracy: 0.9025 - val_loss: 0.3394 - val_accuracy: 0.8993
# Epoch 31/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3354 - accuracy: 0.9019 - val_loss: 0.3307 - val_accuracy: 0.9001
# Epoch 32/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3269 - accuracy: 0.9026 - val_loss: 0.3224 - val_accuracy: 0.9013
# Epoch 33/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3188 - accuracy: 0.9039 - val_loss: 0.3144 - val_accuracy: 0.9025
# Epoch 34/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3109 - accuracy: 0.9048 - val_loss: 0.3067 - val_accuracy: 0.9023
# Epoch 35/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3030 - accuracy: 0.9054 - val_loss: 0.2987 - val_accuracy: 0.9028
# Epoch 36/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.2950 - accuracy: 0.9066 - val_loss: 0.2905 - val_accuracy: 0.9062
# Epoch 37/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2867 - accuracy: 0.9081 - val_loss: 0.2818 - val_accuracy: 0.9082
# Epoch 38/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2779 - accuracy: 0.9103 - val_loss: 0.2729 - val_accuracy: 0.9095
# Epoch 39/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2681 - accuracy: 0.9124 - val_loss: 0.2624 - val_accuracy: 0.9119
# Epoch 40/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.2563 - accuracy: 0.9155 - val_loss: 0.2493 - val_accuracy: 0.9176
# Epoch 41/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2425 - accuracy: 0.9226 - val_loss: 0.2344 - val_accuracy: 0.9309
# Epoch 42/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2257 - accuracy: 0.9540 - val_loss: 0.2164 - val_accuracy: 0.9808
# Epoch 43/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.2065 - accuracy: 0.9902 - val_loss: 0.1961 - val_accuracy: 0.9963
# Epoch 44/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1856 - accuracy: 0.9973 - val_loss: 0.1750 - val_accuracy: 0.9986
# Epoch 45/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1644 - accuracy: 0.9985 - val_loss: 0.1541 - val_accuracy: 0.9991
# Epoch 46/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1444 - accuracy: 0.9992 - val_loss: 0.1349 - val_accuracy: 0.9995
# Epoch 47/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1263 - accuracy: 0.9996 - val_loss: 0.1181 - val_accuracy: 0.9995
# Epoch 48/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1107 - accuracy: 0.9998 - val_loss: 0.1037 - val_accuracy: 0.9995
# Epoch 49/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0974 - accuracy: 0.9999 - val_loss: 0.0915 - val_accuracy: 0.9995
# Epoch 50/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0862 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9995

# %%
fig, axes = plt.subplots(ncols=2, figsize=(16,8))
pd.DataFrame(training.history)[['accuracy', 'val_accuracy']].plot(ax=axes[0])
pd.DataFrame(training.history)[['loss', 'val_loss']].plot(ax=axes[1])
sns.despine()
fig.tight_layout();

# %%
# Get Weights
hidden = model.get_layer('hidden').get_weights()
[t.shape for t in hidden]
# Out:
# [(2, 3), (3,)]

# %%
# Plot Decision Boundary
n_vals = 200
x1 = np.linspace(-1.5, 1.5, num=n_vals)
x2 = np.linspace(-1.5, 1.5, num=n_vals)
xx, yy = np.meshgrid(x1, x2)  # create the grid

X_ = np.array([xx.ravel(), yy.ravel()]).T
y_hat = np.argmax(model.predict(X_), axis=1)

# Create a color map to show the classification colors of each grid point
cmap = ListedColormap([sns.xkcd_rgb["pale red"], sns.xkcd_rgb["denim blue"]])

# Plot the classification plane with decision boundary and input samples
plt.contourf(xx, yy, y_hat.reshape(n_vals, -1), cmap=cmap, alpha=.25)

# Plot both classes on the x1, x2 plane
data = pd.DataFrame(X, columns=['$x_1$', '$x_2$']).assign(Class=pd.Series(y).map({0:'negative', 1:'positive'}))
sns.scatterplot(x='$x_1$', y='$x_2$', hue='Class', data=data, style=y, markers=['_', '+'], legend=False)
sns.despine()
plt.title('Decision Boundary');

# %%
# %load_ext tensorboard
# %tensorboard --logdir results/tensorboard/
# Out:
# Launching TensorBoard...
