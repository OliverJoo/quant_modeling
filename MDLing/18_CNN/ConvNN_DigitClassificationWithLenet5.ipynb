# %%
# %matplotlib inline

from pathlib import Path
from random import randint
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.datasets import mnist
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, AveragePooling2D, Dense, Dropout, Flatten)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')

sns.set_style('whitegrid')
results_path = Path('results')
mnist_path = results_path / 'mnist'
if not mnist_path.exists():
    mnist_path.mkdir(parents=True)
# Out:
# Using GPU

# %%
# load mnist dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print(f'The MNIST database has a training set of {len(X_train)} examples with {X_train.shape} shape')
print(f'The MNIST database has a test set of {len(X_test)} examples with {X_test.shape} shape')
# Out:
# The MNIST database has a training set of 60000 examples with (60000, 28, 28) shape
# The MNIST database has a test set of 10000 examples with (10000, 28, 28) shape

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(20, 14))

print(f'before flatten():{axes.shape}')
# flatten() ravel() difference: copy function(flatten() change the value, where ravel() not change)
axes = axes.flatten() # reshape from multi-dimension to 1-dimension
print(f'after  flatten():{axes.shape}')

for i, ax in enumerate(axes):
    ax.imshow(X_train[i], cmap='gray')
    ax.axis('off')
    ax.set_title('Digit: {}'.format(y_train[i]), fontsize=16)

fig.suptitle('First 10 Digits', fontsize=20)
fig.tight_layout()
fig.subplots_adjust(top=.9)
# Out:
# before flatten():(2, 5)
# after  flatten():(10,)

# %%
# Show random image in detail
fig, ax = plt.subplots(figsize = (16, 16))

i = randint(0, len(X_train))
img = X_train[i]

ax.imshow(img, cmap='gray')
ax.set_title('Digit: {}'.format(y_train[i]), fontsize=16)

width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        ax.annotate(f'{img[x][y]:2}', xy=(y,x), horizontalalignment='center',
                    verticalalignment='center', color='white' if img[x][y]<thresh else 'black')

# %%
# Prepare Data
X_train = X_train.astype('float32')/255  # rescale from [0,255] to [0,1] and to float32 for memory efficiency
X_test = X_test.astype('float32')/255

# One-Hot Label Encoding
print('Integer-valued labels:')
print(y_train[:10])

# Feed-Forward NN
ffnn = Sequential([Flatten(input_shape=X_train.shape[1:]), # 28 * 28 = 784
    Dense(512, activation='relu'), # (784 + 1) * 512 = 401920
    Dropout(0.2),
    Dense(512, activation='relu'), # (512 + 1) * 512 = 262656
    Dropout(0.2),
    Dense(10, activation='softmax') # (512 + 1) * 10 = 5130
])
ffnn.summary()
# Out:
# Integer-valued labels:
# [5 0 4 1 9 2 1 3 1 4]
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
ffnn.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# evaluate test accuracy
baseline_accuracy = ffnn.evaluate(X_test, y_test, verbose=0)[1]

# print test accuracy
print(f'Test accuracy: {baseline_accuracy:.2%}')
# Out:
# Test accuracy: 10.04%

# %%
# Callback for model persistence
ffn_path = mnist_path / 'ffn.best.hdf5'
checkpointer = ModelCheckpoint(filepath=ffn_path.as_posix(), verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=20)

epochs = 100
batch_size = 32
ffnn_history = ffnn.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2,
                        callbacks=[checkpointer, early_stopping], verbose=1, shuffle=True, workers=6)
# Out:
# Epoch 1/100
# 1495/1500 [============================>.] - ETA: 0s - loss: 0.2387 - accuracy: 0.9292
# Epoch 00001: val_loss improved from inf to 0.12191, saving model to results/mnist\ffn.best.hdf5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2383 - accuracy: 0.9294 - val_loss: 0.1219 - val_accuracy: 0.9651
# Epoch 2/100
# 1488/1500 [============================>.] - ETA: 0s - loss: 0.1312 - accuracy: 0.9653
# Epoch 00002: val_loss did not improve from 0.12191
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1308 - accuracy: 0.9655 - val_loss: 0.1427 - val_accuracy: 0.9680
# Epoch 3/100
# 1493/1500 [============================>.] - ETA: 0s - loss: 0.1158 - accuracy: 0.9718
# Epoch 00003: val_loss improved from 0.12191 to 0.10907, saving model to results/mnist\ffn.best.hdf5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1156 - accuracy: 0.9719 - val_loss: 0.1091 - val_accuracy: 0.9748
# Epoch 4/100
# 1479/1500 [============================>.] - ETA: 0s - loss: 0.1075 - accuracy: 0.9752
# Epoch 00004: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1077 - accuracy: 0.9753 - val_loss: 0.1306 - val_accuracy: 0.9739
# Epoch 5/100
# 1485/1500 [============================>.] - ETA: 0s - loss: 0.1052 - accuracy: 0.9764
# Epoch 00005: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1054 - accuracy: 0.9764 - val_loss: 0.1495 - val_accuracy: 0.9747
# Epoch 6/100
# 1498/1500 [============================>.] - ETA: 0s - loss: 0.1012 - accuracy: 0.9788
# Epoch 00006: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1014 - accuracy: 0.9788 - val_loss: 0.1439 - val_accuracy: 0.9771
# Epoch 7/100
# 1481/1500 [============================>.] - ETA: 0s - loss: 0.0972 - accuracy: 0.9808
# Epoch 00007: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0976 - accuracy: 0.9807 - val_loss: 0.1922 - val_accuracy: 0.9753
# Epoch 8/100
# 1482/1500 [============================>.] - ETA: 0s - loss: 0.0943 - accuracy: 0.9813
# Epoch 00008: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0954 - accuracy: 0.9812 - val_loss: 0.1745 - val_accuracy: 0.9776
# Epoch 9/100
# 1478/1500 [============================>.] - ETA: 0s - loss: 0.0877 - accuracy: 0.9827
# Epoch 00009: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0879 - accuracy: 0.9827 - val_loss: 0.1839 - val_accuracy: 0.9778
# Epoch 10/100
# 1492/1500 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9844
# Epoch 00010: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0864 - accuracy: 0.9844 - val_loss: 0.2033 - val_accuracy: 0.9778
# Epoch 11/100
# 1495/1500 [============================>.] - ETA: 0s - loss: 0.0877 - accuracy: 0.9843
# Epoch 00011: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0884 - accuracy: 0.9842 - val_loss: 0.2456 - val_accuracy: 0.9740
# Epoch 12/100
# 1475/1500 [============================>.] - ETA: 0s - loss: 0.0867 - accuracy: 0.9845
# Epoch 00012: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0861 - accuracy: 0.9846 - val_loss: 0.2164 - val_accuracy: 0.9793
# Epoch 13/100
# 1499/1500 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9862
# Epoch 00013: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0837 - accuracy: 0.9862 - val_loss: 0.2282 - val_accuracy: 0.9789
# Epoch 14/100
# 1477/1500 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9872
# Epoch 00014: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0806 - accuracy: 0.9872 - val_loss: 0.2747 - val_accuracy: 0.9755
# Epoch 15/100
# 1483/1500 [============================>.] - ETA: 0s - loss: 0.0813 - accuracy: 0.9869
# Epoch 00015: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0808 - accuracy: 0.9869 - val_loss: 0.2461 - val_accuracy: 0.9794
# Epoch 16/100
# 1482/1500 [============================>.] - ETA: 0s - loss: 0.0775 - accuracy: 0.9876
# Epoch 00016: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0776 - accuracy: 0.9877 - val_loss: 0.2932 - val_accuracy: 0.9789
# Epoch 17/100
# 1489/1500 [============================>.] - ETA: 0s - loss: 0.0779 - accuracy: 0.9878
# Epoch 00017: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0779 - accuracy: 0.9878 - val_loss: 0.2734 - val_accuracy: 0.9779
# Epoch 18/100
# 1489/1500 [============================>.] - ETA: 0s - loss: 0.0779 - accuracy: 0.9889
# Epoch 00018: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0783 - accuracy: 0.9888 - val_loss: 0.2718 - val_accuracy: 0.9778
# Epoch 19/100
# 1486/1500 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9888
# Epoch 00019: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0707 - accuracy: 0.9888 - val_loss: 0.3321 - val_accuracy: 0.9775
# Epoch 20/100
# 1475/1500 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9888
# Epoch 00020: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0717 - accuracy: 0.9888 - val_loss: 0.3234 - val_accuracy: 0.9778
# Epoch 21/100
# 1491/1500 [============================>.] - ETA: 0s - loss: 0.0737 - accuracy: 0.9883
# Epoch 00021: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0739 - accuracy: 0.9883 - val_loss: 0.3448 - val_accuracy: 0.9798
# Epoch 22/100
# 1481/1500 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9900
# Epoch 00022: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0745 - accuracy: 0.9900 - val_loss: 0.3273 - val_accuracy: 0.9781
# Epoch 23/100
# 1482/1500 [============================>.] - ETA: 0s - loss: 0.0765 - accuracy: 0.9903
# Epoch 00023: val_loss did not improve from 0.10907
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0768 - accuracy: 0.9903 - val_loss: 0.2835 - val_accuracy: 0.9800

# %%
# Plot CV Results
pd.DataFrame(ffnn_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(14,4))
sns.despine();

# %%
# Load the Best Model
ffnn.load_weights(ffn_path.as_posix()) # load the weights that yielded the best validation accuracy
ffnn_accuracy = ffnn.evaluate(X_test, y_test, verbose=0)[1] # evaluate test accuracy

print(f'Test accuracy: {ffnn_accuracy:.2%}')
# Out:
# Test accuracy: 97.81%

# %%
# LeNet5 - designed for checks handwriting recognition and used by several banks
K.clear_session() # Resets all state

lenet5 = Sequential([
    # Conv2D
    #   filters(# of output channels after Conv)
    #   kernel_size(size of a Conv filter being used for Conv)
    Conv2D(filters=6, kernel_size=5, activation='relu', input_shape=(28, 28, 1), name='CONV1'),
    AveragePooling2D(pool_size=(2, 2), strides=(1, 1), padding='valid', name='POOL1'),
    Conv2D(filters=16, kernel_size=(5, 5), activation='tanh', name='CONV2'),
    AveragePooling2D(pool_size=(2, 2), strides=(2, 2), name='POOL2'),
    Conv2D(filters=120, kernel_size=(5, 5), activation='tanh', name='CONV3'),
    Flatten(name='FLAT'),
    Dense(units=84, activation='tanh', name='FC6'),
    Dense(units=10, activation='softmax', name='FC7')
])

lenet5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  CONV1 (Conv2D)              (None, 24, 24, 6)         156
#
#  POOL1 (AveragePooling2D)    (None, 23, 23, 6)         0
#
#  CONV2 (Conv2D)              (None, 19, 19, 16)        2416
#
#  POOL2 (AveragePooling2D)    (None, 9, 9, 16)          0
#
#  CONV3 (Conv2D)              (None, 5, 5, 120)         48120
#
#  FLAT (Flatten)              (None, 3000)              0
#
#  FC6 (Dense)                 (None, 84)                252084
#
#  FC7 (Dense)                 (None, 10)                850
#
# =================================================================
# Total params: 303,626
# Trainable params: 303,626
# Non-trainable params: 0
# _________________________________________________________________

# %%
lenet5.compile(loss='sparse_categorical_crossentropy', optimizer='SGD', metrics=['accuracy'])

# Define checkpoint callback
lenet_path = mnist_path / 'lenet.best.hdf5'
checkpointer = ModelCheckpoint(filepath=lenet_path.as_posix(), verbose=1, save_best_only=True)

# %%
batch_size=32
epochs=100
lenet_history = lenet5.fit(X_train.reshape(-1, 28, 28, 1), y_train, batch_size=batch_size, epochs=epochs,
    validation_split=0.2,  # use 0 to train on all data
    callbacks=[checkpointer, early_stopping], verbose=1, shuffle=True, workers=6)
# Out:
# Epoch 1/100
# 1494/1500 [============================>.] - ETA: 0s - loss: 0.4921 - accuracy: 0.8643
# Epoch 00001: val_loss improved from inf to 0.23876, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.4911 - accuracy: 0.8646 - val_loss: 0.2388 - val_accuracy: 0.9355
# Epoch 2/100
# 1486/1500 [============================>.] - ETA: 0s - loss: 0.2028 - accuracy: 0.9425
# Epoch 00002: val_loss improved from 0.23876 to 0.15862, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2022 - accuracy: 0.9427 - val_loss: 0.1586 - val_accuracy: 0.9567
# Epoch 3/100
# 1493/1500 [============================>.] - ETA: 0s - loss: 0.1443 - accuracy: 0.9590
# Epoch 00003: val_loss improved from 0.15862 to 0.12135, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1440 - accuracy: 0.9591 - val_loss: 0.1214 - val_accuracy: 0.9668
# Epoch 4/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.1119 - accuracy: 0.9678
# Epoch 00004: val_loss improved from 0.12135 to 0.10319, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1118 - accuracy: 0.9679 - val_loss: 0.1032 - val_accuracy: 0.9718
# Epoch 5/100
# 1492/1500 [============================>.] - ETA: 0s - loss: 0.0923 - accuracy: 0.9739
# Epoch 00005: val_loss improved from 0.10319 to 0.08951, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0921 - accuracy: 0.9739 - val_loss: 0.0895 - val_accuracy: 0.9744
# Epoch 6/100
# 1497/1500 [============================>.] - ETA: 0s - loss: 0.0788 - accuracy: 0.9775
# Epoch 00006: val_loss improved from 0.08951 to 0.08320, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0787 - accuracy: 0.9775 - val_loss: 0.0832 - val_accuracy: 0.9766
# Epoch 7/100
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.0692 - accuracy: 0.9804
# Epoch 00007: val_loss improved from 0.08320 to 0.07171, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0690 - accuracy: 0.9805 - val_loss: 0.0717 - val_accuracy: 0.9793
# Epoch 8/100
# 1499/1500 [============================>.] - ETA: 0s - loss: 0.0618 - accuracy: 0.9826
# Epoch 00008: val_loss improved from 0.07171 to 0.06981, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0618 - accuracy: 0.9826 - val_loss: 0.0698 - val_accuracy: 0.9803
# Epoch 9/100
# 1486/1500 [============================>.] - ETA: 0s - loss: 0.0558 - accuracy: 0.9839
# Epoch 00009: val_loss improved from 0.06981 to 0.06597, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0560 - accuracy: 0.9840 - val_loss: 0.0660 - val_accuracy: 0.9802
# Epoch 10/100
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.0512 - accuracy: 0.9857
# Epoch 00010: val_loss improved from 0.06597 to 0.06108, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0512 - accuracy: 0.9857 - val_loss: 0.0611 - val_accuracy: 0.9822
# Epoch 11/100
# 1492/1500 [============================>.] - ETA: 0s - loss: 0.0465 - accuracy: 0.9871
# Epoch 00011: val_loss improved from 0.06108 to 0.06022, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0466 - accuracy: 0.9871 - val_loss: 0.0602 - val_accuracy: 0.9829
# Epoch 12/100
# 1500/1500 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9880
# Epoch 00012: val_loss improved from 0.06022 to 0.05900, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0434 - accuracy: 0.9880 - val_loss: 0.0590 - val_accuracy: 0.9822
# Epoch 13/100
# 1493/1500 [============================>.] - ETA: 0s - loss: 0.0403 - accuracy: 0.9892
# Epoch 00013: val_loss improved from 0.05900 to 0.05449, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0402 - accuracy: 0.9892 - val_loss: 0.0545 - val_accuracy: 0.9835
# Epoch 14/100
# 1487/1500 [============================>.] - ETA: 0s - loss: 0.0375 - accuracy: 0.9899
# Epoch 00014: val_loss improved from 0.05449 to 0.05371, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0376 - accuracy: 0.9899 - val_loss: 0.0537 - val_accuracy: 0.9842
# Epoch 15/100
# 1486/1500 [============================>.] - ETA: 0s - loss: 0.0354 - accuracy: 0.9909
# Epoch 00015: val_loss improved from 0.05371 to 0.05285, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0353 - accuracy: 0.9909 - val_loss: 0.0528 - val_accuracy: 0.9847
# Epoch 16/100
# 1486/1500 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9909
# Epoch 00016: val_loss improved from 0.05285 to 0.05125, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0333 - accuracy: 0.9909 - val_loss: 0.0513 - val_accuracy: 0.9843
# Epoch 17/100
# 1489/1500 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9916
# Epoch 00017: val_loss did not improve from 0.05125
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0310 - accuracy: 0.9916 - val_loss: 0.0517 - val_accuracy: 0.9847
# Epoch 18/100
# 1493/1500 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9927
# Epoch 00018: val_loss improved from 0.05125 to 0.04958, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0292 - accuracy: 0.9926 - val_loss: 0.0496 - val_accuracy: 0.9860
# Epoch 19/100
# 1491/1500 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9928
# Epoch 00019: val_loss did not improve from 0.04958
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0274 - accuracy: 0.9927 - val_loss: 0.0512 - val_accuracy: 0.9844
# Epoch 20/100
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9935
# Epoch 00020: val_loss improved from 0.04958 to 0.04800, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0258 - accuracy: 0.9935 - val_loss: 0.0480 - val_accuracy: 0.9859
# Epoch 21/100
# 1483/1500 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 0.9937
# Epoch 00021: val_loss improved from 0.04800 to 0.04620, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0247 - accuracy: 0.9937 - val_loss: 0.0462 - val_accuracy: 0.9868
# Epoch 22/100
# 1487/1500 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9946
# Epoch 00022: val_loss did not improve from 0.04620
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0231 - accuracy: 0.9946 - val_loss: 0.0470 - val_accuracy: 0.9862
# Epoch 23/100
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 0.9944
# Epoch 00023: val_loss improved from 0.04620 to 0.04558, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0221 - accuracy: 0.9943 - val_loss: 0.0456 - val_accuracy: 0.9862
# Epoch 24/100
# 1485/1500 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9947
# Epoch 00024: val_loss improved from 0.04558 to 0.04470, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0208 - accuracy: 0.9948 - val_loss: 0.0447 - val_accuracy: 0.9874
# Epoch 25/100
# 1496/1500 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9955
# Epoch 00025: val_loss improved from 0.04470 to 0.04453, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0196 - accuracy: 0.9955 - val_loss: 0.0445 - val_accuracy: 0.9872
# Epoch 26/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9954
# Epoch 00026: val_loss did not improve from 0.04453
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0188 - accuracy: 0.9954 - val_loss: 0.0452 - val_accuracy: 0.9870
# Epoch 27/100
# 1493/1500 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9959
# Epoch 00027: val_loss improved from 0.04453 to 0.04310, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0178 - accuracy: 0.9959 - val_loss: 0.0431 - val_accuracy: 0.9868
# Epoch 28/100
# 1497/1500 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9962
# Epoch 00028: val_loss did not improve from 0.04310
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0171 - accuracy: 0.9962 - val_loss: 0.0435 - val_accuracy: 0.9869
# Epoch 29/100
# 1492/1500 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9964
# Epoch 00029: val_loss did not improve from 0.04310
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0160 - accuracy: 0.9964 - val_loss: 0.0436 - val_accuracy: 0.9875
# Epoch 30/100
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9968
# Epoch 00030: val_loss improved from 0.04310 to 0.04275, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0154 - accuracy: 0.9968 - val_loss: 0.0427 - val_accuracy: 0.9874
# Epoch 31/100
# 1496/1500 [============================>.] - ETA: 0s - loss: 0.0147 - accuracy: 0.9969
# Epoch 00031: val_loss improved from 0.04275 to 0.04225, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0147 - accuracy: 0.9969 - val_loss: 0.0423 - val_accuracy: 0.9869
# Epoch 32/100
# 1498/1500 [============================>.] - ETA: 0s - loss: 0.0140 - accuracy: 0.9970
# Epoch 00032: val_loss improved from 0.04225 to 0.04219, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0140 - accuracy: 0.9970 - val_loss: 0.0422 - val_accuracy: 0.9872
# Epoch 33/100
# 1491/1500 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9974
# Epoch 00033: val_loss did not improve from 0.04219
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0133 - accuracy: 0.9974 - val_loss: 0.0426 - val_accuracy: 0.9872
# Epoch 34/100
# 1498/1500 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9976
# Epoch 00034: val_loss improved from 0.04219 to 0.04092, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0127 - accuracy: 0.9976 - val_loss: 0.0409 - val_accuracy: 0.9877
# Epoch 35/100
# 1493/1500 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9978
# Epoch 00035: val_loss improved from 0.04092 to 0.04075, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0121 - accuracy: 0.9978 - val_loss: 0.0408 - val_accuracy: 0.9875
# Epoch 36/100
# 1493/1500 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9978
# Epoch 00036: val_loss did not improve from 0.04075
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0117 - accuracy: 0.9978 - val_loss: 0.0411 - val_accuracy: 0.9872
# Epoch 37/100
# 1491/1500 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9981
# Epoch 00037: val_loss did not improve from 0.04075
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0111 - accuracy: 0.9981 - val_loss: 0.0414 - val_accuracy: 0.9883
# Epoch 38/100
# 1496/1500 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9981
# Epoch 00038: val_loss improved from 0.04075 to 0.04070, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0107 - accuracy: 0.9981 - val_loss: 0.0407 - val_accuracy: 0.9876
# Epoch 39/100
# 1492/1500 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9980
# Epoch 00039: val_loss did not improve from 0.04070
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0103 - accuracy: 0.9980 - val_loss: 0.0410 - val_accuracy: 0.9877
# Epoch 40/100
# 1488/1500 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 0.9984
# Epoch 00040: val_loss did not improve from 0.04070
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0098 - accuracy: 0.9984 - val_loss: 0.0417 - val_accuracy: 0.9873
# Epoch 41/100
# 1494/1500 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9984
# Epoch 00041: val_loss improved from 0.04070 to 0.03959, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0094 - accuracy: 0.9984 - val_loss: 0.0396 - val_accuracy: 0.9875
# Epoch 42/100
# 1499/1500 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 0.9985
# Epoch 00042: val_loss did not improve from 0.03959
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0091 - accuracy: 0.9985 - val_loss: 0.0406 - val_accuracy: 0.9877
# Epoch 43/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9987
# Epoch 00043: val_loss did not improve from 0.03959
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0087 - accuracy: 0.9987 - val_loss: 0.0410 - val_accuracy: 0.9876
# Epoch 44/100
# 1489/1500 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9988
# Epoch 00044: val_loss did not improve from 0.03959
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0083 - accuracy: 0.9987 - val_loss: 0.0402 - val_accuracy: 0.9876
# Epoch 45/100
# 1499/1500 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9989
# Epoch 00045: val_loss improved from 0.03959 to 0.03917, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0080 - accuracy: 0.9989 - val_loss: 0.0392 - val_accuracy: 0.9882
# Epoch 46/100
# 1498/1500 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9990
# Epoch 00046: val_loss did not improve from 0.03917
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0077 - accuracy: 0.9990 - val_loss: 0.0401 - val_accuracy: 0.9877
# Epoch 47/100
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9991
# Epoch 00047: val_loss did not improve from 0.03917
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.0402 - val_accuracy: 0.9876
# Epoch 48/100
# 1482/1500 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 0.9990
# Epoch 00048: val_loss did not improve from 0.03917
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0071 - accuracy: 0.9990 - val_loss: 0.0400 - val_accuracy: 0.9879
# Epoch 49/100
# 1499/1500 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9990
# Epoch 00049: val_loss did not improve from 0.03917
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0070 - accuracy: 0.9990 - val_loss: 0.0403 - val_accuracy: 0.9870
# Epoch 50/100
# 1499/1500 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9993
# Epoch 00050: val_loss did not improve from 0.03917
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0066 - accuracy: 0.9993 - val_loss: 0.0405 - val_accuracy: 0.9873
# Epoch 51/100
# 1485/1500 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9992
# Epoch 00051: val_loss did not improve from 0.03917
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0064 - accuracy: 0.9992 - val_loss: 0.0394 - val_accuracy: 0.9883
# Epoch 52/100
# 1500/1500 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9993
# Epoch 00052: val_loss did not improve from 0.03917
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0062 - accuracy: 0.9993 - val_loss: 0.0400 - val_accuracy: 0.9872
# Epoch 53/100
# 1491/1500 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9994
# Epoch 00053: val_loss did not improve from 0.03917
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0059 - accuracy: 0.9994 - val_loss: 0.0394 - val_accuracy: 0.9880
# Epoch 54/100
# 1500/1500 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9994
# Epoch 00054: val_loss improved from 0.03917 to 0.03910, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.0391 - val_accuracy: 0.9873
# Epoch 55/100
# 1500/1500 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9994
# Epoch 00055: val_loss did not improve from 0.03910
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0056 - accuracy: 0.9994 - val_loss: 0.0408 - val_accuracy: 0.9875
# Epoch 56/100
# 1489/1500 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9995
# Epoch 00056: val_loss did not improve from 0.03910
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0054 - accuracy: 0.9995 - val_loss: 0.0396 - val_accuracy: 0.9878
# Epoch 57/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9995
# Epoch 00057: val_loss did not improve from 0.03910
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0052 - accuracy: 0.9995 - val_loss: 0.0396 - val_accuracy: 0.9879
# Epoch 58/100
# 1483/1500 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9995
# Epoch 00058: val_loss did not improve from 0.03910
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0051 - accuracy: 0.9995 - val_loss: 0.0392 - val_accuracy: 0.9878
# Epoch 59/100
# 1500/1500 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9995
# Epoch 00059: val_loss did not improve from 0.03910
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0049 - accuracy: 0.9995 - val_loss: 0.0396 - val_accuracy: 0.9880
# Epoch 60/100
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.9996
# Epoch 00060: val_loss did not improve from 0.03910
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0047 - accuracy: 0.9996 - val_loss: 0.0391 - val_accuracy: 0.9878
# Epoch 61/100
# 1495/1500 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9996
# Epoch 00061: val_loss improved from 0.03910 to 0.03897, saving model to results/mnist\lenet.best.hdf5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0046 - accuracy: 0.9996 - val_loss: 0.0390 - val_accuracy: 0.9883
# Epoch 62/100
# 1488/1500 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9996
# Epoch 00062: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0044 - accuracy: 0.9996 - val_loss: 0.0394 - val_accuracy: 0.9878
# Epoch 63/100
# 1497/1500 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9997
# Epoch 00063: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.0394 - val_accuracy: 0.9881
# Epoch 64/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9996
# Epoch 00064: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0042 - accuracy: 0.9996 - val_loss: 0.0391 - val_accuracy: 0.9879
# Epoch 65/100
# 1494/1500 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9997
# Epoch 00065: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0.0393 - val_accuracy: 0.9880
# Epoch 66/100
# 1498/1500 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9996
# Epoch 00066: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.0390 - val_accuracy: 0.9884
# Epoch 67/100
# 1494/1500 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9997
# Epoch 00067: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.0397 - val_accuracy: 0.9882
# Epoch 68/100
# 1492/1500 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9997
# Epoch 00068: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.0396 - val_accuracy: 0.9877
# Epoch 69/100
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9998
# Epoch 00069: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0036 - accuracy: 0.9998 - val_loss: 0.0394 - val_accuracy: 0.9877
# Epoch 70/100
# 1494/1500 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9997
# Epoch 00070: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.0394 - val_accuracy: 0.9876
# Epoch 71/100
# 1488/1500 [============================>.] - ETA: 0s - loss: 0.0035 - accuracy: 0.9998
# Epoch 00071: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0035 - accuracy: 0.9998 - val_loss: 0.0393 - val_accuracy: 0.9877
# Epoch 72/100
# 1487/1500 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9997
# Epoch 00072: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.0395 - val_accuracy: 0.9877
# Epoch 73/100
# 1497/1500 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9997
# Epoch 00073: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.0391 - val_accuracy: 0.9887
# Epoch 74/100
# 1487/1500 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9998
# Epoch 00074: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0396 - val_accuracy: 0.9881
# Epoch 75/100
# 1486/1500 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9999
# Epoch 00075: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0031 - accuracy: 0.9999 - val_loss: 0.0390 - val_accuracy: 0.9878
# Epoch 76/100
# 1486/1500 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9998
# Epoch 00076: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0391 - val_accuracy: 0.9885
# Epoch 77/100
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9999
# Epoch 00077: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0030 - accuracy: 0.9999 - val_loss: 0.0393 - val_accuracy: 0.9875
# Epoch 78/100
# 1494/1500 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9998
# Epoch 00078: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0393 - val_accuracy: 0.9878
# Epoch 79/100
# 1496/1500 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9999
# Epoch 00079: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0028 - accuracy: 0.9999 - val_loss: 0.0397 - val_accuracy: 0.9878
# Epoch 80/100
# 1498/1500 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9999
# Epoch 00080: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.0395 - val_accuracy: 0.9879
# Epoch 81/100
# 1486/1500 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9999
# Epoch 00081: val_loss did not improve from 0.03897
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.0394 - val_accuracy: 0.9883

# %%
# Plot CV Results
pd.DataFrame(lenet_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(16,8))
sns.despine();

# %%
# evaluate test accuracy
lenet_accuracy = lenet5.evaluate(X_test.reshape(-1, 28, 28, 1), y_test, verbose=0)[1]
print('Test accuracy: {:.2%}'.format(lenet_accuracy))
# Out:
# Test accuracy: 98.99%
