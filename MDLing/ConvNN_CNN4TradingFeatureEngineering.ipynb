# %%
import warnings
warnings.filterwarnings('ignore')
from talib import (RSI, BBANDS, MACD, NATR, WILLR, WMA, EMA, SMA, CCI, CMO, MACD, PPO, ROC, ADOSC, ADX, MOM)
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.regression.rolling import RollingOLS
import statsmodels.api as sm
import pandas_datareader.data as web
import pandas as pd
import numpy as np
from pathlib import Path

# %matplotlib inline

DATA_STORE = 'data/assets.h5'
MONTH = 21
YEAR = 12 * MONTH
START = '2000-01-01'
END = '2022-12-31'

sns.set_style('whitegrid')
idx = pd.IndexSlice
T = [1, 5, 10, 21, 42, 63]

results_path = Path('results', 'cnn_for_trading')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %%
# Loading Quandl Wiki Stock Prices & Meta Data
adj_ohlcv = ['adj_open', 'adj_close', 'adj_low', 'adj_high', 'adj_volume']
with pd.HDFStore(DATA_STORE) as store:
    prices = (store['quandl/wiki/prices'].loc[idx[START:END, :], adj_ohlcv]
              .rename(columns=lambda x: x.replace('adj_', '')).swaplevel().sort_index().dropna())
    metadata = (store['us_equities/stocks'].loc[:, ['marketcap', 'sector']])
ohlcv = prices.columns.tolist()
prices.volume /= 1e3
prices.index.names = ['symbol', 'date']
metadata.index.name = 'symbol'

# %%
ohlcv
# Out:
# ['open', 'close', 'low', 'high', 'volume']

# %%
# Rolling universe: pick 500 most-traded stocks
dollar_vol = prices.close.mul(prices.volume).unstack('symbol').sort_index()
years = sorted(np.unique([d.year for d in prices.index.get_level_values('date').unique()]))
train_window = 5 # years
universe_size = 500

universe = []
for i, year in enumerate(years[5:], 5):
    start = str(years[i-5])
    end = str(years[i])
    most_traded = (dollar_vol.loc[start:end, :].dropna(thresh=1000, axis=1).median().nlargest(universe_size)
                   .index)
    universe.append(prices.loc[idx[most_traded, start:end], :])

universe = pd.concat(universe)
universe = universe.loc[~universe.index.duplicated()]
universe.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2576938 entries, ('BRK_A', Timestamp('2000-01-03 00:00:00')) to ('BWLD', Timestamp('2018-02-05 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    2576938 non-null  float64
#  1   close   2576938 non-null  float64
#  2   low     2576938 non-null  float64
#  3   high    2576938 non-null  float64
#  4   volume  2576938 non-null  float64
# dtypes: float64(5)
# memory usage: 108.3+ MB

# %%
universe.groupby('symbol').size().describe()
# Out:
# count     744.000000
# mean     3463.626344
# std      1173.658096
# min      1007.000000
# 25%      2323.000000
# 50%      3834.000000
# 75%      4586.000000
# max      4587.000000
# dtype: float64

# %%
universe.to_hdf('data/universe_data.h5', 'universe')

# %%
# Generate Technical Indicators Factors
T = list(range(6, 21))

# Relative Strength Index
for t in T:
    universe[f'{t:02}_RSI'] = universe.groupby(level='symbol').close.apply(RSI, timeperiod=t)

# Williams %R
for t in T:
    universe[f'{t:02}_WILLR'] = (universe.groupby(level='symbol', group_keys=False)
     .apply(lambda x: WILLR(x.high, x.low, x.close, timeperiod=t)))

# Compute Bollinger Bands
def compute_bb(close, timeperiod):
    high, mid, low = BBANDS(close, timeperiod=timeperiod)
    return pd.DataFrame({f'{timeperiod:02}_BBH': high, f'{timeperiod:02}_BBL': low}, index=close.index)
for t in T:
    bbh, bbl = f'{t:02}_BBH', f'{t:02}_BBL'
    universe = (universe.join(universe.groupby(level='symbol').close.apply(compute_bb, timeperiod=t)))
    universe[bbh] = universe[bbh].sub(universe.close).div(universe[bbh]).apply(np.log1p)
    universe[bbl] = universe.close.sub(universe[bbl]).div(universe.close).apply(np.log1p)

# %%
# Normalized Average True Range
for t in T:
    universe[f'{t:02}_NATR'] = universe.groupby(level='symbol', group_keys=False).apply(lambda x:
                                                        NATR(x.high, x.low, x.close, timeperiod=t))

# Percentage Price Oscillator
for t in T:
    universe[f'{t:02}_PPO'] = universe.groupby(level='symbol').close.apply(PPO, fastperiod=t, matype=1)

# Moving Average Convergence/Divergence
def compute_macd(close, signalperiod):
    macd = MACD(close, signalperiod=signalperiod)[0]
    return (macd - np.mean(macd))/np.std(macd)

for t in T:
    universe[f'{t:02}_MACD'] = (universe.groupby('symbol', group_keys=False).close
                  .apply(compute_macd, signalperiod=t))

# Momentum
for t in T:
    universe[f'{t:02}_MOM'] = universe.groupby(level='symbol').close.apply(MOM, timeperiod=t)

# %%
# Weighted Moving Average
for t in T:
    universe[f'{t:02}_WMA'] = universe.groupby(level='symbol').close.apply(WMA, timeperiod=t)

# Exponential Moving Average
for t in T:
    universe[f'{t:02}_EMA'] = universe.groupby(level='symbol').close.apply(EMA, timeperiod=t)

# Commodity Channel Index
for t in T:
    universe[f'{t:02}_CCI'] = (universe.groupby(level='symbol', group_keys=False)
     .apply(lambda x: CCI(x.high, x.low, x.close, timeperiod=t)))

# Chande Momentum Oscillator
for t in T:
    universe[f'{t:02}_CMO'] = universe.groupby(level='symbol').close.apply(CMO, timeperiod=t)

# %%
# Rate of Change
for t in T:
    universe[f'{t:02}_ROC'] = universe.groupby(level='symbol').close.apply(ROC, timeperiod=t)

# Chaikin A/D Oscillator
for t in T:
    universe[f'{t:02}_ADOSC'] = (universe.groupby(level='symbol', group_keys=False)
     .apply(lambda x: ADOSC(x.high, x.low, x.close, x.volume, fastperiod=t-3, slowperiod=4+t)))

# Average Directional Movement Index
for t in T:
    universe[f'{t:02}_ADX'] = universe.groupby(level='symbol', group_keys=False).apply(lambda x:
                                                        ADX(x.high, x.low, x.close, timeperiod=t))
universe.drop(ohlcv, axis=1).to_hdf('data/universe_data.h5', 'features')

# %%
# Compute Historical Returns
by_sym = universe.groupby(level='symbol').close
for t in [1,5]:
    universe[f'r{t:02}'] = by_sym.pct_change(t)

# Remove outliers
universe[[f'r{t:02}' for t in [1, 5]]].describe()
outliers = universe[universe.r01>1].index.get_level_values('symbol').unique()
print(f'outliers length: {len(outliers)}')
universe = universe.drop(outliers, level='symbol')
# Out:
# outliers length: 14

# %%
# Historical return quantiles
for t in [1, 5]:
    #  add dropna() function for empty axis call
    universe[f'r{t:02}dec'] = (universe[f'r{t:02}'].dropna().groupby(level='date')
             .apply(lambda x: pd.qcut(x, q=10, labels=False, duplicates='drop')))

# %%
# universe.to_hdf('data/temp_universe.h5', 'universe')
universe = pd.read_hdf('data/temp_universe.h5', 'universe')

# %%
factor_data = (web.DataReader('F-F_Research_Data_5_Factors_2x3_daily', 'famafrench',
                              start=START)[0].rename(columns={'Mkt-RF': 'Market'}))
factor_data.index.names = ['date']
factor_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5868 entries, 2000-01-03 to 2023-04-28
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Market  5868 non-null   float64
#  1   SMB     5868 non-null   float64
#  2   HML     5868 non-null   float64
#  3   RMW     5868 non-null   float64
#  4   CMA     5868 non-null   float64
#  5   RF      5868 non-null   float64
# dtypes: float64(6)
# memory usage: 320.9 KB

# %%
windows = list(range(15, 90, 5))
len(windows)
# Out:
# 15

# %%
t = 1
ret = f'r{t:02}'
factors = ['Market', 'SMB', 'HML', 'RMW', 'CMA']
windows = list(range(15, 90, 5))
for window in windows:
    # print(window)
    betas = []
    for symbol, data in universe.groupby(level='symbol'):
        print(f'Current Running Info - window: {window} | symbol: {symbol}')
        model_data = data[[ret]].merge(factor_data, on='date').dropna()
        model_data[ret] -= model_data.RF

        rolling_ols = RollingOLS(endog=model_data[ret],
                                 exog=sm.add_constant(model_data[factors]), window=window)
        factor_model = rolling_ols.fit(params_only=True).params.drop('const', axis=1)
        result = factor_model.assign(symbol=symbol).set_index('symbol', append=True)
        betas.append(result)
    betas = pd.concat(betas).rename(columns=lambda x: f'{window:02}_{x}')
    universe = universe.join(betas)
# Out:
# Current Running Info - window: 15 | symbol: A
# Current Running Info - window: 15 | symbol: AAL
# Current Running Info - window: 15 | symbol: AAP
# Current Running Info - window: 15 | symbol: AAPL
# Current Running Info - window: 15 | symbol: ABBV
# Current Running Info - window: 15 | symbol: ABC
# Current Running Info - window: 15 | symbol: ABT
# Current Running Info - window: 15 | symbol: ACAS
# Current Running Info - window: 15 | symbol: ACE
# Current Running Info - window: 15 | symbol: ACI
# Current Running Info - window: 15 | symbol: ACN
# Current Running Info - window: 15 | symbol: ACXM
# Current Running Info - window: 15 | symbol: ADBE
# Current Running Info - window: 15 | symbol: ADI
# Current Running Info - window: 15 | symbol: ADM
# Current Running Info - window: 15 | symbol: ADP
# Current Running Info - window: 15 | symbol: ADS
# Current Running Info - window: 15 | symbol: ADSK
# Current Running Info - window: 15 | symbol: ADTN
# Current Running Info - window: 15 | symbol: AEE
# Current Running Info - window: 15 | symbol: AEO
# Current Running Info - window: 15 | symbol: AEP
# Current Running Info - window: 15 | symbol: AES
# Current Running Info - window: 15 | symbol: AET
# Current Running Info - window: 15 | symbol: AFFX
# Current Running Info - window: 15 | symbol: AFL
# Current Running Info - window: 15 | symbol: AGCO
# Current Running Info - window: 15 | symbol: AGN
# Current Running Info - window: 15 | symbol: AGNC
# Current Running Info - window: 15 | symbol: AIG
# Current Running Info - window: 15 | symbol: AIZ
# Current Running Info - window: 15 | symbol: AKAM
# Current Running Info - window: 15 | symbol: AKS
# Current Running Info - window: 15 | symbol: ALB
# Current Running Info - window: 15 | symbol: ALK
# Current Running Info - window: 15 | symbol: ALKS
# Current Running Info - window: 15 | symbol: ALL
# Current Running Info - window: 15 | symbol: ALTR
# Current Running Info - window: 15 | symbol: ALXN
# Current Running Info - window: 15 | symbol: AMAT
# Current Running Info - window: 15 | symbol: AMCC
# Current Running Info - window: 15 | symbol: AMD
# Current Running Info - window: 15 | symbol: AMG
# Current Running Info - window: 15 | symbol: AMGN
# Current Running Info - window: 15 | symbol: AMKR
# Current Running Info - window: 15 | symbol: AMP
# Current Running Info - window: 15 | symbol: AMT
# Current Running Info - window: 15 | symbol: AMTD
# Current Running Info - window: 15 | symbol: AMZN
# Current Running Info - window: 15 | symbol: AN
# Current Running Info - window: 15 | symbol: ANF
# Current Running Info - window: 15 | symbol: ANN
# Current Running Info - window: 15 | symbol: ANR
# Current Running Info - window: 15 | symbol: ANTM
# Current Running Info - window: 15 | symbol: AON
# Current Running Info - window: 15 | symbol: APA
# Current Running Info - window: 15 | symbol: APC
# Current Running Info - window: 15 | symbol: APD
# Current Running Info - window: 15 | symbol: APH
# Current Running Info - window: 15 | symbol: APOL
# Current Running Info - window: 15 | symbol: ARNC
# Current Running Info - window: 15 | symbol: ARO
# Current Running Info - window: 15 | symbol: ARW
# Current Running Info - window: 15 | symbol: ASH
# Current Running Info - window: 15 | symbol: ATI
# Current Running Info - window: 15 | symbol: ATK
# Current Running Info - window: 15 | symbol: ATML
# Current Running Info - window: 15 | symbol: ATVI
# Current Running Info - window: 15 | symbol: AVB
# Current Running Info - window: 15 | symbol: AVGO
# Current Running Info - window: 15 | symbol: AVP
# Current Running Info - window: 15 | symbol: AVT
# Current Running Info - window: 15 | symbol: AVY
# Current Running Info - window: 15 | symbol: AXP
# Current Running Info - window: 15 | symbol: AYI
# Current Running Info - window: 15 | symbol: AZO
# Current Running Info - window: 15 | symbol: BA
# Current Running Info - window: 15 | symbol: BAC
# Current Running Info - window: 15 | symbol: BAX
# Current Running Info - window: 15 | symbol: BBBY
# Current Running Info - window: 15 | symbol: BBT
# Current Running Info - window: 15 | symbol: BBY
# Current Running Info - window: 15 | symbol: BC
# Current Running Info - window: 15 | symbol: BCR
# Current Running Info - window: 15 | symbol: BDX
# Current Running Info - window: 15 | symbol: BEAM
# Current Running Info - window: 15 | symbol: BEN
# Current Running Info - window: 15 | symbol: BG
# Current Running Info - window: 15 | symbol: BHI
# Current Running Info - window: 15 | symbol: BIDU
# Current Running Info - window: 15 | symbol: BIG
# Current Running Info - window: 15 | symbol: BIIB
# Current Running Info - window: 15 | symbol: BK
# Current Running Info - window: 15 | symbol: BLK
# Current Running Info - window: 15 | symbol: BLL
# Current Running Info - window: 15 | symbol: BMRN
# Current Running Info - window: 15 | symbol: BMY
# Current Running Info - window: 15 | symbol: BP
# Current Running Info - window: 15 | symbol: BRCD
# Current Running Info - window: 15 | symbol: BRCM
# Current Running Info - window: 15 | symbol: BRK_A
# Current Running Info - window: 15 | symbol: BRK_B
# Current Running Info - window: 15 | symbol: BSX
# Current Running Info - window: 15 | symbol: BURL
# Current Running Info - window: 15 | symbol: BWA
# Current Running Info - window: 15 | symbol: BWLD
# Current Running Info - window: 15 | symbol: BXP
# Current Running Info - window: 15 | symbol: BYD
# Current Running Info - window: 15 | symbol: BZH
# Current Running Info - window: 15 | symbol: C
# Current Running Info - window: 15 | symbol: CA
# Current Running Info - window: 15 | symbol: CACI
# Current Running Info - window: 15 | symbol: CAG
# Current Running Info - window: 15 | symbol: CAH
# Current Running Info - window: 15 | symbol: CAKE
# Current Running Info - window: 15 | symbol: CAM
# Current Running Info - window: 15 | symbol: CAR
# Current Running Info - window: 15 | symbol: CAT
# Current Running Info - window: 15 | symbol: CB
# Current Running Info - window: 15 | symbol: CBG
# Current Running Info - window: 15 | symbol: CBI
# Current Running Info - window: 15 | symbol: CBRL
# Current Running Info - window: 15 | symbol: CCE
# Current Running Info - window: 15 | symbol: CCI
# Current Running Info - window: 15 | symbol: CCL
# Current Running Info - window: 15 | symbol: CCMP
# Current Running Info - window: 15 | symbol: CDE
# Current Running Info - window: 15 | symbol: CDNS
# Current Running Info - window: 15 | symbol: CE
# Current Running Info - window: 15 | symbol: CECO
# Current Running Info - window: 15 | symbol: CELG
# Current Running Info - window: 15 | symbol: CERN
# Current Running Info - window: 15 | symbol: CF
# Current Running Info - window: 15 | symbol: CFN
# Current Running Info - window: 15 | symbol: CHK
# Current Running Info - window: 15 | symbol: CHKP
# Current Running Info - window: 15 | symbol: CHRW
# Current Running Info - window: 15 | symbol: CHS
# Current Running Info - window: 15 | symbol: CHTR
# Current Running Info - window: 15 | symbol: CI
# Current Running Info - window: 15 | symbol: CIEN
# Current Running Info - window: 15 | symbol: CIT
# Current Running Info - window: 15 | symbol: CL
# Current Running Info - window: 15 | symbol: CLF
# Current Running Info - window: 15 | symbol: CLR
# Current Running Info - window: 15 | symbol: CLX
# Current Running Info - window: 15 | symbol: CMA
# Current Running Info - window: 15 | symbol: CMCSA
# Current Running Info - window: 15 | symbol: CMCSK
# Current Running Info - window: 15 | symbol: CME
# Current Running Info - window: 15 | symbol: CMG
# Current Running Info - window: 15 | symbol: CMI
# Current Running Info - window: 15 | symbol: CMS
# Current Running Info - window: 15 | symbol: CNC
# Current Running Info - window: 15 | symbol: CNO
# Current Running Info - window: 15 | symbol: CNP
# Current Running Info - window: 15 | symbol: CNW
# Current Running Info - window: 15 | symbol: CNX
# Current Running Info - window: 15 | symbol: COCO
# Current Running Info - window: 15 | symbol: COF
# Current Running Info - window: 15 | symbol: COG
# Current Running Info - window: 15 | symbol: COH
# Current Running Info - window: 15 | symbol: COL
# Current Running Info - window: 15 | symbol: COLM
# Current Running Info - window: 15 | symbol: COP
# Current Running Info - window: 15 | symbol: COST
# Current Running Info - window: 15 | symbol: COV
# Current Running Info - window: 15 | symbol: CPB
# Current Running Info - window: 15 | symbol: CPN
# Current Running Info - window: 15 | symbol: CPWR
# Current Running Info - window: 15 | symbol: CREE
# Current Running Info - window: 15 | symbol: CRL
# Current Running Info - window: 15 | symbol: CRM
# Current Running Info - window: 15 | symbol: CSC
# Current Running Info - window: 15 | symbol: CSCO
# Current Running Info - window: 15 | symbol: CSX
# Current Running Info - window: 15 | symbol: CTAS
# Current Running Info - window: 15 | symbol: CTL
# Current Running Info - window: 15 | symbol: CTSH
# Current Running Info - window: 15 | symbol: CTXS
# Current Running Info - window: 15 | symbol: CVC
# Current Running Info - window: 15 | symbol: CVG
# Current Running Info - window: 15 | symbol: CVS
# Current Running Info - window: 15 | symbol: CVX
# Current Running Info - window: 15 | symbol: CXO
# Current Running Info - window: 15 | symbol: CY
# Current Running Info - window: 15 | symbol: CYH
# Current Running Info - window: 15 | symbol: D
# Current Running Info - window: 15 | symbol: DAL
# Current Running Info - window: 15 | symbol: DATA
# Current Running Info - window: 15 | symbol: DD
# Current Running Info - window: 15 | symbol: DE
# Current Running Info - window: 15 | symbol: DECK
# Current Running Info - window: 15 | symbol: DF
# Current Running Info - window: 15 | symbol: DFS
# Current Running Info - window: 15 | symbol: DG
# Current Running Info - window: 15 | symbol: DGX
# Current Running Info - window: 15 | symbol: DHI
# Current Running Info - window: 15 | symbol: DHR
# Current Running Info - window: 15 | symbol: DIS
# Current Running Info - window: 15 | symbol: DISCA
# Current Running Info - window: 15 | symbol: DISH
# Current Running Info - window: 15 | symbol: DKS
# Current Running Info - window: 15 | symbol: DLPH
# Current Running Info - window: 15 | symbol: DLR
# Current Running Info - window: 15 | symbol: DLTR
# Current Running Info - window: 15 | symbol: DNR
# Current Running Info - window: 15 | symbol: DO
# Current Running Info - window: 15 | symbol: DOV
# Current Running Info - window: 15 | symbol: DOW
# Current Running Info - window: 15 | symbol: DOX
# Current Running Info - window: 15 | symbol: DPS
# Current Running Info - window: 15 | symbol: DRI
# Current Running Info - window: 15 | symbol: DRIV
# Current Running Info - window: 15 | symbol: DRL
# Current Running Info - window: 15 | symbol: DST
# Current Running Info - window: 15 | symbol: DTE
# Current Running Info - window: 15 | symbol: DTV
# Current Running Info - window: 15 | symbol: DUK
# Current Running Info - window: 15 | symbol: DVA
# Current Running Info - window: 15 | symbol: DVN
# Current Running Info - window: 15 | symbol: EA
# Current Running Info - window: 15 | symbol: EAT
# Current Running Info - window: 15 | symbol: EBAY
# Current Running Info - window: 15 | symbol: ECL
# Current Running Info - window: 15 | symbol: ED
# Current Running Info - window: 15 | symbol: EFII
# Current Running Info - window: 15 | symbol: EIX
# Current Running Info - window: 15 | symbol: EL
# Current Running Info - window: 15 | symbol: ELX
# Current Running Info - window: 15 | symbol: EMC
# Current Running Info - window: 15 | symbol: EMN
# Current Running Info - window: 15 | symbol: EMR
# Current Running Info - window: 15 | symbol: ENDP
# Current Running Info - window: 15 | symbol: ENR
# Current Running Info - window: 15 | symbol: EOG
# Current Running Info - window: 15 | symbol: EQIX
# Current Running Info - window: 15 | symbol: EQR
# Current Running Info - window: 15 | symbol: EQT
# Current Running Info - window: 15 | symbol: ES
# Current Running Info - window: 15 | symbol: ESI
# Current Running Info - window: 15 | symbol: ESRX
# Current Running Info - window: 15 | symbol: ESS
# Current Running Info - window: 15 | symbol: ESV
# Current Running Info - window: 15 | symbol: ETFC
# Current Running Info - window: 15 | symbol: ETN
# Current Running Info - window: 15 | symbol: ETR
# Current Running Info - window: 15 | symbol: EW
# Current Running Info - window: 15 | symbol: EXC
# Current Running Info - window: 15 | symbol: EXPD
# Current Running Info - window: 15 | symbol: EXPE
# Current Running Info - window: 15 | symbol: EXTR
# Current Running Info - window: 15 | symbol: F
# Current Running Info - window: 15 | symbol: FANG
# Current Running Info - window: 15 | symbol: FAST
# Current Running Info - window: 15 | symbol: FB
# Current Running Info - window: 15 | symbol: FCS
# Current Running Info - window: 15 | symbol: FCX
# Current Running Info - window: 15 | symbol: FDO
# Current Running Info - window: 15 | symbol: FDX
# Current Running Info - window: 15 | symbol: FE
# Current Running Info - window: 15 | symbol: FFIV
# Current Running Info - window: 15 | symbol: FICO
# Current Running Info - window: 15 | symbol: FIS
# Current Running Info - window: 15 | symbol: FISV
# Current Running Info - window: 15 | symbol: FITB
# Current Running Info - window: 15 | symbol: FL
# Current Running Info - window: 15 | symbol: FLR
# Current Running Info - window: 15 | symbol: FLS
# Current Running Info - window: 15 | symbol: FLT
# Current Running Info - window: 15 | symbol: FMD
# Current Running Info - window: 15 | symbol: FNF
# Current Running Info - window: 15 | symbol: FOSL
# Current Running Info - window: 15 | symbol: FOX
# Current Running Info - window: 15 | symbol: FOXA
# Current Running Info - window: 15 | symbol: FRX
# Current Running Info - window: 15 | symbol: FST
# Current Running Info - window: 15 | symbol: FTI
# Current Running Info - window: 15 | symbol: GCI
# Current Running Info - window: 15 | symbol: GD
# Current Running Info - window: 15 | symbol: GE
# Current Running Info - window: 15 | symbol: GILD
# Current Running Info - window: 15 | symbol: GIS
# Current Running Info - window: 15 | symbol: GLW
# Current Running Info - window: 15 | symbol: GM
# Current Running Info - window: 15 | symbol: GMCR
# Current Running Info - window: 15 | symbol: GME
# Current Running Info - window: 15 | symbol: GNTX
# Current Running Info - window: 15 | symbol: GNW
# Current Running Info - window: 15 | symbol: GOLD
# Current Running Info - window: 15 | symbol: GOOG
# Current Running Info - window: 15 | symbol: GOOGL
# Current Running Info - window: 15 | symbol: GPN
# Current Running Info - window: 15 | symbol: GPOR
# Current Running Info - window: 15 | symbol: GPS
# Current Running Info - window: 15 | symbol: GRMN
# Current Running Info - window: 15 | symbol: GRPN
# Current Running Info - window: 15 | symbol: GS
# Current Running Info - window: 15 | symbol: GT
# Current Running Info - window: 15 | symbol: GWW
# Current Running Info - window: 15 | symbol: HAL
# Current Running Info - window: 15 | symbol: HAR
# Current Running Info - window: 15 | symbol: HAS
# Current Running Info - window: 15 | symbol: HBAN
# Current Running Info - window: 15 | symbol: HBI
# Current Running Info - window: 15 | symbol: HCA
# Current Running Info - window: 15 | symbol: HCBK
# Current Running Info - window: 15 | symbol: HCN
# Current Running Info - window: 15 | symbol: HCP
# Current Running Info - window: 15 | symbol: HD
# Current Running Info - window: 15 | symbol: HES
# Current Running Info - window: 15 | symbol: HFC
# Current Running Info - window: 15 | symbol: HLF
# Current Running Info - window: 15 | symbol: HLX
# Current Running Info - window: 15 | symbol: HNT
# Current Running Info - window: 15 | symbol: HOG
# Current Running Info - window: 15 | symbol: HOLX
# Current Running Info - window: 15 | symbol: HON
# Current Running Info - window: 15 | symbol: HOT
# Current Running Info - window: 15 | symbol: HOV
# Current Running Info - window: 15 | symbol: HP
# Current Running Info - window: 15 | symbol: HPQ
# Current Running Info - window: 15 | symbol: HRB
# Current Running Info - window: 15 | symbol: HRS
# Current Running Info - window: 15 | symbol: HSH
# Current Running Info - window: 15 | symbol: HSIC
# Current Running Info - window: 15 | symbol: HSP
# Current Running Info - window: 15 | symbol: HST
# Current Running Info - window: 15 | symbol: HSY
# Current Running Info - window: 15 | symbol: HTZ
# Current Running Info - window: 15 | symbol: HUM
# Current Running Info - window: 15 | symbol: IACI
# Current Running Info - window: 15 | symbol: IBM
# Current Running Info - window: 15 | symbol: ICE
# Current Running Info - window: 15 | symbol: IDTI
# Current Running Info - window: 15 | symbol: IGT
# Current Running Info - window: 15 | symbol: ILMN
# Current Running Info - window: 15 | symbol: INCY
# Current Running Info - window: 15 | symbol: INTC
# Current Running Info - window: 15 | symbol: INTU
# Current Running Info - window: 15 | symbol: IP
# Current Running Info - window: 15 | symbol: IPG
# Current Running Info - window: 15 | symbol: IR
# Current Running Info - window: 15 | symbol: IRF
# Current Running Info - window: 15 | symbol: ISIL
# Current Running Info - window: 15 | symbol: ISRG
# Current Running Info - window: 15 | symbol: ITT
# Current Running Info - window: 15 | symbol: ITW
# Current Running Info - window: 15 | symbol: IVZ
# Current Running Info - window: 15 | symbol: JBHT
# Current Running Info - window: 15 | symbol: JBL
# Current Running Info - window: 15 | symbol: JBLU
# Current Running Info - window: 15 | symbol: JCI
# Current Running Info - window: 15 | symbol: JCP
# Current Running Info - window: 15 | symbol: JDSU
# Current Running Info - window: 15 | symbol: JEC
# Current Running Info - window: 15 | symbol: JNJ
# Current Running Info - window: 15 | symbol: JNPR
# Current Running Info - window: 15 | symbol: JNS
# Current Running Info - window: 15 | symbol: JNY
# Current Running Info - window: 15 | symbol: JOE
# Current Running Info - window: 15 | symbol: JOY
# Current Running Info - window: 15 | symbol: JPM
# Current Running Info - window: 15 | symbol: JWN
# Current Running Info - window: 15 | symbol: K
# Current Running Info - window: 15 | symbol: KBH
# Current Running Info - window: 15 | symbol: KBR
# Current Running Info - window: 15 | symbol: KEY
# Current Running Info - window: 15 | symbol: KIM
# Current Running Info - window: 15 | symbol: KKD
# Current Running Info - window: 15 | symbol: KLAC
# Current Running Info - window: 15 | symbol: KMB
# Current Running Info - window: 15 | symbol: KMI
# Current Running Info - window: 15 | symbol: KMX
# Current Running Info - window: 15 | symbol: KO
# Current Running Info - window: 15 | symbol: KORS
# Current Running Info - window: 15 | symbol: KR
# Current Running Info - window: 15 | symbol: KSS
# Current Running Info - window: 15 | symbol: KSU
# Current Running Info - window: 15 | symbol: KWK
# Current Running Info - window: 15 | symbol: L
# Current Running Info - window: 15 | symbol: LAMR
# Current Running Info - window: 15 | symbol: LB
# Current Running Info - window: 15 | symbol: LBTYA
# Current Running Info - window: 15 | symbol: LEA
# Current Running Info - window: 15 | symbol: LEN
# Current Running Info - window: 15 | symbol: LH
# Current Running Info - window: 15 | symbol: LINTA
# Current Running Info - window: 15 | symbol: LLL
# Current Running Info - window: 15 | symbol: LLTC
# Current Running Info - window: 15 | symbol: LLY
# Current Running Info - window: 15 | symbol: LM
# Current Running Info - window: 15 | symbol: LMT
# Current Running Info - window: 15 | symbol: LNC
# Current Running Info - window: 15 | symbol: LNG
# Current Running Info - window: 15 | symbol: LNKD
# Current Running Info - window: 15 | symbol: LO
# Current Running Info - window: 15 | symbol: LOW
# Current Running Info - window: 15 | symbol: LPNT
# Current Running Info - window: 15 | symbol: LPX
# Current Running Info - window: 15 | symbol: LRCX
# Current Running Info - window: 15 | symbol: LSCC
# Current Running Info - window: 15 | symbol: LUV
# Current Running Info - window: 15 | symbol: LVLT
# Current Running Info - window: 15 | symbol: LVS
# Current Running Info - window: 15 | symbol: LXK
# Current Running Info - window: 15 | symbol: LYB
# Current Running Info - window: 15 | symbol: M
# Current Running Info - window: 15 | symbol: MA
# Current Running Info - window: 15 | symbol: MAN
# Current Running Info - window: 15 | symbol: MAR
# Current Running Info - window: 15 | symbol: MAS
# Current Running Info - window: 15 | symbol: MAT
# Current Running Info - window: 15 | symbol: MBI
# Current Running Info - window: 15 | symbol: MCD
# Current Running Info - window: 15 | symbol: MCHP
# Current Running Info - window: 15 | symbol: MCK
# Current Running Info - window: 15 | symbol: MCO
# Current Running Info - window: 15 | symbol: MCP
# Current Running Info - window: 15 | symbol: MCRL
# Current Running Info - window: 15 | symbol: MDC
# Current Running Info - window: 15 | symbol: MDLZ
# Current Running Info - window: 15 | symbol: MDR
# Current Running Info - window: 15 | symbol: MDT
# Current Running Info - window: 15 | symbol: MET
# Current Running Info - window: 15 | symbol: MGM
# Current Running Info - window: 15 | symbol: MHFI
# Current Running Info - window: 15 | symbol: MHK
# Current Running Info - window: 15 | symbol: MJN
# Current Running Info - window: 15 | symbol: MLM
# Current Running Info - window: 15 | symbol: MMC
# Current Running Info - window: 15 | symbol: MMM
# Current Running Info - window: 15 | symbol: MNK
# Current Running Info - window: 15 | symbol: MNST
# Current Running Info - window: 15 | symbol: MO
# Current Running Info - window: 15 | symbol: MON
# Current Running Info - window: 15 | symbol: MOS
# Current Running Info - window: 15 | symbol: MPC
# Current Running Info - window: 15 | symbol: MRK
# Current Running Info - window: 15 | symbol: MRO
# Current Running Info - window: 15 | symbol: MRVL
# Current Running Info - window: 15 | symbol: MS
# Current Running Info - window: 15 | symbol: MSFT
# Current Running Info - window: 15 | symbol: MSI
# Current Running Info - window: 15 | symbol: MSTR
# Current Running Info - window: 15 | symbol: MTB
# Current Running Info - window: 15 | symbol: MTG
# Current Running Info - window: 15 | symbol: MU
# Current Running Info - window: 15 | symbol: MUR
# Current Running Info - window: 15 | symbol: MWV
# Current Running Info - window: 15 | symbol: MWW
# Current Running Info - window: 15 | symbol: MXIM
# Current Running Info - window: 15 | symbol: MYL
# Current Running Info - window: 15 | symbol: NAV
# Current Running Info - window: 15 | symbol: NBIX
# Current Running Info - window: 15 | symbol: NBL
# Current Running Info - window: 15 | symbol: NBR
# Current Running Info - window: 15 | symbol: NDAQ
# Current Running Info - window: 15 | symbol: NE
# Current Running Info - window: 15 | symbol: NEE
# Current Running Info - window: 15 | symbol: NEM
# Current Running Info - window: 15 | symbol: NFLX
# Current Running Info - window: 15 | symbol: NFX
# Current Running Info - window: 15 | symbol: NKE
# Current Running Info - window: 15 | symbol: NKTR
# Current Running Info - window: 15 | symbol: NLSN
# Current Running Info - window: 15 | symbol: NLY
# Current Running Info - window: 15 | symbol: NOC
# Current Running Info - window: 15 | symbol: NOV
# Current Running Info - window: 15 | symbol: NOW
# Current Running Info - window: 15 | symbol: NRG
# Current Running Info - window: 15 | symbol: NSC
# Current Running Info - window: 15 | symbol: NTAP
# Current Running Info - window: 15 | symbol: NTRS
# Current Running Info - window: 15 | symbol: NU
# Current Running Info - window: 15 | symbol: NUAN
# Current Running Info - window: 15 | symbol: NUE
# Current Running Info - window: 15 | symbol: NVDA
# Current Running Info - window: 15 | symbol: NVR
# Current Running Info - window: 15 | symbol: NWL
# Current Running Info - window: 15 | symbol: NYT
# Current Running Info - window: 15 | symbol: O
# Current Running Info - window: 15 | symbol: OAS
# Current Running Info - window: 15 | symbol: OCR
# Current Running Info - window: 15 | symbol: ODP
# Current Running Info - window: 15 | symbol: OI
# Current Running Info - window: 15 | symbol: OKE
# Current Running Info - window: 15 | symbol: OMC
# Current Running Info - window: 15 | symbol: ONNN
# Current Running Info - window: 15 | symbol: ORCL
# Current Running Info - window: 15 | symbol: ORLY
# Current Running Info - window: 15 | symbol: OVTI
# Current Running Info - window: 15 | symbol: OXY
# Current Running Info - window: 15 | symbol: P
# Current Running Info - window: 15 | symbol: PANW
# Current Running Info - window: 15 | symbol: PAYX
# Current Running Info - window: 15 | symbol: PBCT
# Current Running Info - window: 15 | symbol: PBI
# Current Running Info - window: 15 | symbol: PCAR
# Current Running Info - window: 15 | symbol: PCG
# Current Running Info - window: 15 | symbol: PCL
# Current Running Info - window: 15 | symbol: PCLN
# Current Running Info - window: 15 | symbol: PCP
# Current Running Info - window: 15 | symbol: PDCO
# Current Running Info - window: 15 | symbol: PEG
# Current Running Info - window: 15 | symbol: PENN
# Current Running Info - window: 15 | symbol: PEP
# Current Running Info - window: 15 | symbol: PETM
# Current Running Info - window: 15 | symbol: PFE
# Current Running Info - window: 15 | symbol: PFG
# Current Running Info - window: 15 | symbol: PG
# Current Running Info - window: 15 | symbol: PGR
# Current Running Info - window: 15 | symbol: PH
# Current Running Info - window: 15 | symbol: PHM
# Current Running Info - window: 15 | symbol: PII
# Current Running Info - window: 15 | symbol: PKI
# Current Running Info - window: 15 | symbol: PLCM
# Current Running Info - window: 15 | symbol: PLD
# Current Running Info - window: 15 | symbol: PM
# Current Running Info - window: 15 | symbol: PMCS
# Current Running Info - window: 15 | symbol: PNC
# Current Running Info - window: 15 | symbol: PNR
# Current Running Info - window: 15 | symbol: PNRA
# Current Running Info - window: 15 | symbol: PPG
# Current Running Info - window: 15 | symbol: PPL
# Current Running Info - window: 15 | symbol: PRGO
# Current Running Info - window: 15 | symbol: PRU
# Current Running Info - window: 15 | symbol: PSA
# Current Running Info - window: 15 | symbol: PSUN
# Current Running Info - window: 15 | symbol: PSX
# Current Running Info - window: 15 | symbol: PTEN
# Current Running Info - window: 15 | symbol: PVH
# Current Running Info - window: 15 | symbol: PWR
# Current Running Info - window: 15 | symbol: PX
# Current Running Info - window: 15 | symbol: PXD
# Current Running Info - window: 15 | symbol: QCOM
# Current Running Info - window: 15 | symbol: QEP
# Current Running Info - window: 15 | symbol: QLGC
# Current Running Info - window: 15 | symbol: RAD
# Current Running Info - window: 15 | symbol: RAI
# Current Running Info - window: 15 | symbol: RAX
# Current Running Info - window: 15 | symbol: RCII
# Current Running Info - window: 15 | symbol: RCL
# Current Running Info - window: 15 | symbol: RDC
# Current Running Info - window: 15 | symbol: RDN
# Current Running Info - window: 15 | symbol: RE
# Current Running Info - window: 15 | symbol: REGN
# Current Running Info - window: 15 | symbol: RF
# Current Running Info - window: 15 | symbol: RFMD
# Current Running Info - window: 15 | symbol: RH
# Current Running Info - window: 15 | symbol: RHI
# Current Running Info - window: 15 | symbol: RHT
# Current Running Info - window: 15 | symbol: RIG
# Current Running Info - window: 15 | symbol: RL
# Current Running Info - window: 15 | symbol: RMBS
# Current Running Info - window: 15 | symbol: RNR
# Current Running Info - window: 15 | symbol: ROK
# Current Running Info - window: 15 | symbol: ROP
# Current Running Info - window: 15 | symbol: ROST
# Current Running Info - window: 15 | symbol: ROVI
# Current Running Info - window: 15 | symbol: RRC
# Current Running Info - window: 15 | symbol: RS
# Current Running Info - window: 15 | symbol: RSG
# Current Running Info - window: 15 | symbol: RSH
# Current Running Info - window: 15 | symbol: RTN
# Current Running Info - window: 15 | symbol: RVBD
# Current Running Info - window: 15 | symbol: RYL
# Current Running Info - window: 15 | symbol: S
# Current Running Info - window: 15 | symbol: SANM
# Current Running Info - window: 15 | symbol: SBAC
# Current Running Info - window: 15 | symbol: SBUX
# Current Running Info - window: 15 | symbol: SCCO
# Current Running Info - window: 15 | symbol: SCHW
# Current Running Info - window: 15 | symbol: SE
# Current Running Info - window: 15 | symbol: SEE
# Current Running Info - window: 15 | symbol: SEIC
# Current Running Info - window: 15 | symbol: SHLD
# Current Running Info - window: 15 | symbol: SHW
# Current Running Info - window: 15 | symbol: SIAL
# Current Running Info - window: 15 | symbol: SIG
# Current Running Info - window: 15 | symbol: SIRI
# Current Running Info - window: 15 | symbol: SIVB
# Current Running Info - window: 15 | symbol: SJM
# Current Running Info - window: 15 | symbol: SLAB
# Current Running Info - window: 15 | symbol: SLB
# Current Running Info - window: 15 | symbol: SLG
# Current Running Info - window: 15 | symbol: SLM
# Current Running Info - window: 15 | symbol: SM
# Current Running Info - window: 15 | symbol: SMTC
# Current Running Info - window: 15 | symbol: SNDK
# Current Running Info - window: 15 | symbol: SNI
# Current Running Info - window: 15 | symbol: SNPS
# Current Running Info - window: 15 | symbol: SNV
# Current Running Info - window: 15 | symbol: SO
# Current Running Info - window: 15 | symbol: SONS
# Current Running Info - window: 15 | symbol: SPF
# Current Running Info - window: 15 | symbol: SPG
# Current Running Info - window: 15 | symbol: SPLK
# Current Running Info - window: 15 | symbol: SPLS
# Current Running Info - window: 15 | symbol: SPW
# Current Running Info - window: 15 | symbol: SPWR
# Current Running Info - window: 15 | symbol: SRCL
# Current Running Info - window: 15 | symbol: SRE
# Current Running Info - window: 15 | symbol: STI
# Current Running Info - window: 15 | symbol: STJ
# Current Running Info - window: 15 | symbol: STLD
# Current Running Info - window: 15 | symbol: STR
# Current Running Info - window: 15 | symbol: STT
# Current Running Info - window: 15 | symbol: STX
# Current Running Info - window: 15 | symbol: STZ
# Current Running Info - window: 15 | symbol: SUNE
# Current Running Info - window: 15 | symbol: SVU
# Current Running Info - window: 15 | symbol: SWK
# Current Running Info - window: 15 | symbol: SWKS
# Current Running Info - window: 15 | symbol: SWN
# Current Running Info - window: 15 | symbol: SWY
# Current Running Info - window: 15 | symbol: SYK
# Current Running Info - window: 15 | symbol: SYMC
# Current Running Info - window: 15 | symbol: SYY
# Current Running Info - window: 15 | symbol: T
# Current Running Info - window: 15 | symbol: TAP
# Current Running Info - window: 15 | symbol: TDC
# Current Running Info - window: 15 | symbol: TDG
# Current Running Info - window: 15 | symbol: TDS
# Current Running Info - window: 15 | symbol: TDW
# Current Running Info - window: 15 | symbol: TECD
# Current Running Info - window: 15 | symbol: TEL
# Current Running Info - window: 15 | symbol: TER
# Current Running Info - window: 15 | symbol: TEX
# Current Running Info - window: 15 | symbol: TGNA
# Current Running Info - window: 15 | symbol: TGT
# Current Running Info - window: 15 | symbol: THC
# Current Running Info - window: 15 | symbol: TIBX
# Current Running Info - window: 15 | symbol: TIF
# Current Running Info - window: 15 | symbol: TIVO
# Current Running Info - window: 15 | symbol: TJX
# Current Running Info - window: 15 | symbol: TMK
# Current Running Info - window: 15 | symbol: TMO
# Current Running Info - window: 15 | symbol: TMUS
# Current Running Info - window: 15 | symbol: TOL
# Current Running Info - window: 15 | symbol: TQNT
# Current Running Info - window: 15 | symbol: TRIP
# Current Running Info - window: 15 | symbol: TROW
# Current Running Info - window: 15 | symbol: TRUE
# Current Running Info - window: 15 | symbol: TRV
# Current Running Info - window: 15 | symbol: TRW
# Current Running Info - window: 15 | symbol: TSCO
# Current Running Info - window: 15 | symbol: TSLA
# Current Running Info - window: 15 | symbol: TSN
# Current Running Info - window: 15 | symbol: TSO
# Current Running Info - window: 15 | symbol: TTWO
# Current Running Info - window: 15 | symbol: TWC
# Current Running Info - window: 15 | symbol: TWTR
# Current Running Info - window: 15 | symbol: TWX
# Current Running Info - window: 15 | symbol: TXN
# Current Running Info - window: 15 | symbol: TXT
# Current Running Info - window: 15 | symbol: TYC
# Current Running Info - window: 15 | symbol: UAA
# Current Running Info - window: 15 | symbol: UAL
# Current Running Info - window: 15 | symbol: UIS
# Current Running Info - window: 15 | symbol: ULTA
# Current Running Info - window: 15 | symbol: UNH
# Current Running Info - window: 15 | symbol: UNM
# Current Running Info - window: 15 | symbol: UNP
# Current Running Info - window: 15 | symbol: UPIP
# Current Running Info - window: 15 | symbol: UPL
# Current Running Info - window: 15 | symbol: UPS
# Current Running Info - window: 15 | symbol: URBN
# Current Running Info - window: 15 | symbol: URI
# Current Running Info - window: 15 | symbol: USB
# Current Running Info - window: 15 | symbol: USG
# Current Running Info - window: 15 | symbol: UTHR
# Current Running Info - window: 15 | symbol: UTX
# Current Running Info - window: 15 | symbol: V
# Current Running Info - window: 15 | symbol: VAR
# Current Running Info - window: 15 | symbol: VECO
# Current Running Info - window: 15 | symbol: VFC
# Current Running Info - window: 15 | symbol: VIAB
# Current Running Info - window: 15 | symbol: VIAS
# Current Running Info - window: 15 | symbol: VLO
# Current Running Info - window: 15 | symbol: VMC
# Current Running Info - window: 15 | symbol: VMW
# Current Running Info - window: 15 | symbol: VNO
# Current Running Info - window: 15 | symbol: VOD
# Current Running Info - window: 15 | symbol: VRSN
# Current Running Info - window: 15 | symbol: VRTX
# Current Running Info - window: 15 | symbol: VRX
# Current Running Info - window: 15 | symbol: VSH
# Current Running Info - window: 15 | symbol: VTR
# Current Running Info - window: 15 | symbol: VTSS
# Current Running Info - window: 15 | symbol: VZ
# Current Running Info - window: 15 | symbol: WAG
# Current Running Info - window: 15 | symbol: WAT
# Current Running Info - window: 15 | symbol: WBA
# Current Running Info - window: 15 | symbol: WCG
# Current Running Info - window: 15 | symbol: WDAY
# Current Running Info - window: 15 | symbol: WDC
# Current Running Info - window: 15 | symbol: WEC
# Current Running Info - window: 15 | symbol: WFC
# Current Running Info - window: 15 | symbol: WFM
# Current Running Info - window: 15 | symbol: WGO
# Current Running Info - window: 15 | symbol: WHR
# Current Running Info - window: 15 | symbol: WLL
# Current Running Info - window: 15 | symbol: WLT
# Current Running Info - window: 15 | symbol: WM
# Current Running Info - window: 15 | symbol: WMB
# Current Running Info - window: 15 | symbol: WMT
# Current Running Info - window: 15 | symbol: WPX
# Current Running Info - window: 15 | symbol: WTW
# Current Running Info - window: 15 | symbol: WU
# Current Running Info - window: 15 | symbol: WY
# Current Running Info - window: 15 | symbol: WYN
# Current Running Info - window: 15 | symbol: WYNN
# Current Running Info - window: 15 | symbol: X
# Current Running Info - window: 15 | symbol: XEC
# Current Running Info - window: 15 | symbol: XEL
# Current Running Info - window: 15 | symbol: XL
# Current Running Info - window: 15 | symbol: XLNX
# Current Running Info - window: 15 | symbol: XOM
# Current Running Info - window: 15 | symbol: XRAY
# Current Running Info - window: 15 | symbol: XRX
# Current Running Info - window: 15 | symbol: YELP
# Current Running Info - window: 15 | symbol: YHOO
# Current Running Info - window: 15 | symbol: YRCW
# Current Running Info - window: 15 | symbol: YUM
# Current Running Info - window: 15 | symbol: ZBH
# Current Running Info - window: 15 | symbol: ZBRA
# Current Running Info - window: 15 | symbol: ZION
# Current Running Info - window: 15 | symbol: ZMH
# Current Running Info - window: 15 | symbol: ZTS
# Current Running Info - window: 20 | symbol: A
# Current Running Info - window: 20 | symbol: AAL
# Current Running Info - window: 20 | symbol: AAP
# Current Running Info - window: 20 | symbol: AAPL
# Current Running Info - window: 20 | symbol: ABBV
# Current Running Info - window: 20 | symbol: ABC
# Current Running Info - window: 20 | symbol: ABT
# Current Running Info - window: 20 | symbol: ACAS
# Current Running Info - window: 20 | symbol: ACE
# Current Running Info - window: 20 | symbol: ACI
# Current Running Info - window: 20 | symbol: ACN
# Current Running Info - window: 20 | symbol: ACXM
# Current Running Info - window: 20 | symbol: ADBE
# Current Running Info - window: 20 | symbol: ADI
# Current Running Info - window: 20 | symbol: ADM
# Current Running Info - window: 20 | symbol: ADP
# Current Running Info - window: 20 | symbol: ADS
# Current Running Info - window: 20 | symbol: ADSK
# Current Running Info - window: 20 | symbol: ADTN
# Current Running Info - window: 20 | symbol: AEE
# Current Running Info - window: 20 | symbol: AEO
# Current Running Info - window: 20 | symbol: AEP
# Current Running Info - window: 20 | symbol: AES
# Current Running Info - window: 20 | symbol: AET
# Current Running Info - window: 20 | symbol: AFFX
# Current Running Info - window: 20 | symbol: AFL
# Current Running Info - window: 20 | symbol: AGCO
# Current Running Info - window: 20 | symbol: AGN
# Current Running Info - window: 20 | symbol: AGNC
# Current Running Info - window: 20 | symbol: AIG
# Current Running Info - window: 20 | symbol: AIZ
# Current Running Info - window: 20 | symbol: AKAM
# Current Running Info - window: 20 | symbol: AKS
# Current Running Info - window: 20 | symbol: ALB
# Current Running Info - window: 20 | symbol: ALK
# Current Running Info - window: 20 | symbol: ALKS
# Current Running Info - window: 20 | symbol: ALL
# Current Running Info - window: 20 | symbol: ALTR
# Current Running Info - window: 20 | symbol: ALXN
# Current Running Info - window: 20 | symbol: AMAT
# Current Running Info - window: 20 | symbol: AMCC
# Current Running Info - window: 20 | symbol: AMD
# Current Running Info - window: 20 | symbol: AMG
# Current Running Info - window: 20 | symbol: AMGN
# Current Running Info - window: 20 | symbol: AMKR
# Current Running Info - window: 20 | symbol: AMP
# Current Running Info - window: 20 | symbol: AMT
# Current Running Info - window: 20 | symbol: AMTD
# Current Running Info - window: 20 | symbol: AMZN
# Current Running Info - window: 20 | symbol: AN
# Current Running Info - window: 20 | symbol: ANF
# Current Running Info - window: 20 | symbol: ANN
# Current Running Info - window: 20 | symbol: ANR
# Current Running Info - window: 20 | symbol: ANTM
# Current Running Info - window: 20 | symbol: AON
# Current Running Info - window: 20 | symbol: APA
# Current Running Info - window: 20 | symbol: APC
# Current Running Info - window: 20 | symbol: APD
# Current Running Info - window: 20 | symbol: APH
# Current Running Info - window: 20 | symbol: APOL
# Current Running Info - window: 20 | symbol: ARNC
# Current Running Info - window: 20 | symbol: ARO
# Current Running Info - window: 20 | symbol: ARW
# Current Running Info - window: 20 | symbol: ASH
# Current Running Info - window: 20 | symbol: ATI
# Current Running Info - window: 20 | symbol: ATK
# Current Running Info - window: 20 | symbol: ATML
# Current Running Info - window: 20 | symbol: ATVI
# Current Running Info - window: 20 | symbol: AVB
# Current Running Info - window: 20 | symbol: AVGO
# Current Running Info - window: 20 | symbol: AVP
# Current Running Info - window: 20 | symbol: AVT
# Current Running Info - window: 20 | symbol: AVY
# Current Running Info - window: 20 | symbol: AXP
# Current Running Info - window: 20 | symbol: AYI
# Current Running Info - window: 20 | symbol: AZO
# Current Running Info - window: 20 | symbol: BA
# Current Running Info - window: 20 | symbol: BAC
# Current Running Info - window: 20 | symbol: BAX
# Current Running Info - window: 20 | symbol: BBBY
# Current Running Info - window: 20 | symbol: BBT
# Current Running Info - window: 20 | symbol: BBY
# Current Running Info - window: 20 | symbol: BC
# Current Running Info - window: 20 | symbol: BCR
# Current Running Info - window: 20 | symbol: BDX
# Current Running Info - window: 20 | symbol: BEAM
# Current Running Info - window: 20 | symbol: BEN
# Current Running Info - window: 20 | symbol: BG
# Current Running Info - window: 20 | symbol: BHI
# Current Running Info - window: 20 | symbol: BIDU
# Current Running Info - window: 20 | symbol: BIG
# Current Running Info - window: 20 | symbol: BIIB
# Current Running Info - window: 20 | symbol: BK
# Current Running Info - window: 20 | symbol: BLK
# Current Running Info - window: 20 | symbol: BLL
# Current Running Info - window: 20 | symbol: BMRN
# Current Running Info - window: 20 | symbol: BMY
# Current Running Info - window: 20 | symbol: BP
# Current Running Info - window: 20 | symbol: BRCD
# Current Running Info - window: 20 | symbol: BRCM
# Current Running Info - window: 20 | symbol: BRK_A
# Current Running Info - window: 20 | symbol: BRK_B
# Current Running Info - window: 20 | symbol: BSX
# Current Running Info - window: 20 | symbol: BURL
# Current Running Info - window: 20 | symbol: BWA
# Current Running Info - window: 20 | symbol: BWLD
# Current Running Info - window: 20 | symbol: BXP
# Current Running Info - window: 20 | symbol: BYD
# Current Running Info - window: 20 | symbol: BZH
# Current Running Info - window: 20 | symbol: C
# Current Running Info - window: 20 | symbol: CA
# Current Running Info - window: 20 | symbol: CACI
# Current Running Info - window: 20 | symbol: CAG
# Current Running Info - window: 20 | symbol: CAH
# Current Running Info - window: 20 | symbol: CAKE
# Current Running Info - window: 20 | symbol: CAM
# Current Running Info - window: 20 | symbol: CAR
# Current Running Info - window: 20 | symbol: CAT
# Current Running Info - window: 20 | symbol: CB
# Current Running Info - window: 20 | symbol: CBG
# Current Running Info - window: 20 | symbol: CBI
# Current Running Info - window: 20 | symbol: CBRL
# Current Running Info - window: 20 | symbol: CCE
# Current Running Info - window: 20 | symbol: CCI
# Current Running Info - window: 20 | symbol: CCL
# Current Running Info - window: 20 | symbol: CCMP
# Current Running Info - window: 20 | symbol: CDE
# Current Running Info - window: 20 | symbol: CDNS
# Current Running Info - window: 20 | symbol: CE
# Current Running Info - window: 20 | symbol: CECO
# Current Running Info - window: 20 | symbol: CELG
# Current Running Info - window: 20 | symbol: CERN
# Current Running Info - window: 20 | symbol: CF
# Current Running Info - window: 20 | symbol: CFN
# Current Running Info - window: 20 | symbol: CHK
# Current Running Info - window: 20 | symbol: CHKP
# Current Running Info - window: 20 | symbol: CHRW
# Current Running Info - window: 20 | symbol: CHS
# Current Running Info - window: 20 | symbol: CHTR
# Current Running Info - window: 20 | symbol: CI
# Current Running Info - window: 20 | symbol: CIEN
# Current Running Info - window: 20 | symbol: CIT
# Current Running Info - window: 20 | symbol: CL
# Current Running Info - window: 20 | symbol: CLF
# Current Running Info - window: 20 | symbol: CLR
# Current Running Info - window: 20 | symbol: CLX
# Current Running Info - window: 20 | symbol: CMA
# Current Running Info - window: 20 | symbol: CMCSA
# Current Running Info - window: 20 | symbol: CMCSK
# Current Running Info - window: 20 | symbol: CME
# Current Running Info - window: 20 | symbol: CMG
# Current Running Info - window: 20 | symbol: CMI
# Current Running Info - window: 20 | symbol: CMS
# Current Running Info - window: 20 | symbol: CNC
# Current Running Info - window: 20 | symbol: CNO
# Current Running Info - window: 20 | symbol: CNP
# Current Running Info - window: 20 | symbol: CNW
# Current Running Info - window: 20 | symbol: CNX
# Current Running Info - window: 20 | symbol: COCO
# Current Running Info - window: 20 | symbol: COF
# Current Running Info - window: 20 | symbol: COG
# Current Running Info - window: 20 | symbol: COH
# Current Running Info - window: 20 | symbol: COL
# Current Running Info - window: 20 | symbol: COLM
# Current Running Info - window: 20 | symbol: COP
# Current Running Info - window: 20 | symbol: COST
# Current Running Info - window: 20 | symbol: COV
# Current Running Info - window: 20 | symbol: CPB
# Current Running Info - window: 20 | symbol: CPN
# Current Running Info - window: 20 | symbol: CPWR
# Current Running Info - window: 20 | symbol: CREE
# Current Running Info - window: 20 | symbol: CRL
# Current Running Info - window: 20 | symbol: CRM
# Current Running Info - window: 20 | symbol: CSC
# Current Running Info - window: 20 | symbol: CSCO
# Current Running Info - window: 20 | symbol: CSX
# Current Running Info - window: 20 | symbol: CTAS
# Current Running Info - window: 20 | symbol: CTL
# Current Running Info - window: 20 | symbol: CTSH
# Current Running Info - window: 20 | symbol: CTXS
# Current Running Info - window: 20 | symbol: CVC
# Current Running Info - window: 20 | symbol: CVG
# Current Running Info - window: 20 | symbol: CVS
# Current Running Info - window: 20 | symbol: CVX
# Current Running Info - window: 20 | symbol: CXO
# Current Running Info - window: 20 | symbol: CY
# Current Running Info - window: 20 | symbol: CYH
# Current Running Info - window: 20 | symbol: D
# Current Running Info - window: 20 | symbol: DAL
# Current Running Info - window: 20 | symbol: DATA
# Current Running Info - window: 20 | symbol: DD
# Current Running Info - window: 20 | symbol: DE
# Current Running Info - window: 20 | symbol: DECK
# Current Running Info - window: 20 | symbol: DF
# Current Running Info - window: 20 | symbol: DFS
# Current Running Info - window: 20 | symbol: DG
# Current Running Info - window: 20 | symbol: DGX
# Current Running Info - window: 20 | symbol: DHI
# Current Running Info - window: 20 | symbol: DHR
# Current Running Info - window: 20 | symbol: DIS
# Current Running Info - window: 20 | symbol: DISCA
# Current Running Info - window: 20 | symbol: DISH
# Current Running Info - window: 20 | symbol: DKS
# Current Running Info - window: 20 | symbol: DLPH
# Current Running Info - window: 20 | symbol: DLR
# Current Running Info - window: 20 | symbol: DLTR
# Current Running Info - window: 20 | symbol: DNR
# Current Running Info - window: 20 | symbol: DO
# Current Running Info - window: 20 | symbol: DOV
# Current Running Info - window: 20 | symbol: DOW
# Current Running Info - window: 20 | symbol: DOX
# Current Running Info - window: 20 | symbol: DPS
# Current Running Info - window: 20 | symbol: DRI
# Current Running Info - window: 20 | symbol: DRIV
# Current Running Info - window: 20 | symbol: DRL
# Current Running Info - window: 20 | symbol: DST
# Current Running Info - window: 20 | symbol: DTE
# Current Running Info - window: 20 | symbol: DTV
# Current Running Info - window: 20 | symbol: DUK
# Current Running Info - window: 20 | symbol: DVA
# Current Running Info - window: 20 | symbol: DVN
# Current Running Info - window: 20 | symbol: EA
# Current Running Info - window: 20 | symbol: EAT
# Current Running Info - window: 20 | symbol: EBAY
# Current Running Info - window: 20 | symbol: ECL
# Current Running Info - window: 20 | symbol: ED
# Current Running Info - window: 20 | symbol: EFII
# Current Running Info - window: 20 | symbol: EIX
# Current Running Info - window: 20 | symbol: EL
# Current Running Info - window: 20 | symbol: ELX
# Current Running Info - window: 20 | symbol: EMC
# Current Running Info - window: 20 | symbol: EMN
# Current Running Info - window: 20 | symbol: EMR
# Current Running Info - window: 20 | symbol: ENDP
# Current Running Info - window: 20 | symbol: ENR
# Current Running Info - window: 20 | symbol: EOG
# Current Running Info - window: 20 | symbol: EQIX
# Current Running Info - window: 20 | symbol: EQR
# Current Running Info - window: 20 | symbol: EQT
# Current Running Info - window: 20 | symbol: ES
# Current Running Info - window: 20 | symbol: ESI
# Current Running Info - window: 20 | symbol: ESRX
# Current Running Info - window: 20 | symbol: ESS
# Current Running Info - window: 20 | symbol: ESV
# Current Running Info - window: 20 | symbol: ETFC
# Current Running Info - window: 20 | symbol: ETN
# Current Running Info - window: 20 | symbol: ETR
# Current Running Info - window: 20 | symbol: EW
# Current Running Info - window: 20 | symbol: EXC
# Current Running Info - window: 20 | symbol: EXPD
# Current Running Info - window: 20 | symbol: EXPE
# Current Running Info - window: 20 | symbol: EXTR
# Current Running Info - window: 20 | symbol: F
# Current Running Info - window: 20 | symbol: FANG
# Current Running Info - window: 20 | symbol: FAST
# Current Running Info - window: 20 | symbol: FB
# Current Running Info - window: 20 | symbol: FCS
# Current Running Info - window: 20 | symbol: FCX
# Current Running Info - window: 20 | symbol: FDO
# Current Running Info - window: 20 | symbol: FDX
# Current Running Info - window: 20 | symbol: FE
# Current Running Info - window: 20 | symbol: FFIV
# Current Running Info - window: 20 | symbol: FICO
# Current Running Info - window: 20 | symbol: FIS
# Current Running Info - window: 20 | symbol: FISV
# Current Running Info - window: 20 | symbol: FITB
# ...
# Current Running Info - window: 85 | symbol: LPX
# Current Running Info - window: 85 | symbol: LRCX
# Current Running Info - window: 85 | symbol: LSCC
# Current Running Info - window: 85 | symbol: LUV
# Current Running Info - window: 85 | symbol: LVLT
# Current Running Info - window: 85 | symbol: LVS
# Current Running Info - window: 85 | symbol: LXK
# Current Running Info - window: 85 | symbol: LYB
# Current Running Info - window: 85 | symbol: M
# Current Running Info - window: 85 | symbol: MA
# Current Running Info - window: 85 | symbol: MAN
# Current Running Info - window: 85 | symbol: MAR
# Current Running Info - window: 85 | symbol: MAS
# Current Running Info - window: 85 | symbol: MAT
# Current Running Info - window: 85 | symbol: MBI
# Current Running Info - window: 85 | symbol: MCD
# Current Running Info - window: 85 | symbol: MCHP
# Current Running Info - window: 85 | symbol: MCK
# Current Running Info - window: 85 | symbol: MCO
# Current Running Info - window: 85 | symbol: MCP
# Current Running Info - window: 85 | symbol: MCRL
# Current Running Info - window: 85 | symbol: MDC
# Current Running Info - window: 85 | symbol: MDLZ
# Current Running Info - window: 85 | symbol: MDR
# Current Running Info - window: 85 | symbol: MDT
# Current Running Info - window: 85 | symbol: MET
# Current Running Info - window: 85 | symbol: MGM
# Current Running Info - window: 85 | symbol: MHFI
# Current Running Info - window: 85 | symbol: MHK
# Current Running Info - window: 85 | symbol: MJN
# Current Running Info - window: 85 | symbol: MLM
# Current Running Info - window: 85 | symbol: MMC
# Current Running Info - window: 85 | symbol: MMM
# Current Running Info - window: 85 | symbol: MNK
# Current Running Info - window: 85 | symbol: MNST
# Current Running Info - window: 85 | symbol: MO
# Current Running Info - window: 85 | symbol: MON
# Current Running Info - window: 85 | symbol: MOS
# Current Running Info - window: 85 | symbol: MPC
# Current Running Info - window: 85 | symbol: MRK
# Current Running Info - window: 85 | symbol: MRO
# Current Running Info - window: 85 | symbol: MRVL
# Current Running Info - window: 85 | symbol: MS
# Current Running Info - window: 85 | symbol: MSFT
# Current Running Info - window: 85 | symbol: MSI
# Current Running Info - window: 85 | symbol: MSTR
# Current Running Info - window: 85 | symbol: MTB
# Current Running Info - window: 85 | symbol: MTG
# Current Running Info - window: 85 | symbol: MU
# Current Running Info - window: 85 | symbol: MUR
# Current Running Info - window: 85 | symbol: MWV
# Current Running Info - window: 85 | symbol: MWW
# Current Running Info - window: 85 | symbol: MXIM
# Current Running Info - window: 85 | symbol: MYL
# Current Running Info - window: 85 | symbol: NAV
# Current Running Info - window: 85 | symbol: NBIX
# Current Running Info - window: 85 | symbol: NBL
# Current Running Info - window: 85 | symbol: NBR
# Current Running Info - window: 85 | symbol: NDAQ
# Current Running Info - window: 85 | symbol: NE
# Current Running Info - window: 85 | symbol: NEE
# Current Running Info - window: 85 | symbol: NEM
# Current Running Info - window: 85 | symbol: NFLX
# Current Running Info - window: 85 | symbol: NFX
# Current Running Info - window: 85 | symbol: NKE
# Current Running Info - window: 85 | symbol: NKTR
# Current Running Info - window: 85 | symbol: NLSN
# Current Running Info - window: 85 | symbol: NLY
# Current Running Info - window: 85 | symbol: NOC
# Current Running Info - window: 85 | symbol: NOV
# Current Running Info - window: 85 | symbol: NOW
# Current Running Info - window: 85 | symbol: NRG
# Current Running Info - window: 85 | symbol: NSC
# Current Running Info - window: 85 | symbol: NTAP
# Current Running Info - window: 85 | symbol: NTRS
# Current Running Info - window: 85 | symbol: NU
# Current Running Info - window: 85 | symbol: NUAN
# Current Running Info - window: 85 | symbol: NUE
# Current Running Info - window: 85 | symbol: NVDA
# Current Running Info - window: 85 | symbol: NVR
# Current Running Info - window: 85 | symbol: NWL
# Current Running Info - window: 85 | symbol: NYT
# Current Running Info - window: 85 | symbol: O
# Current Running Info - window: 85 | symbol: OAS
# Current Running Info - window: 85 | symbol: OCR
# Current Running Info - window: 85 | symbol: ODP
# Current Running Info - window: 85 | symbol: OI
# Current Running Info - window: 85 | symbol: OKE
# Current Running Info - window: 85 | symbol: OMC
# Current Running Info - window: 85 | symbol: ONNN
# Current Running Info - window: 85 | symbol: ORCL
# Current Running Info - window: 85 | symbol: ORLY
# Current Running Info - window: 85 | symbol: OVTI
# Current Running Info - window: 85 | symbol: OXY
# Current Running Info - window: 85 | symbol: P
# Current Running Info - window: 85 | symbol: PANW
# Current Running Info - window: 85 | symbol: PAYX
# Current Running Info - window: 85 | symbol: PBCT
# Current Running Info - window: 85 | symbol: PBI
# Current Running Info - window: 85 | symbol: PCAR
# Current Running Info - window: 85 | symbol: PCG
# Current Running Info - window: 85 | symbol: PCL
# Current Running Info - window: 85 | symbol: PCLN
# Current Running Info - window: 85 | symbol: PCP
# Current Running Info - window: 85 | symbol: PDCO
# Current Running Info - window: 85 | symbol: PEG
# Current Running Info - window: 85 | symbol: PENN
# Current Running Info - window: 85 | symbol: PEP
# Current Running Info - window: 85 | symbol: PETM
# Current Running Info - window: 85 | symbol: PFE
# Current Running Info - window: 85 | symbol: PFG
# Current Running Info - window: 85 | symbol: PG
# Current Running Info - window: 85 | symbol: PGR
# Current Running Info - window: 85 | symbol: PH
# Current Running Info - window: 85 | symbol: PHM
# Current Running Info - window: 85 | symbol: PII
# Current Running Info - window: 85 | symbol: PKI
# Current Running Info - window: 85 | symbol: PLCM
# Current Running Info - window: 85 | symbol: PLD
# Current Running Info - window: 85 | symbol: PM
# Current Running Info - window: 85 | symbol: PMCS
# Current Running Info - window: 85 | symbol: PNC
# Current Running Info - window: 85 | symbol: PNR
# Current Running Info - window: 85 | symbol: PNRA
# Current Running Info - window: 85 | symbol: PPG
# Current Running Info - window: 85 | symbol: PPL
# Current Running Info - window: 85 | symbol: PRGO
# Current Running Info - window: 85 | symbol: PRU
# Current Running Info - window: 85 | symbol: PSA
# Current Running Info - window: 85 | symbol: PSUN
# Current Running Info - window: 85 | symbol: PSX
# Current Running Info - window: 85 | symbol: PTEN
# Current Running Info - window: 85 | symbol: PVH
# Current Running Info - window: 85 | symbol: PWR
# Current Running Info - window: 85 | symbol: PX
# Current Running Info - window: 85 | symbol: PXD
# Current Running Info - window: 85 | symbol: QCOM
# Current Running Info - window: 85 | symbol: QEP
# Current Running Info - window: 85 | symbol: QLGC
# Current Running Info - window: 85 | symbol: RAD
# Current Running Info - window: 85 | symbol: RAI
# Current Running Info - window: 85 | symbol: RAX
# Current Running Info - window: 85 | symbol: RCII
# Current Running Info - window: 85 | symbol: RCL
# Current Running Info - window: 85 | symbol: RDC
# Current Running Info - window: 85 | symbol: RDN
# Current Running Info - window: 85 | symbol: RE
# Current Running Info - window: 85 | symbol: REGN
# Current Running Info - window: 85 | symbol: RF
# Current Running Info - window: 85 | symbol: RFMD
# Current Running Info - window: 85 | symbol: RH
# Current Running Info - window: 85 | symbol: RHI
# Current Running Info - window: 85 | symbol: RHT
# Current Running Info - window: 85 | symbol: RIG
# Current Running Info - window: 85 | symbol: RL
# Current Running Info - window: 85 | symbol: RMBS
# Current Running Info - window: 85 | symbol: RNR
# Current Running Info - window: 85 | symbol: ROK
# Current Running Info - window: 85 | symbol: ROP
# Current Running Info - window: 85 | symbol: ROST
# Current Running Info - window: 85 | symbol: ROVI
# Current Running Info - window: 85 | symbol: RRC
# Current Running Info - window: 85 | symbol: RS
# Current Running Info - window: 85 | symbol: RSG
# Current Running Info - window: 85 | symbol: RSH
# Current Running Info - window: 85 | symbol: RTN
# Current Running Info - window: 85 | symbol: RVBD
# Current Running Info - window: 85 | symbol: RYL
# Current Running Info - window: 85 | symbol: S
# Current Running Info - window: 85 | symbol: SANM
# Current Running Info - window: 85 | symbol: SBAC
# Current Running Info - window: 85 | symbol: SBUX
# Current Running Info - window: 85 | symbol: SCCO
# Current Running Info - window: 85 | symbol: SCHW
# Current Running Info - window: 85 | symbol: SE
# Current Running Info - window: 85 | symbol: SEE
# Current Running Info - window: 85 | symbol: SEIC
# Current Running Info - window: 85 | symbol: SHLD
# Current Running Info - window: 85 | symbol: SHW
# Current Running Info - window: 85 | symbol: SIAL
# Current Running Info - window: 85 | symbol: SIG
# Current Running Info - window: 85 | symbol: SIRI
# Current Running Info - window: 85 | symbol: SIVB
# Current Running Info - window: 85 | symbol: SJM
# Current Running Info - window: 85 | symbol: SLAB
# Current Running Info - window: 85 | symbol: SLB
# Current Running Info - window: 85 | symbol: SLG
# Current Running Info - window: 85 | symbol: SLM
# Current Running Info - window: 85 | symbol: SM
# Current Running Info - window: 85 | symbol: SMTC
# Current Running Info - window: 85 | symbol: SNDK
# Current Running Info - window: 85 | symbol: SNI
# Current Running Info - window: 85 | symbol: SNPS
# Current Running Info - window: 85 | symbol: SNV
# Current Running Info - window: 85 | symbol: SO
# Current Running Info - window: 85 | symbol: SONS
# Current Running Info - window: 85 | symbol: SPF
# Current Running Info - window: 85 | symbol: SPG
# Current Running Info - window: 85 | symbol: SPLK
# Current Running Info - window: 85 | symbol: SPLS
# Current Running Info - window: 85 | symbol: SPW
# Current Running Info - window: 85 | symbol: SPWR
# Current Running Info - window: 85 | symbol: SRCL
# Current Running Info - window: 85 | symbol: SRE
# Current Running Info - window: 85 | symbol: STI
# Current Running Info - window: 85 | symbol: STJ
# Current Running Info - window: 85 | symbol: STLD
# Current Running Info - window: 85 | symbol: STR
# Current Running Info - window: 85 | symbol: STT
# Current Running Info - window: 85 | symbol: STX
# Current Running Info - window: 85 | symbol: STZ
# Current Running Info - window: 85 | symbol: SUNE
# Current Running Info - window: 85 | symbol: SVU
# Current Running Info - window: 85 | symbol: SWK
# Current Running Info - window: 85 | symbol: SWKS
# Current Running Info - window: 85 | symbol: SWN
# Current Running Info - window: 85 | symbol: SWY
# Current Running Info - window: 85 | symbol: SYK
# Current Running Info - window: 85 | symbol: SYMC
# Current Running Info - window: 85 | symbol: SYY
# Current Running Info - window: 85 | symbol: T
# Current Running Info - window: 85 | symbol: TAP
# Current Running Info - window: 85 | symbol: TDC
# Current Running Info - window: 85 | symbol: TDG
# Current Running Info - window: 85 | symbol: TDS
# Current Running Info - window: 85 | symbol: TDW
# Current Running Info - window: 85 | symbol: TECD
# Current Running Info - window: 85 | symbol: TEL
# Current Running Info - window: 85 | symbol: TER
# Current Running Info - window: 85 | symbol: TEX
# Current Running Info - window: 85 | symbol: TGNA
# Current Running Info - window: 85 | symbol: TGT
# Current Running Info - window: 85 | symbol: THC
# Current Running Info - window: 85 | symbol: TIBX
# Current Running Info - window: 85 | symbol: TIF
# Current Running Info - window: 85 | symbol: TIVO
# Current Running Info - window: 85 | symbol: TJX
# Current Running Info - window: 85 | symbol: TMK
# Current Running Info - window: 85 | symbol: TMO
# Current Running Info - window: 85 | symbol: TMUS
# Current Running Info - window: 85 | symbol: TOL
# Current Running Info - window: 85 | symbol: TQNT
# Current Running Info - window: 85 | symbol: TRIP
# Current Running Info - window: 85 | symbol: TROW
# Current Running Info - window: 85 | symbol: TRUE
# Current Running Info - window: 85 | symbol: TRV
# Current Running Info - window: 85 | symbol: TRW
# Current Running Info - window: 85 | symbol: TSCO
# Current Running Info - window: 85 | symbol: TSLA
# Current Running Info - window: 85 | symbol: TSN
# Current Running Info - window: 85 | symbol: TSO
# Current Running Info - window: 85 | symbol: TTWO
# Current Running Info - window: 85 | symbol: TWC
# Current Running Info - window: 85 | symbol: TWTR
# Current Running Info - window: 85 | symbol: TWX
# Current Running Info - window: 85 | symbol: TXN
# Current Running Info - window: 85 | symbol: TXT
# Current Running Info - window: 85 | symbol: TYC
# Current Running Info - window: 85 | symbol: UAA
# Current Running Info - window: 85 | symbol: UAL
# Current Running Info - window: 85 | symbol: UIS
# Current Running Info - window: 85 | symbol: ULTA
# Current Running Info - window: 85 | symbol: UNH
# Current Running Info - window: 85 | symbol: UNM
# Current Running Info - window: 85 | symbol: UNP
# Current Running Info - window: 85 | symbol: UPIP
# Current Running Info - window: 85 | symbol: UPL
# Current Running Info - window: 85 | symbol: UPS
# Current Running Info - window: 85 | symbol: URBN
# Current Running Info - window: 85 | symbol: URI
# Current Running Info - window: 85 | symbol: USB
# Current Running Info - window: 85 | symbol: USG
# Current Running Info - window: 85 | symbol: UTHR
# Current Running Info - window: 85 | symbol: UTX
# Current Running Info - window: 85 | symbol: V
# Current Running Info - window: 85 | symbol: VAR
# Current Running Info - window: 85 | symbol: VECO
# Current Running Info - window: 85 | symbol: VFC
# Current Running Info - window: 85 | symbol: VIAB
# Current Running Info - window: 85 | symbol: VIAS
# Current Running Info - window: 85 | symbol: VLO
# Current Running Info - window: 85 | symbol: VMC
# Current Running Info - window: 85 | symbol: VMW
# Current Running Info - window: 85 | symbol: VNO
# Current Running Info - window: 85 | symbol: VOD
# Current Running Info - window: 85 | symbol: VRSN
# Current Running Info - window: 85 | symbol: VRTX
# Current Running Info - window: 85 | symbol: VRX
# Current Running Info - window: 85 | symbol: VSH
# Current Running Info - window: 85 | symbol: VTR
# Current Running Info - window: 85 | symbol: VTSS
# Current Running Info - window: 85 | symbol: VZ
# Current Running Info - window: 85 | symbol: WAG
# Current Running Info - window: 85 | symbol: WAT
# Current Running Info - window: 85 | symbol: WBA
# Current Running Info - window: 85 | symbol: WCG
# Current Running Info - window: 85 | symbol: WDAY
# Current Running Info - window: 85 | symbol: WDC
# Current Running Info - window: 85 | symbol: WEC
# Current Running Info - window: 85 | symbol: WFC
# Current Running Info - window: 85 | symbol: WFM
# Current Running Info - window: 85 | symbol: WGO
# Current Running Info - window: 85 | symbol: WHR
# Current Running Info - window: 85 | symbol: WLL
# Current Running Info - window: 85 | symbol: WLT
# Current Running Info - window: 85 | symbol: WM
# Current Running Info - window: 85 | symbol: WMB
# Current Running Info - window: 85 | symbol: WMT
# Current Running Info - window: 85 | symbol: WPX
# Current Running Info - window: 85 | symbol: WTW
# Current Running Info - window: 85 | symbol: WU
# Current Running Info - window: 85 | symbol: WY
# Current Running Info - window: 85 | symbol: WYN
# Current Running Info - window: 85 | symbol: WYNN
# Current Running Info - window: 85 | symbol: X
# Current Running Info - window: 85 | symbol: XEC
# Current Running Info - window: 85 | symbol: XEL
# Current Running Info - window: 85 | symbol: XL
# Current Running Info - window: 85 | symbol: XLNX
# Current Running Info - window: 85 | symbol: XOM
# Current Running Info - window: 85 | symbol: XRAY
# Current Running Info - window: 85 | symbol: XRX
# Current Running Info - window: 85 | symbol: YELP
# Current Running Info - window: 85 | symbol: YHOO
# Current Running Info - window: 85 | symbol: YRCW
# Current Running Info - window: 85 | symbol: YUM
# Current Running Info - window: 85 | symbol: ZBH
# Current Running Info - window: 85 | symbol: ZBRA
# Current Running Info - window: 85 | symbol: ZION
# Current Running Info - window: 85 | symbol: ZMH
# Current Running Info - window: 85 | symbol: ZTS

# %%
# Compute Forward Returns
for t in [1, 5]:
    universe[f'r{t:02}_fwd'] = universe.groupby(level='symbol')[f'r{t:02}'].shift(-t)
    universe[f'r{t:02}dec_fwd'] = universe.groupby(level='symbol')[f'r{t:02}dec'].shift(-t)

# Store Model Data

universe = universe.drop(ohlcv, axis=1)
universe.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2536336 entries, ('BRK_A', Timestamp('2000-01-03 00:00:00')) to ('BWLD', Timestamp('2018-02-05 00:00:00'))
# Columns: 308 entries, 06_RSI to r05dec_fwd
# dtypes: float64(308)
# memory usage: 5.8+ GB

# %%
drop_cols = ['r01', 'r01dec', 'r05',  'r05dec']
outcomes = universe.filter(like='_fwd').columns
universe = universe.sort_index()

# %%
with pd.HDFStore('data/universe_data.h5') as store:
    store.put('features', universe.drop(drop_cols, axis=1).drop(outcomes, axis=1).loc[idx[:, '2001':], :])
    store.put('targets', universe.loc[idx[:, '2001':], outcomes])

# %%
universe.sample(10)
# Out:
#                       06_RSI     07_RSI     08_RSI     09_RSI     10_RSI  \
# symbol date
# KMI    2015-06-12   8.713382  10.020615  11.315844  12.613166  13.911916
# VMC    2010-02-25  49.745682  49.085303  48.063121  47.002444  46.037182
# KO     2007-05-08  66.214983  68.548652  70.253789  71.501568  72.405089
# HCN    2017-05-08  38.404957  38.423582  39.017760  39.898490  40.902807
# DRIV   2006-03-27  65.860153  66.530388  67.077024  67.519238  67.873463
# CAM    2007-04-12  76.786051  75.772994  74.952632  74.249941  73.624613
# HES    2002-04-01  80.435940  79.814681  79.370568  79.027262  78.736248
# FOXA   2018-03-01  33.483223  35.960019  37.869547  39.399821  40.670273
# SANM   2008-01-23  47.890392  46.356451  45.263367  44.462249  43.860767
# PRGO   2014-01-23  40.753007  42.775512  44.393132  45.707619  46.803815
#
#                       11_RSI     12_RSI     13_RSI     14_RSI     15_RSI  ...  \
# symbol date                                                               ...
# KMI    2015-06-12  15.205370  16.485110  17.743158  18.972889  20.169278  ...
# VMC    2010-02-25  45.212282  44.532747  43.987069  43.558189  43.228417  ...
# KO     2007-05-08  73.044305  73.478423  73.752594  73.901862  73.953703  ...
# HCN    2017-05-08  41.938446  42.953768  43.920848  44.825709  45.662563  ...
# DRIV   2006-03-27  68.152537  68.366362  68.522676  68.627705  68.686651  ...
# CAM    2007-04-12  73.053486  72.522412  72.022369  71.547449  71.093714  ...
# HES    2002-04-01  78.467952  78.204907  77.937114  77.659105  77.368147  ...
# FOXA   2018-03-01  41.757131  42.709590  43.559867  44.329453  45.033006  ...
# SANM   2008-01-23  43.399739  43.040207  42.755850  42.528404  42.344845  ...
# PRGO   2014-01-23  47.743938  48.570936  49.313545  49.990706  50.614880  ...
#
#                      80_CMA  85_Market    85_SMB    85_HML    85_RMW  \
# symbol date
# KMI    2015-06-12  0.001057   0.005256 -0.005957 -0.000501 -0.004660
# VMC    2010-02-25  0.002939   0.015113 -0.000800 -0.005711 -0.005104
# KO     2007-05-08  0.006587   0.006461 -0.001981 -0.001036  0.001388
# HCN    2017-05-08  0.009088   0.002183 -0.002680 -0.007463  0.003355
# DRIV   2006-03-27 -0.007743   0.008052  0.004854 -0.033244  0.008136
# CAM    2007-04-12 -0.026013   0.007426 -0.000605  0.000189  0.024451
# HES    2002-04-01  0.014506   0.009734 -0.006273 -0.009323 -0.004503
# FOXA   2018-03-01  0.010358   0.008469 -0.001804  0.010424 -0.007196
# SANM   2008-01-23  0.034714   0.016042  0.008827  0.010074 -0.014793
# PRGO   2014-01-23  0.010681   0.005392 -0.000753 -0.007564 -0.007246
#
#                      85_CMA   r01_fwd  r01dec_fwd   r05_fwd  r05dec_fwd
# symbol date
# KMI    2015-06-12 -0.000134  0.011305         9.0  0.015930         6.0
# VMC    2010-02-25  0.004422 -0.025589         0.0 -0.017508         0.0
# KO     2007-05-08  0.005610  0.000754         3.0 -0.011494         4.0
# HCN    2017-05-08  0.009710 -0.009897         1.0  0.027826         8.0
# DRIV   2006-03-27 -0.005608 -0.009007         3.0  0.028406         8.0
# CAM    2007-04-12 -0.026296 -0.005023         2.0 -0.014764         1.0
# HES    2002-04-01  0.014923  0.021126         9.0 -0.017895         4.0
# FOXA   2018-03-01  0.007460  0.012528         7.0  0.035078         6.0
# SANM   2008-01-23  0.034583 -0.035461         0.0  0.014184         4.0
# PRGO   2014-01-23  0.010506 -0.015275         7.0  0.004769         7.0
#
# [10 rows x 308 columns]
