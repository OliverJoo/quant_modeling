# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

import pandas as pd

from statsmodels.api import OLS, add_constant, graphics
from statsmodels.graphics.tsaplots import plot_acf
from scipy.stats import norm

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
idx = pd.IndexSlice

# %%
with pd.HDFStore('data/data.h5') as store:
    data = (store['model_data'].dropna().drop(['open', 'close', 'low', 'high'], axis=1))

# %%
data = data[data.dollar_vol_rank<100]
data.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 109675 entries, ('AAL', Timestamp('2013-07-25 00:00:00')) to ('ZTS', Timestamp('2014-12-04 00:00:00'))
# Data columns (total 66 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   volume                 109675 non-null  float64
#  1   dollar_vol             109675 non-null  float64
#  2   dollar_vol_1m          109675 non-null  float64
#  3   dollar_vol_rank        109675 non-null  float64
#  4   rsi                    109675 non-null  float64
#  5   bb_high                109675 non-null  float64
#  6   bb_mid                 109675 non-null  float64
#  7   bb_low                 109675 non-null  float64
#  8   atr                    109675 non-null  float64
#  9   macd                   109675 non-null  float64
#  10  return_1d              109675 non-null  float64
#  11  return_5d              109675 non-null  float64
#  12  return_10d             109675 non-null  float64
#  13  return_21d             109675 non-null  float64
#  14  return_42d             109675 non-null  float64
#  15  return_63d             109675 non-null  float64
#  16  return_1d_lag1         109675 non-null  float64
#  17  return_5d_lag1         109675 non-null  float64
#  18  return_10d_lag1        109675 non-null  float64
#  19  return_21d_lag1        109675 non-null  float64
#  20  return_1d_lag2         109675 non-null  float64
#  21  return_5d_lag2         109675 non-null  float64
#  22  return_10d_lag2        109675 non-null  float64
#  23  return_21d_lag2        109675 non-null  float64
#  24  return_1d_lag3         109675 non-null  float64
#  25  return_5d_lag3         109675 non-null  float64
#  26  return_10d_lag3        109675 non-null  float64
#  27  return_21d_lag3        109675 non-null  float64
#  28  return_1d_lag4         109675 non-null  float64
#  29  return_5d_lag4         109675 non-null  float64
#  30  return_10d_lag4        109675 non-null  float64
#  31  return_21d_lag4        109675 non-null  float64
#  32  return_1d_lag5         109675 non-null  float64
#  33  return_5d_lag5         109675 non-null  float64
#  34  return_10d_lag5        109675 non-null  float64
#  35  return_21d_lag5        109675 non-null  float64
#  36  target_1d              109675 non-null  float64
#  37  target_5d              109675 non-null  float64
#  38  target_10d             109675 non-null  float64
#  39  target_21d             109675 non-null  float64
#  40  year_2014              109675 non-null  uint8
#  41  year_2015              109675 non-null  uint8
#  42  year_2016              109675 non-null  uint8
#  43  year_2017              109675 non-null  uint8
#  44  month_2                109675 non-null  uint8
#  45  month_3                109675 non-null  uint8
#  46  month_4                109675 non-null  uint8
#  47  month_5                109675 non-null  uint8
#  48  month_6                109675 non-null  uint8
#  49  month_7                109675 non-null  uint8
#  50  month_8                109675 non-null  uint8
#  51  month_9                109675 non-null  uint8
#  52  month_10               109675 non-null  uint8
#  53  month_11               109675 non-null  uint8
#  54  month_12               109675 non-null  uint8
#  55  capital_goods          109675 non-null  uint8
#  56  consumer_durables      109675 non-null  uint8
#  57  consumer_non-durables  109675 non-null  uint8
#  58  consumer_services      109675 non-null  uint8
#  59  energy                 109675 non-null  uint8
#  60  finance                109675 non-null  uint8
#  61  health_care            109675 non-null  uint8
#  62  miscellaneous          109675 non-null  uint8
#  63  public_utilities       109675 non-null  uint8
#  64  technology             109675 non-null  uint8
#  65  transportation         109675 non-null  uint8
# dtypes: float64(40), uint8(26)
# memory usage: 37.4+ MB

# %%
# create features and targets
y = data.filter(like='target') # take columns that include 'target' only
X = data.drop(y.columns, axis=1)
X = X.drop(['dollar_vol', 'dollar_vol_rank', 'volume', 'consumer_durables'], axis=1)
sns.clustermap(y.corr(), cmap=sns.diverging_palette(h_neg=20, h_pos=245, l=65), center=0, annot=True, fmt='.2%');

# %%
sns.clustermap(X.corr(), cmap=sns.diverging_palette(h_neg=20, h_pos=220, l=40), center=0);
# plt.gcf() : get current figure
plt.gcf().set_size_inches((14, 14))

# %%
corr_mat = X.corr().stack().reset_index()
corr_mat.columns=['var1', 'var2', 'corr']
corr_mat = corr_mat[corr_mat.var1!=corr_mat.var2].sort_values(by='corr', ascending=False)
corr_mat.head().append(corr_mat.tail())
# Out:
#            var1        var2      corr
# 650  return_42d  return_63d  0.835634
# 707  return_63d  return_42d  0.835634
# 64          rsi        macd  0.817113
# 349        macd         rsi  0.817113
# 586  return_21d        macd  0.793893
# 126     bb_high  return_21d -0.632777
# 125     bb_high  return_10d -0.693640
# 524  return_10d     bb_high -0.693640
# 60          rsi     bb_high -0.696555
# 117     bb_high         rsi -0.696555

# %%
y.boxplot();

# %%
X
# Out:
#                    dollar_vol_1m       rsi   bb_high    bb_mid    bb_low  \
# ticker date
# AAL    2013-07-25      -1.377498  1.427605 -0.773214  0.638319  0.535185
#        2013-07-26      -1.308351  1.606301 -0.824760  0.692322  0.589545
#        2013-07-29      -1.257876  1.697656 -0.802774  0.746909  0.595311
#        2013-07-30      -1.257131  1.642956 -0.684236  0.793530  0.550522
#        2013-07-31      -1.175599  1.747786 -0.709213  0.850254  0.527137
# ...                          ...       ...       ...       ...       ...
# ZTS    2014-11-28       0.482447  0.789549 -0.697431  0.222654  0.231390
#        2014-12-01       0.925568 -0.628407  0.432822  0.559544 -0.492799
#        2014-12-02       1.043318 -0.187862 -0.963998  0.881192 -0.779983
#        2014-12-03       0.577032 -0.019482 -1.418054  1.145108 -1.041020
#        2014-12-04      -0.830073 -2.259217  0.401583  1.361831 -1.879585
#
#                         atr      macd  return_1d  return_5d  return_10d  ...  \
# ticker date                                                              ...
# AAL    2013-07-25 -0.461161  0.702504   0.639313   0.267036    0.686683  ...
#        2013-07-26 -0.487341  0.784250   0.486606   0.559203    0.710383  ...
#        2013-07-29 -0.560761  0.857554   0.241291   0.701721    0.676785  ...
#        2013-07-30 -0.624026  0.902031  -0.095710   0.750056    0.574837  ...
#        2013-07-31 -0.702416  0.946050   0.259434   0.544923    0.410579  ...
# ...                     ...       ...        ...        ...         ...  ...
# ZTS    2014-11-28 -0.457231  0.456081   0.314405   1.766856   -0.136877  ...
#        2014-12-01 -0.419505 -0.181351  -1.004132   0.035205   -0.420698  ...
#        2014-12-02 -0.909876 -0.599807   0.496023  -0.424441   -0.882110  ...
#        2014-12-03 -1.449963 -1.012653   0.120329   0.660102   -0.770513  ...
#        2014-12-04 -1.222688 -2.173507  -1.519309  -1.530273   -0.819365  ...
#
#                    capital_goods  consumer_non-durables  consumer_services  \
# ticker date
# AAL    2013-07-25              0                      0                  0
#        2013-07-26              0                      0                  0
#        2013-07-29              0                      0                  0
#        2013-07-30              0                      0                  0
#        2013-07-31              0                      0                  0
# ...                          ...                    ...                ...
# ZTS    2014-11-28              0                      0                  0
#        2014-12-01              0                      0                  0
#        2014-12-02              0                      0                  0
#        2014-12-03              0                      0                  0
#        2014-12-04              0                      0                  0
#
#                    energy  finance  health_care  miscellaneous  \
# ticker date
# AAL    2013-07-25       0        0            0              0
#        2013-07-26       0        0            0              0
#        2013-07-29       0        0            0              0
#        2013-07-30       0        0            0              0
#        2013-07-31       0        0            0              0
# ...                   ...      ...          ...            ...
# ZTS    2014-11-28       0        0            1              0
#        2014-12-01       0        0            1              0
#        2014-12-02       0        0            1              0
#        2014-12-03       0        0            1              0
#        2014-12-04       0        0            1              0
#
#                    public_utilities  technology  transportation
# ticker date
# AAL    2013-07-25                 0           0               1
#        2013-07-26                 0           0               1
#        2013-07-29                 0           0               1
#        2013-07-30                 0           0               1
#        2013-07-31                 0           0               1
# ...                             ...         ...             ...
# ZTS    2014-11-28                 0           0               0
#        2014-12-01                 0           0               0
#        2014-12-02                 0           0               0
#        2014-12-03                 0           0               0
#        2014-12-04                 0           0               0
#
# [109675 rows x 58 columns]

# %%
sectors = X.iloc[:, -10:]
# Ticker-wise standardization
# apply() vs transform(): apply() manipulate all data. Whereas, transform() can control only 1 row or column
X = (X.drop(sectors.columns, axis=1).groupby(level='ticker').transform(lambda x: (x - x.mean()) / x.std())
    .join(sectors).fillna(0))

# 1d returns
target = 'target_1d'
model = OLS(endog=y[target], exog=add_constant(X))
trained_model = model.fit()
print(trained_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              target_1d   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     21.57
# Date:                Sun, 09 Apr 2023   Prob (F-statistic):          3.44e-222
# Time:                        15:36:04   Log-Likelihood:             2.8860e+05
# No. Observations:              109675   AIC:                        -5.771e+05
# Df Residuals:                  109616   BIC:                        -5.765e+05
# Df Model:                          58
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.0002      0.000     -0.794      0.427      -0.001       0.000
# dollar_vol_1m            -0.0003   6.89e-05     -4.325      0.000      -0.000      -0.000
# rsi                       0.0004      0.000      2.035      0.042    1.44e-05       0.001
# bb_high                   0.0002      0.000      0.826      0.409      -0.000       0.001
# bb_mid                   -0.0010   7.62e-05    -12.844      0.000      -0.001      -0.001
# bb_low                    0.0002      0.000      0.937      0.349      -0.000       0.001
# atr                       0.0003   8.02e-05      4.341      0.000       0.000       0.001
# macd                   3.615e-06      0.000      0.015      0.988      -0.000       0.000
# return_1d                 0.0027      0.000      8.954      0.000       0.002       0.003
# return_5d                -0.0014      0.001     -1.507      0.132      -0.003       0.000
# return_10d               -0.0064      0.001     -6.413      0.000      -0.008      -0.004
# return_21d                0.0029      0.000      6.442      0.000       0.002       0.004
# return_42d               -0.0038      0.001     -6.301      0.000      -0.005      -0.003
# return_63d               -0.0018      0.000     -4.099      0.000      -0.003      -0.001
# return_1d_lag1            0.0024      0.000      8.183      0.000       0.002       0.003
Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2799851.688
# Skew:                          -0.124   Prob(JB):                         0.00
# Kurtosis:                      27.751   Cond. No.                         80.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 5d returns
target = 'target_5d'
model = OLS(endog=y[target], exog=add_constant(X))
trained_model = model.fit()
print(trained_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              target_5d   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     74.58
# Date:                Sun, 09 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:36:41   Log-Likelihood:             3.7922e+05
# No. Observations:              109675   AIC:                        -7.583e+05
# Df Residuals:                  109616   BIC:                        -7.578e+05
# Df Model:                          58
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.0005      0.000     -3.424      0.001      -0.001      -0.000
# dollar_vol_1m            -0.0002   3.02e-05     -6.893      0.000      -0.000      -0.000
# rsi                       0.0007   8.43e-05      7.773      0.000       0.000       0.001
# bb_high                   0.0010   9.85e-05     10.170      0.000       0.001       0.001
# bb_mid                   -0.0009   3.34e-05    -27.833      0.000      -0.001      -0.001
# bb_low                   -0.0008   9.54e-05     -8.783      0.000      -0.001      -0.001
# atr                       0.0003   3.51e-05      7.631      0.000       0.000       0.000
# macd                   1.238e-05      0.000      0.118      0.906      -0.000       0.000
# return_1d                 0.0008      0.000      5.918      0.000       0.001       0.001
# return_5d                 0.0016      0.000      4.055      0.000       0.001       0.002
# return_10d               -0.0037      0.000     -8.594      0.000      -0.005      -0.003
# return_21d                0.0022      0.000     11.176      0.000       0.002       0.003
# return_42d               -0.0026      0.000     -9.810      0.000      -0.003      -0.002
# return_63d               -0.0017      0.000     -8.515      0.000      -0.002      -0.001
# return_1d_lag1            0.0007      0.000      5.550      0.000       0.000       0.001
# return_5d_lag1            0.0033      0.000     11.148      0.000       0.003       0.004
# return_10d_lag1           0.0007      0.000      1.555      0.120      -0.000       0.002
# return_21d_lag1           0.0022      0.000     12.918      0.000       0.002       0.003
# return_1d_lag2            0.0007      0.000      5.634      0.000       0.000       0.001
# return_5d_lag2           -0.0001      0.000     -0.363      0.717      -0.001       0.001
# return_10d_lag2          -0.0002      0.000     -0.520      0.603      -0.001       0.001
# return_21d_lag2           0.0006      0.000      4.950      0.000       0.000       0.001
# return_1d_lag3            0.0008      0.000      5.888      0.000       0.001       0.001
# return_5d_lag3         4.789e-05      0.000      0.144      0.886      -0.001       0.001
# return_10d_lag3           0.0005   6.38e-05      7.878      0.000       0.000       0.001
# return_21d_lag3       -8.101e-05   2.46e-05     -3.289      0.001      -0.000   -3.27e-05
# return_1d_lag4            0.0008      0.000      5.860      0.000       0.001       0.001
# return_5d_lag4            0.0005      0.000      1.748      0.080   -5.64e-05       0.001
# return_10d_lag4        3.168e-05   4.49e-05      0.706      0.480   -5.63e-05       0.000
# return_21d_lag4           0.0002   2.43e-05      7.283      0.000       0.000       0.000
# return_1d_lag5         1.313e-05   2.71e-05      0.485      0.628   -3.99e-05    6.62e-05
# return_5d_lag5            0.0003      0.000      1.264      0.206      -0.000       0.001
# return_10d_lag5           0.0004   4.35e-05      8.380      0.000       0.000       0.000
# return_21d_lag5           0.0003   2.41e-05     11.226      0.000       0.000       0.000
# year_2014                -0.0002   3.72e-05     -4.512      0.000      -0.000   -9.49e-05
# year_2015                -0.0003    4.1e-05     -7.224      0.000      -0.000      -0.000
# year_2016             -7.994e-05   4.01e-05     -1.993      0.046      -0.000   -1.33e-06
# year_2017                 0.0003   4.29e-05      8.093      0.000       0.000       0.000
# month_2                   0.0009   3.15e-05     27.036      0.000       0.001       0.001
# month_3                   0.0002   3.26e-05      4.609      0.000    8.62e-05       0.000
# month_4                   0.0004   3.22e-05     10.950      0.000       0.000       0.000
# month_5                   0.0005   3.18e-05     16.637      0.000       0.000       0.001
# month_6                   0.0003   3.24e-05     10.622      0.000       0.000       0.000
# month_7                   0.0005   3.35e-05     16.133      0.000       0.000       0.001
# month_8                   0.0001   3.39e-05      4.143      0.000    7.39e-05       0.000
# month_9                   0.0004   3.34e-05     10.957      0.000       0.000       0.000
# month_10                  0.0005   3.43e-05     15.276      0.000       0.000       0.001
# month_11                  0.0006   3.34e-05     16.825      0.000       0.000       0.001
# month_12                  0.0002   3.26e-05      6.986      0.000       0.000       0.000
# capital_goods             0.0011      0.000      6.723      0.000       0.001       0.001
# consumer_non-durables     0.0009      0.000      5.198      0.000       0.001       0.001
# consumer_services         0.0009      0.000      6.059      0.000       0.001       0.001
# energy                    0.0004      0.000      2.497      0.013    8.21e-05       0.001
# finance                   0.0010      0.000      6.533      0.000       0.001       0.001
# health_care               0.0008      0.000      5.259      0.000       0.000       0.001
# miscellaneous             0.0012      0.000      6.376      0.000       0.001       0.002
# public_utilities          0.0003      0.000      1.871      0.061   -1.65e-05       0.001
# technology                0.0011      0.000      7.787      0.000       0.001       0.001
# transportation            0.0010      0.000      5.941      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                    44086.839   Durbin-Watson:                   0.436
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2327995.228
# Skew:                          -1.165   Prob(JB):                         0.00
# Kurtosis:                      25.450   Cond. No.                         80.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
preds = trained_model.predict(add_constant(X))
residuals = y[target] - preds
fig, axes = plt.subplots(ncols=2, figsize=(14,6))
sns.distplot(residuals, fit=norm, ax=axes[0], axlabel='Residuals', label='Residuals')
axes[0].set_title('Residual Distribution')
axes[0].legend()
plot_acf(residuals, lags=10, zero=False, ax=axes[1], title='Residual Autocorrelation')
axes[1].set_xlabel('Lags')
# Out:
# Text(0.5, 0, 'Lags')

# %%
# 10d returns
target = 'target_10d'
model = OLS(endog=y[target], exog=add_constant(X))
trained_model = model.fit()
print(trained_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             target_10d   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     111.2
# Date:                Sun, 09 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:43:35   Log-Likelihood:             4.1968e+05
# No. Observations:              109675   AIC:                        -8.392e+05
# Df Residuals:                  109616   BIC:                        -8.387e+05
# Df Model:                          58
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                
# month_9                   0.0002   2.31e-05      6.607      0.000       0.000       0.000
# month_10                  0.0004   2.37e-05     18.523      0.000       0.000       0.000
# month_11                  0.0003   2.31e-05     14.574      0.000       0.000       0.000
# month_12               4.851e-05   2.25e-05      2.153      0.031    4.35e-06    9.27e-05
# capital_goods             0.0010      0.000      8.745      0.000       0.001       0.001
# consumer_non-durables     0.0007      0.000      6.443      0.000       0.001       0.001
# consumer_services         0.0007      0.000      7.259      0.000       0.001       0.001
# energy                    0.0003      0.000      2.754      0.006     8.4e-05       0.000
# finance                   0.0009      0.000      8.375      0.000       0.001       0.001
# health_care               0.0006      0.000      6.211      0.000       0.000       0.001
# miscellaneous             0.0012      0.000      8.915      0.000       0.001       0.001
# public_utilities          0.0002      0.000      1.629      0.103   -4.22e-05       0.000
# technology                0.0010      0.000     10.053      0.000       0.001       0.001
# transportation            0.0010      0.000      7.983      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                    39078.426   Durbin-Watson:                   0.233
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1091663.386
# Skew:                          -1.124   Prob(JB):                         0.00
# Kurtosis:                      18.292   Cond. No.                         80.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 21d returns
target = 'target_21d'
model = OLS(endog=y[target], exog=add_constant(X))
trained_model = model.fit()
print(trained_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             target_21d   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     168.5
# Date:                Sun, 09 Apr 2023   Prob (F-statistic):               0.00
# Time:                        02:34:23   Log-Likelihood:             4.6292e+05
# No. Observations:              109675   AIC:                        -9.257e+05
# Df Residuals:                  109616   BIC:                        -9.252e+05
# Df Model:                          58
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.0003   6.36e-05     -4.413      0.000      -0.000      -0.000
# dollar_vol_1m          1.072e-05   1.41e-05      0.762      0.446   -1.69e-05    3.83e-05
# rsi                       0.0002   3.93e-05      4.861      0.000       0.000       0.000
# bb_high                   0.0002   4.59e-05      3.316      0.001    6.22e-05       0.000
# bb_mid                   -0.0008   1.56e-05    -52.688      0.000      -0.001      -0.001
# bb_low                   -0.0002   4.45e-05     -3.715      0.000      -0.000   -7.81e-05
# atr                       0.0001   1.64e-05      8.151      0.000       0.000       0.000
# macd                      0.0001   4.88e-05      2.370      0.018       2e-05       0.000
# return_1d                 0.0001   6.04e-05      1.945      0.052    -9.2e-07       0.000
# return_5d             -9.893e-05      0.000     -0.523      0.601      -0.000       0.000
# return_10d               -0.0002      0.000     -1.206      0.228      -0.001       0.000
# return_21d                0.0018    9.3e-05     19.739      0.000       0.002       0.002
# return_42d               -0.0019      0.000    -15.731      0.000      -0.002      -0.002
# return_63d               -0.0011    9.2e-05    -12.239      0.000      -0.001      -0.001
# return_1d_lag1            0.0001   6.02e-05      1.769      0.077   -1.15e-05       0.000
# return_5d_lag1            0.0002      0.000      1.427      0.154   -7.41e-05       0.000
# return_10d_lag1           0.0001      0.000      0.458      0.647      -0.000       0.001
# return_21d_lag1           0.0018   7.84e-05     23.502      0.000       0.002       0.002
# return_1d_lag2            0.0001   6.03e-05      2.014      0.044    3.25e-06       0.000
# return_5d_lag2        -3.043e-05      0.000     -0.196      0.844      -0.000       0.000
# return_10d_lag2           0.0003      0.000      1.483      0.138   -8.11e-05       0.001
# return_21d_lag2           0.0006   6.03e-05      9.178      0.000       0.000       0.001
# return_1d_lag3            0.0001   6.06e-05      2.298      0.022    2.05e-05       0.000
# return_5d_lag3         3.455e-05      0.000      0.222      0.824      -0.000       0.000
# return_10d_lag3           0.0001   2.97e-05      3.615      0.000    4.92e-05       0.000
# return_21d_lag3        1.415e-05   1.15e-05      1.233      0.218   -8.35e-06    3.67e-05
# return_1d_lag4            0.0001    6.1e-05      2.397      0.017    2.67e-05       0.000
# return_5d_lag4           -0.0001      0.000     -0.923      0.356      -0.000       0.000
# return_10d_lag4        2.668e-05   2.09e-05      1.275      0.202   -1.43e-05    6.77e-05
# return_21d_lag4           0.0002   1.13e-05     19.925      0.000       0.000       0.000
# return_1d_lag5         4.894e-06   1.26e-05      0.388      0.698   -1.98e-05    2.96e-05
# return_5d_lag5           -0.0001      0.000     -1.198      0.231      -0.000     9.2e-05
# return_10d_lag5          2.6e-06   2.03e-05      0.128      0.898   -3.71e-05    4.23e-05
# return_21d_lag5        3.803e-05   1.13e-05      3.378      0.001     1.6e-05    6.01e-05
# year_2014                -0.0001   1.73e-05     -7.982      0.000      -0.000      -0.000
# year_2015                -0.0003   1.91e-05    -17.875      0.000      -0.000      -0.000
# year_2016              3.289e-05   1.87e-05      1.759      0.079   -3.75e-06    6.95e-05
# year_2017                 0.0003      2e-05     13.795      0.000       0.000       0.000
# month_2                7.198e-05   1.47e-05      4.896      0.000    4.32e-05       0.000
# month_3                  -0.0001   1.52e-05     -8.488      0.000      -0.000   -9.91e-05
# month_4               -8.671e-05    1.5e-05     -5.775      0.000      -0.000   -5.73e-05
# month_5                8.389e-05   1.48e-05      5.656      0.000    5.48e-05       0.000
# month_6                7.938e-05   1.51e-05      5.260      0.000    4.98e-05       0.000
# month_7                  -0.0002   1.56e-05    -13.138      0.000      -0.000      -0.000
# month_8                  -0.0001   1.58e-05     -9.126      0.000      -0.000      -0.000
# month_9               -8.721e-05   1.56e-05     -5.599      0.000      -0.000   -5.67e-05
# month_10                  0.0002    1.6e-05      9.617      0.000       0.000       0.000
# month_11              -2.527e-05   1.56e-05     -1.621      0.105   -5.58e-05    5.28e-06
# month_12                 -0.0003   1.52e-05    -21.183      0.000      -0.000      -0.000
# capital_goods             0.0008   7.48e-05     11.338      0.000       0.001       0.001
# consumer_non-durables     0.0007   7.74e-05      8.727      0.000       0.001       0.001
# consumer_services         0.0006   6.92e-05      9.045      0.000       0.000       0.001
# energy                    0.0002   7.13e-05      2.685      0.007    5.17e-05       0.000
# finance                   0.0008   7.28e-05     10.929      0.000       0.001       0.001
# health_care               0.0005    6.8e-05      7.587      0.000       0.000       0.001
# miscellaneous             0.0012   8.91e-05     13.132      0.000       0.001       0.001
# public_utilities          0.0001    8.6e-05      1.256      0.209   -6.05e-05       0.000
# technology                0.0009   6.86e-05     13.586      0.000       0.001       0.001
# transportation            0.0009   8.14e-05     11.305      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                    41198.463   Durbin-Watson:                   0.128
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           853976.582
# Skew:                          -1.304   Prob(JB):                         0.00
# Kurtosis:                      16.419   Cond. No.                         80.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
