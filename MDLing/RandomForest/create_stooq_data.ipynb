# %%
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path
import requests
from io import BytesIO
from zipfile import ZipFile, BadZipFile

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from sklearn.datasets import fetch_openml

pd.set_option('display.expand_frame_repr', False)

# %%
DATA_STORE = Path('data/assets.h5')

# %%
stooq_path = Path('data/stooq')
if not stooq_path.exists():
    stooq_path.mkdir()

# %%
# download manually is req from https://stooq.com/db/l/?g={code}
# code : metadata_dict numbers
metadata_dict = {
    ('jp', 'tse etfs'): 34,
    ('jp', 'tse stocks'): 32,
    ('us', 'nasdaq etfs'): 69,
    ('us', 'nasdaq stocks'): 27,
    ('us', 'nyse etfs'): 70,
    ('us', 'nyse stocks'): 28,
    ('us', 'nysemkt stocks'): 26
}

# %%
for (market, asset_class), code in metadata_dict.items():
    try:
        print(market, asset_class)
        df = pd.read_csv(f'data/stooq/txt/{asset_class}.txt', sep=', ', header=None)
        df.columns = ['ticker', 'name']
        df = df.drop_duplicates('ticker').dropna()
        # print(market, asset_class, f'# tickers: {df.shape[0]:,.0f}')
        path = stooq_path / 'tickers' / market
        if not path.exists():
            path.mkdir(parents=True)
        df.to_csv(path / f'{asset_class}.csv', index=False)
    except Exception as e:
        print(e, market, asset_class)
# Out:
# jp tse etfs
# jp tse stocks
# us nasdaq etfs
# us nasdaq stocks
# us nyse etfs
# us nyse stocks
# us nysemkt stocks

# %%
def get_stooq_prices_and_tickers(frequency='daily', market='us', asset_class='nasdaq etfs'):
    prices = []

    tickers = (pd.read_csv(stooq_path / 'tickers' / market / f'{asset_class}.csv'))

    if frequency in ['5 min', 'hourly']:
        parse_dates = [['date', 'time']]
        date_label = 'date_time'
    else:
        parse_dates = ['date']
        date_label = 'date'
    names = ['ticker', 'freq', 'date', 'time', 'open', 'high', 'low', 'close','volume', 'openint']

    usecols = ['ticker', 'open', 'high', 'low', 'close', 'volume'] + parse_dates
    path = stooq_path / 'data' / frequency / market / asset_class
    print(path.as_posix())
    files = path.glob('**/*.txt')
    for i, file in enumerate(files, 1):
        if i % 500 == 0:
            print(i)
        if file.stem not in set(tickers.ticker.str.lower()):
            print(file.stem, 'not available')
            file.unlink()
        else:
            try:
                df = (pd.read_csv(file, names=names, usecols=usecols, header=0, parse_dates=parse_dates))
                prices.append(df)
            except pd.errors.EmptyDataError:
                print('\tdata missing', file.stem)
                file.unlink()

    prices = (pd.concat(prices, ignore_index=True).rename(columns=str.lower)
              .set_index(['ticker', date_label]).apply(lambda x: pd.to_numeric(x, errors='coerce')))
    return prices, tickers

# %%
# load some Japanese and all US assets for 2000-2023
markets = {'jp': ['tse stocks'],
           'us': ['nasdaq etfs', 'nasdaq stocks', 'nyse etfs', 'nyse stocks', 'nysemkt stocks']}
frequency = 'daily'

idx = pd.IndexSlice
for market, asset_classes in markets.items():
    for asset_class in asset_classes:
        print(f'\n{asset_class}')
        prices, tickers = get_stooq_prices_and_tickers(frequency=frequency, market=market, asset_class=asset_class)

        prices = prices.sort_index().loc[idx[:, '2000': '2023'], :]
        names = prices.index.names
        prices = (prices.reset_index().drop_duplicates().set_index(names).sort_index())

        print('\nNo. of observations per asset')
        print(prices.groupby('ticker').size().describe())
        key = f'stooq/{market}/{asset_class.replace(" ", "/")}/'

        print(prices.info(null_counts=True))

        prices.to_hdf(DATA_STORE, key + 'prices', format='t')

        print(tickers.info())
        tickers.to_hdf(DATA_STORE, key + 'tickers', format='t')
# Out:
# tse stocks
# stooq/data/daily/jp/tse stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
#
# No. of observations per asset
# count    3889.000000
# mean     3254.058113
# std      1523.918803
# min         1.000000
# 25%      2094.000000
# 50%      3830.000000
# 75%      4433.000000
# max      5717.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 12655032 entries, ('1301.JP', Timestamp('2005-03-22 00:00:00')) to ('9997.JP', Timestamp('2023-05-01 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count     Dtype
# ---  ------  --------------     -----
#  0   open    12655032 non-null  float64
#  1   high    12655032 non-null  float64
#  2   low     12655032 non-null  float64
#  3   close   12655032 non-null  float64
#  4   volume  12655032 non-null  float64
# dtypes: float64(5)
# memory usage: 531.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3889 entries, 0 to 3888
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  3889 non-null   object
#  1   name    3889 non-null   object
# dtypes: object(2)
# memory usage: 60.9+ KB
# None
#
# nasdaq etfs
# stooq/data/daily/us/nasdaq etfs
# pr_.us not available
#
# No. of observations per asset
# count     378.000000
# mean     2265.976190
# std      1227.360718
# min       450.000000
# 25%      1224.000000
# 50%      2109.500000
# 75%      3132.500000
# max      5873.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 856539 entries, ('AADR.US', Timestamp('2010-07-21 00:00:00')) to ('YLDE.US', Timestamp('2023-05-05 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   open    856539 non-null  float64
#  1   high    856539 non-null  float64
#  2   low     856539 non-null  float64
#  3   close   856539 non-null  float64
#  4   volume  856539 non-null  float64
# dtypes: float64(5)
# memory usage: 36.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  379 non-null    object
#  1   name    379 non-null    object
# dtypes: object(2)
# memory usage: 6.0+ KB
# None
#
# nasdaq stocks
# stooq/data/daily/us/nasdaq stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
#
# No. of observations per asset
# count    5036.000000
# mean     1630.827244
# std      1716.345192
# min         1.000000
# 25%       300.000000
# 50%       713.500000
# 75%      2770.000000
# max      5873.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8212846 entries, ('AACG.US', Timestamp('2008-01-28 00:00:00')) to ('ZYXI.US', Timestamp('2023-05-05 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    8212846 non-null  float64
#  1   high    8212846 non-null  float64
#  2   low     8212846 non-null  float64
#  3   close   8212846 non-null  float64
#  4   volume  8212846 non-null  float64
# dtypes: float64(5)
# memory usage: 345.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  5050 non-null   object
#  1   name    5050 non-null   object
# dtypes: object(2)
# memory usage: 79.0+ KB
# None
#
# nyse etfs
# stooq/data/daily/us/nyse etfs
# 500
# 1000
# 1500
# 2000
#
# No. of observations per asset
# count    2259.000000
# mean     1949.195219
# std      1426.104160
# min       262.000000
# 25%       662.000000
# 50%      1453.000000
# 75%      3201.500000
# max      4580.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4403232 entries, ('AAA.US', Timestamp('2020-09-11 00:00:00')) to ('ZSL.US', Timestamp('2023-05-05 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    4403232 non-null  float64
#  1   high    4403232 non-null  float64
#  2   low     4403232 non-null  float64
#  3   close   4403232 non-null  float64
#  4   volume  4403232 non-null  float64
# dtypes: float64(5)
# memory usage: 185.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260 entries, 0 to 2259
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  2260 non-null   object
#  1   name    2260 non-null   object
# dtypes: object(2)
# memory usage: 35.4+ KB
# None
#
# nyse stocks
# stooq/data/daily/us/nyse stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
#
# No. of observations per asset
# count    3695.000000
# mean     2366.600271
# std      1960.288108
# min         1.000000
# 25%       451.000000
# 50%      1875.000000
# 75%      4579.000000
# max      5873.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8744588 entries, ('A.US', Timestamp('2000-01-03 00:00:00')) to ('ZXIET.US', Timestamp('2023-05-02 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    8744588 non-null  float64
#  1   high    8744588 non-null  float64
#  2   low     8744588 non-null  float64
#  3   close   8744588 non-null  float64
#  4   volume  8744588 non-null  float64
# dtypes: float64(5)
# memory usage: 367.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3698 entries, 0 to 3697
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  3698 non-null   object
#  1   name    3698 non-null   object
# dtypes: object(2)
# memory usage: 57.9+ KB
# None
#
# nysemkt stocks
# stooq/data/daily/us/nysemkt stocks
# mimo-ws-b.us not available
# oust-ws-a.us not available
#
# No. of observations per asset
# count     355.000000
# mean     2351.247887
# std      1854.390864
# min         1.000000
# 25%       433.500000
# 50%      2229.000000
# 75%      4410.500000
# max      5871.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 834693 entries, ('AAMC.US', Timestamp('2022-03-22 00:00:00')) to ('ZOM.US', Timestamp('2023-05-05 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   open    834693 non-null  float64
#  1   high    834693 non-null  float64
#  2   low     834693 non-null  float64
#  3   close   834693 non-null  float64
#  4   volume  834693 non-null  float64
# dtypes: float64(5)
# memory usage: 35.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355 entries, 0 to 354
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  355 non-null    object
#  1   name    355 non-null    object
# dtypes: object(2)
# memory usage: 5.7+ KB
# None
